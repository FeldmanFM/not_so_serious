# %%
from openstack import connection, identity
import numpy as np
import copy
import re
import openpyxl
from openpyxl import *
import os
from openpyxl.styles import Color, PatternFill, Font, Border
from openpyxl.styles import colors, Alignment
from openpyxl.cell import Cell
import configparser, logging, operator

# %%
def connection_to_cluster(project):
    conn = connection.Connection(auth_url="http://controller:35357/v3",
                                 project_name=project,
                                 project_domain_name="default",
                                 user_domain_name="default",
                                 username="admin",
                                 password="QIP@t4Ay")
    return conn

# %%
class OSmap(object):
    
    def __init__ (self, connection='', OS=True, with_flavors=True, with_volumes=True, hypervisor_details=False):
        'Инит функция'
        if OS == True:
            self.__conn = connection
            self.__sl = [i for i in self.__conn.compute.servers(all_tenants=True)]
            self.__hl = [i for i in self.__conn.compute.hypervisors()]
            
            if with_flavors == True:
                self.__fd = self.__get_fl_dict()
                self.dict_flavors = copy.deepcopy(self.__fd)
            
            if with_volumes == True:
                self.__vd = self.__get_vl_dict()
                self.dict_volumes = copy.deepcopy(self.__vd)
                
                
            self.dict_hypervisors = self.__get_hp_dict(details=hypervisor_details)
            self.dict_servers = self.__get_vm_dict(flavors=with_flavors)
            self.list_names  = self.__get_names()
    
    
    def get_vm_by_name(self, vmn=''):
        'Функция возвращает объект ВМ на основании имени'
        for i in self.__sl:
            if i.name == vmn:
                return i 
    
    def get_vm_by_id(self, vmn=''):
        'Функция возвращает объект ВМ на основании ID'
        for i in self.__sl:
            if i.id == vmn:
                return i 
    
        
    
    def __get_hp_dict(self, details=False):
        'Функция возвращает словарь гипервизоров'
        d = {}
        for i in self.__hl:
            if details == True:
                d[i.name]=self.__conn.compute.get_hypervisor(i.id).to_dict()
            else:
                d[i.name]=i.to_dict()
        return d   
           
    def __get_fl_dict(self):
        'Функция возвращает словарь флейворов'
        d = {}
        for i in set([i.flavor['id'] for i in self.__sl]):
            d[i]=self.__conn.compute.get_flavor(flavor=i).to_dict()
        return d
    
    def __get_vl_dict(self):
        'Функция возвращает словарь вольюмов'
        d = {}
        for i in [i for i in self.__conn.block_store.volumes(all_tenants=True)]:
            d[i.id]=i.to_dict()
        return d
    
    
    def __get_names (self):
        'Функция возвращает список имен ВМ'
        a = [i.name for i in self.__sl]
        return a
    
            
    def __get_vm_dict(self,flavors=True):
        'Возвращает словарь с описанием ВМ из OS + cpu & ram'
        d = {}
        for i in self.__sl:
            d[i.name] = self.get_vm_by_name(vmn=i.name).to_dict()
            if flavors == True:
                d[i.name]['cpu'] = self.__fd[i.flavor['id']]['vcpus']
                d[i.name]['ram'] = self.__fd[i.flavor['id']]['ram']
        return d

# %%
conn = connection_to_cluster('admin')

# %%
##%%time
#x = OSmap(connection_to_cluster('admin'), with_flavors=False, with_volumes=False)

# %%
#%%time
#y = OSmap(connection_to_cluster('admin'), with_flavors=True, with_volumes=False)

# %%
#%%time
#z = OSmap(connection_to_cluster('admin'), with_flavors=True, with_volumes=True)

# %%
#%%time
#x1 = OSmap(connection_to_cluster('admin'), with_flavors=False, with_volumes=False, hypervisor_details=True)

# %%
#%%time
#y1 = OSmap(connection_to_cluster('admin'), with_flavors=True, with_volumes=False, hypervisor_details=True)

# %%
# %%time
z1 = OSmap(connection_to_cluster('admin'), with_flavors=True, with_volumes=True, hypervisor_details=True)
# Out:
# CPU times: user 4.51 s, sys: 167 ms, total: 4.68 s
# Wall time: 37.9 s

# %% [markdown]
# ## Копируем данные из класса. Создаем словарь групп

# %%
## Типы распределений
## 1 - распределение по зонам доступности
## 2 - распределение по ВУ
## 3 - распределение по модулю 2 (четные на одной ЗД, нечетные на другой ЗД)
## *** по 3 модулю пробуем распеределение нечетные на одной - четные на двух других
## 4 - распределение по модулю 3 (1,2,3 на разных ЗД)
## 5 - распределение - master-stanby на разных ЗД
## 6 - распределение - migr ВМ
## 7 - распределение ВМ на мигр нодах

# %%
dRealVm = copy.deepcopy(z1.dict_servers)

# %%
lRealVmName = copy.deepcopy(z1.list_names)

# %%
dRealHyper = copy.deepcopy(z1.dict_hypervisors)

# %%
master_slave_list = [\
                    ['pg-master-standby','pg-master'],\
                    ['pg-attribute-standby-books','pg-attribute-books'],\
                    ['pg-attribute-standby-borders','pg-attribute-borders'],\
                    ['pg-attribute-standby-right-registry-entities','pg-attribute-right-registry-entities'],\
                    ['pg-reservation-01-standby','pg-reservation-01'],\
                     ['pg-master-replica-standby-01','pg-master-replica-01']\
                    
                    ]
reserve_list = [\
               'cn-e0f6.egron.tnx',\
               'cn-dce8.egron.tnx',\
               'cn-e624.egron.tnx'\
              ]

# %%
#######
#######
#######  GLOBAL VARIABLES

on_the_place_limit = 0.01

# %%
test_machines = [i for i in lRealVmName if ('bragin' in i or 'lacp' in i or 'Free' in i or 'is_efem' in i or 'gerc' in i)]

# %%
master_slave_list
total_ms_list = [i for j in master_slave_list for i in j]

# %%
[i for i in master_slave_list if 'pg-master-standby' in i ][0]
# Out:
# ['pg-master-standby', 'pg-master']

# %%
with open('./group_prefix', 'r') as f:
    lGroupPrefix = f.readlines()
    lGroupPrefix = [i.replace('\n','') for i in lGroupPrefix]
f.close()


#with open('./group_prefixes_via_types2', 'r') as f:
#    lGroupPrefixTypes = f.readlines()
#    lGroupPrefixTypes = [i.replace('\n','') for i in lGroupPrefixTypes]
#    lGroupPrefixTypes = [i.split(',') for i in lGroupPrefixTypes]
#f.close()


with open('./group_prefix_via_types2', 'r') as f:
    lGroupPrefixTypes = f.readlines()
    lGroupPrefixTypes = [i.replace('\n','') for i in lGroupPrefixTypes]
    lGroupPrefixTypes = [i.split(',') for i in lGroupPrefixTypes]
f.close()


with open('./z1', 'r') as f:
    lAZ1 = f.readlines()
    lAZ1 = [i.replace('\n','') for i in lAZ1]
f.close()


with open('./z2', 'r') as f:
    lAZ2 = f.readlines()
    lAZ2 = [i.replace('\n','') for i in lAZ2]
f.close()
    
with open('./z3', 'r') as f:
    lAZ3 = f.readlines()
    lAZ3 = [i.replace('\n','') for i in lAZ3]
f.close()

with open('./very_new_cn_all', 'r') as f:
    lCN = f.readlines()
    lCN = [i.replace('\n','') for i in lCN]
    lCN = [i.split(',') for i in lCN]
f.close()

with open('./very_new_cn_migr', 'r') as f:
    lMigr = f.readlines()
    lMigr = [i.replace('\n','') for i in lMigr]
    lMigr = [i.split(',') for i in lMigr]
    lMigr = [i[1] for i in lMigr]
f.close()

# %%
dGroups = {}
for lprefix in lGroupPrefixTypes:
    prefix_name=lprefix[0]
    prefix_type=int(lprefix[1])
    sTemp = re.escape(prefix_name) + r"-\d{2,}"
    #print(prefix)
    regexp = re.compile(sTemp, re.IGNORECASE)
    dGroups[prefix_name]={}
    dGroups[prefix_name]['type'] = prefix_type
    dGroups[prefix_name]['vms'] = []
    for vm in lRealVmName:
        if regexp.match(vm):
            #print(vm)
            dGroups[prefix_name]['vms'].append(vm)
    dGroups[prefix_name]['vm_count'] = len(dGroups[prefix_name]['vms'])

# %%
#[[i, dGroups[i]['vm_count']] for i in dGroups.keys() if dGroups[i]['type'] == 1]

# %%
def _make_xls_width_sub(worksheet):
    for column_cells in worksheet.columns:
        length = max(len(_make_xls_as_text(cell.value)) for cell in column_cells)
        worksheet.column_dimensions[column_cells[0].column].width = length

def _make_xls_as_text(value):
    if value is None:
        return ""
    return str(value)


def make_xls():
    file="my_big_table.xlsx"
    wb = Workbook ()
    try:
        os.remove(file)
    except OSError:
        pass
    ws = wb.active
    
    ws.title=('Сводка')
    dh=copy.deepcopy(dUseHyper)
    dv = copy.deepcopy(dUseVms)
    l = [dh[h]['free_ram']/dh[h]['total_ram']  for h in dh.keys() if h not in reserve_list]
    m = [dh[h]['free_cpu']/dh[h]['total_cpu']  for h in dh.keys() if h not in reserve_list]
    #m = [hpd_res[h]['perc_cpu'] for h in hpd_res.keys()]
    vml = sum([dh[h]['vm_count'] for h in dh.keys()])
    hpl = [i for i in dh.keys()]
    migrations = count_migrations(d=dv)
    #print("Всего машин:", vml)
    #print("Всего ВУ:", len(hpl))
    #print("Забитость ВУ по RAM")
    #print("Самый забитый :", 1-min(l))
    #print("Наименее забитый :", 1-max(l))
    #print("Средняя загруженность :",  1 - sum(l)/len(l))
    #print("Среднедратичное отклонение по ВУ :",  np.std(l))
    #print('')
    #print("Перерасход vCPU относительно CPU ВУ ")
    #print("Самый забитый :", 1-min(m))
    #print("Наименее забитый :", 1-max(m))
    #print("Средняя загруженность :", 1 - sum(m)/len(m))
    ws.cell(column = 1, row = 2, value='Всего машин:')
    ws.cell(column = 1, row = 3, value='Всего ВУ')
    ws.cell(column = 1, row = 4, value='Самый забитый по RAM')
    ws.cell(column = 1, row = 5, value='Наименее забитый по RAM')
    ws.cell(column = 1, row = 6, value='Средняя загруженность ВУ по RAM')
    ws.cell(column = 1, row = 7, value='Среднеквадратичное отклонение по ВУ')
    ws.cell(column = 1, row = 8, value='')
    ws.cell(column = 1, row = 9, value='Самый забитый ВУ по CPU')
    ws.cell(column = 1, row = 10, value='Наименее забитый ВУ по CPU')
    ws.cell(column = 1, row = 11, value='Средняя загруженность по CPU')
    ws.cell(column = 1, row = 12, value='')
    ws.cell(column = 1, row = 13, value='Количество миграций')
    ws.cell(column = 2, row = 2, value=vml)
    ws.cell(column = 2, row = 3, value=len(hpl))
    ws.cell(column = 2, row = 4, value=1-min(l))
    ws.cell(column = 2, row = 5, value=1-max(l))
    ws.cell(column = 2, row = 6, value=1 - sum(l)/len(l))
    ws.cell(column = 2, row = 7, value=np.std(l))
    ws.cell(column = 2, row = 8, value='')
    ws.cell(column = 2, row = 9, value=1-min(m))
    ws.cell(column = 2, row = 10, value=1-max(m))
    ws.cell(column = 2, row = 11, value=1 - sum(m)/len(m))
    ws.cell(column = 2, row = 12, value='')
    ws.cell(column = 2, row = 13, value=migrations)

    ws = wb.create_sheet('Распределение ВМ по ВУ')
    warningFill = PatternFill(start_color='ffcc33',
                       end_color='ffcc33', fill_type='solid')
    criticalFill = PatternFill(start_color='ee4000',
                       end_color='ee4400', fill_type='solid')
    headersFill = PatternFill(start_color='ebecec',
                       end_color='ebecec', fill_type='solid')
    vm_headersFill = PatternFill(start_color='faebd7',
                       end_color='faebd7', fill_type='solid')
    top_headersFill = PatternFill(start_color='C2C8CC',
                       end_color='C2C8CC', fill_type='solid')

    row = 3
    col = 1
    t=dUseHyper
    ws.merge_cells('A1:E1')

    for i in t.keys():
        migration = t[i]['migr']
        if migration:
            mig = 'Да'
        else:
            mig = 'Нет'
        for rows in ws.iter_rows(min_row=row - 1, max_row=row - 1 , min_col=1, max_col=7):
            for cell in rows:
                cell.font = Font(italic=True)
                cell.alignment= Alignment(horizontal='center')
                cell.fill = top_headersFill
        ws.cell(column = col, row = row - 1 , value='Имя ВУ').alignment= Alignment(horizontal='left')
        ws.cell(column = col + 1, row = row  - 1, value='Номер зоны доступности')
        ws.cell(column = col + 2, row = row - 1, value='Переподписка по CPU')
        ws.cell(column = col + 3, row = row - 1, value='Свободная RAM')
        ws.cell(column = col + 4, row = row - 1, value='Количество ВМ на ВУ')
        ws.cell(column = col + 5, row = row - 1, value='Нода миграции')
        for rows in ws.iter_rows(min_row=row + 1, max_row=row + 1 , min_col=1, max_col=7):
            for cell in rows:
                cell.font = Font(italic=True) 
                cell.alignment= Alignment(horizontal='right')
        ws.cell(column=col, row=row).font = Font(name='Calibri', bold=True)
        for rows in ws.iter_rows(min_row=row , max_row=row, min_col=1, max_col=7):
            for cell in rows:
                  cell.fill = headersFill 
        ws.cell(column=col, row=row, value=i)
        ws.cell(column=col + 1, row=row, value=t[i]['az'])
        ws.cell(column=col + 2, row=row, value="{:10.2f}".format((t[i]['free_cpu']))).alignment = Alignment(horizontal='center')
        ws.cell(column=col + 3, row=row, value="{:10.2f}".format((t[i]['free_ram']))).alignment = Alignment(horizontal='center')
        ws.cell(column=col + 4, row=row, value=t[i]['vm_count'])
        ws.cell(column = col + 5, row = row , value=mig).alignment = Alignment(horizontal='center')
       # ws.cell(column=col + 5, row=row, value=t[i]['vm_critical']) 
       # ws.cell(column=col + 6, row=row, value=t[i]['vm_warning']) 
        row = row + 1
        for rows in ws.iter_rows(min_row=row, max_row=row, min_col=1, max_col=7):
            for cell in rows:
                cell.fill = vm_headersFill
                cell.alignment = Alignment(horizontal='center')
        ws.cell(column=col + 2, row=row, value='Имя ВМ').alignment = Alignment(horizontal='left')
        ws.cell(column=col + 3, row=row, value='vCPU')
        ws.cell(column=col + 4, row=row, value='RAM') 
        ws.cell(column=col + 5, row=row, value='Имя логической группы') 

        row = row + 1
        for j in t[i]['vms']:
            v = dUseVms[j]
            ws.cell(column=col + 2, row=row, value=v['name'])
            ws.cell(column=col + 3, row=row, value=v['cpu'])
            ws.cell(column=col + 4, row=row, value=v['ram']) 
            #if v['crit_rate'] == 2:
            #    crit = 1
            #elif v['crit_rate'] == 1:
            #    crit = 2
            #elif v['crit_rate'] == 0:
            #    crit = 'н/д'
            #ws.cell(column=col + 5, row=row, value=crit)
            #if v['crit_rate'] == 2:
            #    for rows in ws.iter_rows(min_row=row, max_row=row, min_col=3, max_col=7):
            #        for cell in rows:
            #              cell.fill = criticalFill
            #elif v['crit_rate'] == 1:
            #    for rows in ws.iter_rows(min_row=row, max_row=row, min_col=3, max_col=7):
            #        for cell in rows:
            #              cell.fill = warningFill

            ws.cell(column=col + 5, row=row, value=v['group']) 
            row = row + 1
        row = row + 2
        
        
        
    ################################################   
    ################################################   JUST MIGR #############################
    ################################################
    ws = wb.create_sheet('Ноды миграции')
    row = 3
    col = 1
    for i in t.keys():
        migration = t[i]['migr']
        if migration:
            mig = 'Да'
        else:
            mig = 'Нет'
            continue
        for rows in ws.iter_rows(min_row=row - 1, max_row=row - 1 , min_col=1, max_col=7):
            for cell in rows:
                cell.font = Font(italic=True)
                cell.alignment= Alignment(horizontal='center')
                cell.fill = top_headersFill
        ws.cell(column = col, row = row - 1 , value='Имя ВУ').alignment= Alignment(horizontal='left')
        ws.cell(column = col + 1, row = row  - 1, value='Номер зоны доступности')
        ws.cell(column = col + 2, row = row - 1, value='Переподписка по CPU')
        ws.cell(column = col + 3, row = row - 1, value='Свободная RAM')
        ws.cell(column = col + 4, row = row - 1, value='Количество ВМ на ВУ')
        ws.cell(column = col + 5, row = row - 1, value='Нода миграции')
        for rows in ws.iter_rows(min_row=row + 1, max_row=row + 1 , min_col=1, max_col=7):
            for cell in rows:
                cell.font = Font(italic=True) 
                cell.alignment= Alignment(horizontal='right')
        ws.cell(column=col, row=row).font = Font(name='Calibri', bold=True)
        for rows in ws.iter_rows(min_row=row , max_row=row, min_col=1, max_col=7):
            for cell in rows:
                  cell.fill = headersFill 
        ws.cell(column=col, row=row, value=i)
        ws.cell(column=col + 1, row=row, value=t[i]['az'])
        ws.cell(column=col + 2, row=row, value="{:10.2f}".format((t[i]['free_cpu']))).alignment = Alignment(horizontal='center')
        ws.cell(column=col + 3, row=row, value="{:10.2f}".format((t[i]['free_ram']))).alignment = Alignment(horizontal='center')
        ws.cell(column=col + 4, row=row, value=t[i]['vm_count'])
        ws.cell(column = col + 5, row = row , value=mig).alignment = Alignment(horizontal='center')
       # ws.cell(column=col + 5, row=row, value=t[i]['vm_critical']) 
       # ws.cell(column=col + 6, row=row, value=t[i]['vm_warning']) 
        row = row + 1
        for rows in ws.iter_rows(min_row=row, max_row=row, min_col=1, max_col=7):
            for cell in rows:
                cell.fill = vm_headersFill
                cell.alignment = Alignment(horizontal='center')
        ws.cell(column=col + 2, row=row, value='Имя ВМ').alignment = Alignment(horizontal='left')
        ws.cell(column=col + 3, row=row, value='vCPU')
        ws.cell(column=col + 4, row=row, value='RAM') 
        ws.cell(column=col + 5, row=row, value='Имя логической группы') 

        row = row + 1
        for j in t[i]['vms']:
            v = dUseVms[j]
            ws.cell(column=col + 2, row=row, value=v['name'])
            ws.cell(column=col + 3, row=row, value=v['cpu'])
            ws.cell(column=col + 4, row=row, value=v['ram']) 
            #if v['crit_rate'] == 2:
            #    crit = 1
            #elif v['crit_rate'] == 1:
            #    crit = 2
            #elif v['crit_rate'] == 0:
            #    crit = 'н/д'
            #ws.cell(column=col + 5, row=row, value=crit)
            #if v['crit_rate'] == 2:
            #    for rows in ws.iter_rows(min_row=row, max_row=row, min_col=3, max_col=7):
            #        for cell in rows:
            #              cell.fill = criticalFill
            #elif v['crit_rate'] == 1:
            #    for rows in ws.iter_rows(min_row=row, max_row=row, min_col=3, max_col=7):
            #        for cell in rows:
            #              cell.fill = warningFill

            ws.cell(column=col + 5, row=row, value=v['group']) 
            row = row + 1
        row = row + 2
    
    
    
    ###############################################
    ###############################################
    ###############################################
    
            
    ################################################   
    ################################################   JUST AZs (wo/migr) #############################
    ################################################
    for z in [1,2,3]:
        sh_name = 'ЗД '+ str(z)
        ws = wb.create_sheet(sh_name)
        row = 3
        col = 1
        for i in t.keys():
            migration = t[i]['migr']
            av_zone = t[i]['az']
            if migration:
                mig = 'Да'
                continue
            else:
                mig = 'Нет'
                #continue
            if av_zone != z:
                continue
            for rows in ws.iter_rows(min_row=row - 1, max_row=row - 1 , min_col=1, max_col=7):
                for cell in rows:
                    cell.font = Font(italic=True)
                    cell.alignment= Alignment(horizontal='center')
                    cell.fill = top_headersFill
            ws.cell(column = col, row = row - 1 , value='Имя ВУ').alignment= Alignment(horizontal='left')
            ws.cell(column = col + 1, row = row  - 1, value='Номер зоны доступности')
            ws.cell(column = col + 2, row = row - 1, value='Переподписка по CPU')
            ws.cell(column = col + 3, row = row - 1, value='Свободная RAM')
            ws.cell(column = col + 4, row = row - 1, value='Количество ВМ на ВУ')
            ws.cell(column = col + 5, row = row - 1, value='Нода миграции')
            for rows in ws.iter_rows(min_row=row + 1, max_row=row + 1 , min_col=1, max_col=7):
                for cell in rows:
                    cell.font = Font(italic=True) 
                    cell.alignment= Alignment(horizontal='right')
            ws.cell(column=col, row=row).font = Font(name='Calibri', bold=True)
            for rows in ws.iter_rows(min_row=row , max_row=row, min_col=1, max_col=7):
                for cell in rows:
                      cell.fill = headersFill 
            ws.cell(column=col, row=row, value=i)
            ws.cell(column=col + 1, row=row, value=t[i]['az'])
            ws.cell(column=col + 2, row=row, value="{:10.2f}".format((t[i]['free_cpu']))).alignment = Alignment(horizontal='center')
            ws.cell(column=col + 3, row=row, value="{:10.2f}".format((t[i]['free_ram']))).alignment = Alignment(horizontal='center')
            ws.cell(column=col + 4, row=row, value=t[i]['vm_count'])
            ws.cell(column = col + 5, row = row , value=mig).alignment = Alignment(horizontal='center')
            row = row + 1
            for rows in ws.iter_rows(min_row=row, max_row=row, min_col=1, max_col=7):
                for cell in rows:
                    cell.fill = vm_headersFill
                    cell.alignment = Alignment(horizontal='center')
            ws.cell(column=col + 2, row=row, value='Имя ВМ').alignment = Alignment(horizontal='left')
            ws.cell(column=col + 3, row=row, value='vCPU')
            ws.cell(column=col + 4, row=row, value='RAM') 
            ws.cell(column=col + 5, row=row, value='Имя логической группы') 

            row = row + 1
            for j in t[i]['vms']:
                v = dUseVms[j]
                ws.cell(column=col + 2, row=row, value=v['name'])
                ws.cell(column=col + 3, row=row, value=v['cpu'])
                ws.cell(column=col + 4, row=row, value=v['ram']) 
                ws.cell(column=col + 5, row=row, value=v['group']) 
                row = row + 1
            row = row + 2

    
    
    
    
    ###############################################
    ###############################################
    ###############################################
    
    
    ws = wb.create_sheet('Информация по ВУ')
    row = 3 
    col = 1
    for az in [1,2,3]:
        aCnList = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] == az]
        #####
        ##### Надо переделать нижнюю часть и ссылаться на уже сделанный лист гиперов, а не дергать каждый раз словарь
        #####
        tCn  = len([i for i in dUseHyper.keys() if dUseHyper[i]['az'] == az ])
        tFreeCpu = sum([dUseHyper[i]['free_cpu'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == az])
        tFreeRam = sum([dUseHyper[i]['free_ram'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == az])
        tTotalCpu = sum([dUseHyper[i]['total_cpu'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == az])
        tTotalRam = sum([dUseHyper[i]['total_ram'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == az])
        tPercFreeCpu = tFreeCpu/tTotalCpu
        tPercFreeRam = tFreeRam/tTotalRam
        tVm  = sum([dUseHyper[i]['vm_count'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == az])
        for rows in ws.iter_rows(min_row=row - 1, max_row=row - 1 , min_col=1, max_col=7):
            for cell in rows:
                cell.font = Font(italic=True)
                cell.alignment= Alignment(horizontal='center')
                cell.fill = top_headersFill
        for rows in ws.iter_rows(min_row=row, max_row=row , min_col=1, max_col=7):
            for cell in rows:
                cell.fill = headersFill
        ws.cell(column = col, row = row - 1 , value='Номер ЗД').alignment= Alignment(horizontal='left')
        ws.cell(column = col + 2, row = row - 1, value='Переподписка по CPU')
        ws.cell(column = col + 3, row = row - 1, value='Процент свободной RAM')
        ws.cell(column = col + 4, row = row - 1, value='Количество ВУ')
        ws.cell(column = col + 5, row = row - 1, value='Количество ВМ в зоне доступности')
        ws.cell(column = col, row = row , value=az).alignment= Alignment(horizontal='center')
        ws.cell(column = col + 2, row = row, value=tFreeCpu)
        ws.cell(column = col + 3, row = row, value=tPercFreeRam)
        ws.cell(column = col + 4, row = row, value=tCn)
        ws.cell(column = col + 5, row = row, value=tVm)
        row = row + 1
        for rows in ws.iter_rows(min_row=row, max_row=row, min_col=1, max_col=7):
            for cell in rows:
                cell.fill = vm_headersFill
                cell.alignment = Alignment(horizontal='center')
        ws.cell(column=col + 1, row=row, value='FQDN').alignment = Alignment(horizontal='left')       
        ws.cell(column=col + 2, row=row, value='Имя ВУ').alignment = Alignment(horizontal='left')
        ws.cell(column=col + 3, row=row, value='Переподписка по CPU')
        ws.cell(column=col + 4, row=row, value='Процент свободной RAM')
        ws.cell(column=col + 5, row=row, value='Количество свободной RAM')
        ws.cell(column=col + 6, row=row, value='Примечание') 
        for cn in aCnList:
            row = row + 1
            h = dUseHyper[cn]
            lName=h['label']
            lFreeCpu = h['free_cpu']
            lFreeRam = h['free_ram']
            lTotalCpu = h['total_cpu']
            lTotalRam = h['total_ram']
            lFreePercRam = lFreeRam/lTotalRam
            if h['migr']:
                lPrim='migr'
            else:
                lPrim=''
            ws.cell(column=col + 1, row=row, value=cn).alignment = Alignment(horizontal='left')
            ws.cell(column=col + 2, row=row, value=lName).alignment = Alignment(horizontal='left')
            ws.cell(column=col + 3, row=row, value=lFreeCpu)
            ws.cell(column=col + 4, row=row, value=lFreePercRam) 
            ws.cell(column=col + 5, row=row, value=lFreeRam) 
            ws.cell(column=col + 6, row=row, value=lPrim)
            #row = row + 1
        row = row + 3
    ws = wb.create_sheet('Список тестовых машин на удаление')
    row=2
    for rows in ws.iter_rows(min_row=row - 1, max_row=row - 1 , min_col=1, max_col=3):
        for cell in rows:
            cell.font = Font(italic=True)
            cell.alignment= Alignment(horizontal='center')
            cell.fill = top_headersFill
    ws.cell(column = 1, row = row - 1 , value='Имя ВМ').alignment= Alignment(horizontal='left')
    ws.cell(column = 2, row = row  - 1, value='RAM')
    ws.cell(column = 3, row = row - 1, value='vCPU')
    for v in test_machines:
        vn = dv[v]['name']
        vr = dv[v]['ram']
        vc = dv[v]['cpu']
        ws.cell(column=1, row=row, value=vn).alignment = Alignment(horizontal='left')
        ws.cell(column=2, row=row, value=vr).alignment = Alignment(horizontal='left')
        ws.cell(column=3, row=row, value=vc)
        row = row + 1
    
    #############################
    #############################
    #############################
    
    for w in wb.worksheets:
        _make_xls_width_sub(worksheet=w)
    
    
    
    
    wb.save(file)
    wb.close()

# %%
#make_xls()
#dUseHyper

# %%
### основные функции по созданию словарей

def create_dict_computes_clean(z1,z2,z3,cn,migr):
    rd={}
    for i in cn:
        hname = i[0]
        hlabel = i[1]
        #print(hlabel,hname)
        if hlabel in z1:
            hzone=int('1')
        elif hlabel in z2:
            hzone=int('2')
        elif hlabel in z3:
            hzone=int('3')
       
        if hlabel in migr:
            hmigr=True
        else: 
            hmigr=False
        
        rd[hname]={}
        rd[hname]['migr']=hmigr
        rd[hname]['label']=hlabel
        rd[hname]['az']=hzone
        rd[hname]['total_cpu']=dRealHyper[hname]['vcpus']
        rd[hname]['total_ram']=dRealHyper[hname]['memory_size']
        rd[hname]['free_cpu']=dRealHyper[hname]['vcpus']
        rd[hname]['free_ram']=dRealHyper[hname]['memory_size']
        rd[hname]['vms']=[]
        rd[hname]['vm_count']=len(rd[hname]['vms'])
        
    return rd
        
def create_dict_vm_with_groups(vdict,gdict):
    rd={}
    for v in vdict.keys():
        rd[v]={}
        rd[v]['cpu']=vdict[v]['cpu']
        rd[v]['name']=vdict[v]['name']
        rd[v]['ram']=vdict[v]['ram']
        rd[v]['cn']=vdict[v]['hypervisor_hostname']
        rd[v]['cn_new'] = ''
        rd[v]['group']=''
        if v in total_ms_list:
            rd[v]['group'] = 'master_slave'
        for g in gdict.keys():
            if v in gdict[g]['vms']:
                rd[v]['group'] = g
                continue
            
    return rd

def create_dict_groups_via_az(gdict):
    rd={}
    rd=copy.deepcopy(gdict)
    for g in gdict:
        rd[g]['az']={}
        rd[g]['az'][1] = int('0')
        rd[g]['az'][2] = int('0')
        rd[g]['az'][3] = int('0')
        rd[g]['az_even'] = ''
        rd[g]['az_odd'] = ''
        rd[g]['hypers']={}
        for h in dVirtualHyper.keys():
            rd[g]['hypers'][h]=0

    
    return rd

# %%
##
## Функции распределения и поиска пула доступных гипервизоров
##



###### Необходимо сделать - описать дистрибуцию уровня 2 и 1, дистрибуцию для остальных машин (тип 0). - СДЕЛАНО


def distributuion_init(gdict,vdict,hdict,vms_on_migr):
    global dUseGroups, dUseVms, dUseHyper
    dUseGroups = copy.deepcopy(gdict)
    dUseVms    = copy.deepcopy(vdict)
    dUseHyper  = copy.deepcopy(hdict)
    dl=[]
    for v in dVirtualVm.keys():
        vmname = v
        vram = dUseVms[v]['ram'] 
        if vmname in test_machines:
            continue
        if   dVirtualVm[v]['group'] == 'master_slave':
            vmtype = int('5')
        elif dVirtualHyper[dVirtualVm[v]['cn']]['label'] in lMigr:
            vmtype = int('7')
        elif dVirtualVm[v]['group'] != '':
            vmtype = dVirtualGroups[dVirtualVm[v]['group']]['type']
        else:
            vmtype= int('0')
        dl.append([vmname,vmtype, vram])
    logger.debug(sorted(dl, key = operator.itemgetter(1,2), reverse=True))
    
    #distribution(vl=sorted(dl, key = lambda x: float(x[1]), reverse=True)) ## Первый - высокий тип
    distribution(vl=sorted(dl, key = operator.itemgetter(1,2), reverse=True)) ## Первыми - высокий тип и жирные
    #distribution(vl=sorted(dl, key = operator.itemgetter(1,2), reverse=False)) ## Первыми - низкий типа и легкие
    
    
def distribution(vl):
    for v in vl:
        vmname = v[0]
        vmtype = v[1]
        vm_cn  = dUseVms[vmname]['cn']
        cn_ram_after_distrib = dUseHyper[vm_cn]['free_ram'] - dUseVms[vmname]['ram']
        perc_cn = cn_ram_after_distrib / dUseHyper[vm_cn]['total_ram']
        hyper_list=[]
        ####
        #### Если ВМ на ВУ миграции - оставляем на ВУ 
        ####
        if vmname in vms_on_migr:
            #print( dUseVms[vmname]['cn'])
            hname = dUseVms[vmname]['cn']
            count_after_distrib(h=hname,vm=vmname)
            continue
        if vmtype == 1:
            hyper_list = az_distribution(vmname)
        
        elif vmtype == 2:
            hyper_list = cn_distribution(vmname)
        
        elif vmtype == 3:
            hyper_list = even_distribution(vmname)
            
        elif vmtype == 4: 
            hyper_list = triple_distribution(vmname)
            
        elif vmtype == 5:
            hyper_list = master_slave_distribution(vmname)
            
        elif vmtype == 6:
            hyper_list = migr_prefix_distribution(vmname)
            
        elif vmtype == 0:
            hyper_list = null_type_distribution(vmname)
        #print(vmname,vmtype)
        #print(vmname, set([dUseHyper[i]['az'] for i in hyper_list]))
        #print(vmname,vmtype)
        if vm_cn in hyper_list and perc_cn > 0.05:
            hyper_list=[vm_cn]
        main_distributuion_function(hl=hyper_list,vm=vmname)
        
        
def count_after_distrib(h,vm):
    az = dUseHyper[h]['az']
    vm_group = dUseVms[vm]['group']
    if vm_group != '' and vm_group != 'master_slave':
        dUseGroups[vm_group]['az'][az] = dUseGroups[vm_group]['az'][az] + 1
        dUseGroups[vm_group]['hypers'][h] = dUseGroups[vm_group]['hypers'][h] + 1
    vm_cpu = dUseVms[vm]['cpu']
    vm_ram = dUseVms[vm]['ram']
    dUseHyper[h]['free_ram'] = dUseHyper[h]['free_ram'] - vm_ram
    dUseHyper[h]['free_cpu'] = dUseHyper[h]['free_cpu'] - vm_cpu
    dUseHyper[h]['vms'].append(vm)
    dUseHyper[h]['vm_count']=len(dUseHyper[h]['vms'])
    dUseVms[vm]['cn_new']=h
    pass


def main_distributuion_function(hl, vm):
    #print(vm)
    top_list=[]
    vm_group = dUseVms[vm]['group']
    for h in hl:
        if (vm_group !='master_slave' and dUseHyper[h]['migr'] and dUseGroups[vm_group]['type'] != 6):
            #print('ouch! migration')
            continue
        if h in reserve_list:
            continue
        pram = dUseHyper[h]['free_ram']/dUseHyper[h]['total_ram']
        pcpu = dUseHyper[h]['free_cpu']/dUseHyper[h]['total_cpu']
        res_score = (0.00001 * pcpu + 1 * pram)
        top_list.append([res_score,h])
    #if vm == 'pg-attribute-18':
    #    print (top_list, hl)
    #print(top_list[:1])
    print(vm_group,vm)
    if (vm_group !='master_slave' and vm_group !=''
        and dUseGroups[vm_group]['type'] == 6 ):
        #logger.debug(vm)
        #logger.debug(top_list)
        #print('OK')
        logger.debug(top_list)
    best_buddy = sorted(top_list, reverse=True)[:1][0][1]
   
    count_after_distrib(h=best_buddy,vm=vm)
    
    
def count_migrations(d):
    dv = copy.deepcopy(d)
    tl = [[i,dv[i]['cn'],dv[i]['cn_new']] for i in dv.keys() if (i not in test_machines)]
    otl = [[i,dv[i]['cn'],dv[i]['cn_new']] \
       for i in dv.keys() if (dUseVms[i]['cn_new'] ==  dv[i]['cn'] and i not in test_machines)]
    otl_vm = [i \
       for i in dv.keys() if (dUseVms[i]['cn_new'] ==  dv[i]['cn'] and i not in test_machines)]
    return len(tl) - len(otl)

# %%
#dUseHyper

# %%
#def keep_vm_migrate_on_its_host(vm):
#    rl = list(dUseVms[vm]['cn'])
#    return rl
#    pass

def migr_prefix_distribution(vm):
    rl = []
    #rl = [i for i in dUseHyper.keys() if dUseHyper[i]['migr'] and dUseHyper[i]['free_ram'] > 8192]
    for i in dUseHyper.keys():
        ram_left_after_ditribution = dUseHyper[i]['free_ram'] - dUseVms[vm]['ram']
        if dUseHyper[i]['migr'] and ram_left_after_ditribution > 8192:
            rl.append(i)
    if rl == []:
        rl = null_type_distribution(vm)
    return rl
    pass


def master_slave_distribution(vm):
    pair = [i for i in master_slave_list if vm in i ][0]
    #pair = [i for i in master_slave_list if vm in i ][0]
    pair_vm = [i for i in pair if i != vm][0]
    pair_cn = dUseVms[pair_vm]['cn_new']
    if pair_cn != '':
        rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] != dUseHyper[pair_cn]['az']]
    else:
        rl = [i for i in dUseHyper.keys()]
    return rl
    pass

def null_type_distribution(vm):
    if 'pg-attribute-standby' in vm:
        number = re.sub("\D", "", vm)
        vm_master = 'pg-attribute-' + number
        az_master = dUseHyper[dUseVms[vm_master]['cn_new']]['az']
        #print(vm,vm_master, az_master)
        rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] != az_master]
    else:
        logger.debug(vm)
#### Убери это в функцию !!! 
        alist=[]
        for a in [1,2,3]:
            memory_free=sum([dUseHyper[i]['free_ram'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == a and\
                    not dUseHyper[i]['migr']])
            memory_sum = sum([dUseHyper[i]['total_ram'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == a and\
                    not dUseHyper[i]['migr']])
            memory = memory_free / memory_sum
            alist.append([memory,a])
        logger.debug(alist)
        best_az = sorted(alist,reverse=True)[0][1]
        second_az = sorted(alist,reverse=True)[0][1]
        logger.debug(best_az)
        rl = [i for i in dUseHyper.keys() if not dUseHyper[i]['migr'] and dUseHyper[i]['az'] == best_az and\
             i not in reserve_list]
    logger.debug(rl)
    if rl == []:
        logger.debug('STOP')
    return rl
    pass

def az_distribution(vm):
    vm_group = dUseVms[vm]['group']
    azl = [dUseGroups[vm_group]['az'][i] for i in dUseGroups[vm_group]['az'].keys()]
    min_az = min(azl)
    min_az_list = [i for i in dUseGroups[vm_group]['az'].keys() if dUseGroups[vm_group]['az'][i] == min_az ]
    rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] in min_az_list]
    #print(vm,min_az,min_az_list)
    return rl
    
    pass

def cn_distribution(vm):
    vm_group = dUseVms[vm]['group']
    cnl = [dUseGroups[vm_group]['hypers'][i] for i in dUseGroups[vm_group]['hypers'].keys()\
          if not dUseHyper[i]['migr']]
    min_cnl = min(cnl)
    #print(min_cnl)
    ### УБЕРИ ЭТО БЛЯТЬ В ФУНКЦИЮ!!!!!! 
    '''
    alist=[]
    for a in [1,2,3]:
        memory_free=sum([dUseHyper[i]['free_ram'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == a and\
                not dUseHyper[i]['migr'] and i not in reserve_list])
        memory_sum = sum([dUseHyper[i]['total_ram'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == a and\
                not dUseHyper[i]['migr'] and i not in reserve_list])
        memory = memory_free / memory_sum
        alist.append([memory,a])
    logger.debug(alist)
    best_az = sorted(alist,reverse=True)[0][1]
    second_az = sorted(alist,reverse=True)[1][1]
    third_az = sorted(alist,reverse=True)[2][1]
    
    logger.debug(best_az)
        #rl = [i for i in dUseHyper.keys() if not dUseHyper[i]['migr'] and dUseHyper[i]['az'] == best_az]    
    rl = [i for i in dUseGroups[vm_group]['hypers'].keys() if not dUseHyper[i]['migr'] and\
          dUseGroups[vm_group]['hypers'][i] == min_cnl and i not in reserve_list and\
          dUseHyper[i]['az'] == best_az ]
    #print(rl)
    if rl == []:
        rl = [i for i in dUseGroups[vm_group]['hypers'].keys() if not dUseHyper[i]['migr'] and\
              dUseGroups[vm_group]['hypers'][i] == min_cnl and i not in reserve_list and\
          dUseHyper[i]['az'] == second_az] 
        #print('second',rl)
    if rl == []:
        rl = [i for i in dUseGroups[vm_group]['hypers'].keys() if not dUseHyper[i]['migr'] and\
              dUseGroups[vm_group]['hypers'][i] == min_cnl and i not in reserve_list and\
          dUseHyper[i]['az'] == third_az] 
        #print('third',rl)
    #print(rl)
    logger.debug(vm)
    logger.debug(rl)
    '''
    rl = [i for i in dUseGroups[vm_group]['hypers'].keys() if not dUseHyper[i]['migr'] and\
              dUseGroups[vm_group]['hypers'][i] == min_cnl and i not in reserve_list]
    if rl == []:
        rl = [i for i in dUseGroups[vm_group]['hypers'].keys() if not dUseHyper[i]['migr'] and\
              dUseGroups[vm_group]['hypers'][i] == min_cnl+1 and i not in reserve_list]    
    return rl
    pass


#### переделываем это гавно part1
'''
def even_distribution(vm):
    
    group = dUseVms[vm]['group']
    #ga1 = dUseGroups[group]['az1']
    #ga2 = dUseGroups[group]['az2']
    #ga3 = dUseGroups[group]['az3']
    if dUseGroups[group]['az_even'] == '':
        dUseGroups[group]['az_even'] = get_best_availability_zone(group=group)
    if dUseGroups[group]['az_odd'] == '':
        dUseGroups[group]['az_odd'] = get_best_availability_zone(group=group)
    odd_zone = dUseGroups[group]['az_odd']
    even_zone = dUseGroups[group]['az_even']
    stripped_name = vm.strip(group+'-')
    #print(group, )
    regexp = re.compile(r"\d\d-\d\d")
    if regexp.match(stripped_name):
        vmnumber_in_group = int(stripped_name.split('-')[1])
    else:
        vmnumber_in_group = int(stripped_name)
    #print(vm, vmnumber_in_group)
    if vmnumber_in_group % 2 == 0:
        az_to_land = even_zone
    else:
        az_to_land = odd_zone
    rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] == az_to_land]
    return rl

'''

def even_distribution(vm):
    
    group = dUseVms[vm]['group']
    stripped_name = vm.strip(group+'-')
    #ga1 = dUseGroups[group]['az1']
    #ga2 = dUseGroups[group]['az2']
    #ga3 = dUseGroups[group]['az3']
    big_az = 3
    even_az = dUseGroups[group]['az_even']
    odd_az =  dUseGroups[group]['az_odd']
    regexp = re.compile(r"\d\d-\d\d")
    if regexp.match(stripped_name):
        vmnumber_in_group = int(stripped_name.split('-')[1])
    else:
        vmnumber_in_group = int(stripped_name)
    print(vmnumber_in_group)    
    if (even_az == '' and odd_az == ''):
        target_az = big_az
        if vmnumber_in_group % 2 == 0:
            dUseGroups[group]['az_even'] = target_az
        else:
            dUseGroups[group]['az_odd'] = target_az
        rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] == target_az]
    elif (even_az == big_az):
        if vmnumber_in_group % 2 == 0:
            rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] == big_az] 
        else:
            rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] != big_az] 
    elif (odd_az == big_az):
        if vmnumber_in_group % 2 == 0:
            rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] != big_az] 
        else:
            rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] == big_az]
        
    #if dUseGroups[group]['az_even'] == '':
    #    dUseGroups[group]['az_even'] = get_best_availability_zone(group=group)
    #if dUseGroups[group]['az_odd'] == '':
    #    dUseGroups[group]['az_odd'] = get_best_availability_zone(group=group)
    #odd_zone = dUseGroups[group]['az_odd']
    #even_zone = dUseGroups[group]['az_even']
    #stripped_name = vm.strip(group+'-')
    #print(group, )
    #regexp = re.compile(r"\d\d-\d\d")
    #if regexp.match(stripped_name):
    #    vmnumber_in_group = int(stripped_name.split('-')[1])
    #else:
    #    vmnumber_in_group = int(stripped_name)
    #print(vm, vmnumber_in_group)
    #if vmnumber_in_group % 2 == 0:
    #    az_to_land = even_zone
    #else:
    #    az_to_land = odd_zone
    #rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] == az_to_land]
    return rl





def triple_distribution(vm):
    #print(vm, 'TRIPLE')
    group = dUseVms[vm]['group']
    #ga1 = dUseGroups[group]['az1']
    #ga2 = dUseGroups[group]['az2']
    #ga3 = dUseGroups[group]['az3']
    vmnumber_in_group = int(vm.strip(group+'-'))
    az_to_land = (vmnumber_in_group % 3) + 1
    rl = [i for i in dUseHyper.keys() if dUseHyper[i]['az'] == az_to_land]
    return rl



def get_best_availability_zone(group):
    azl = [i for i in [1,2,3] if i not in [dUseGroups[group]['az_odd'], dUseGroups[group]['az_even']]]
    alist=[]
    for a in azl:
        memory=sum([dUseHyper[i]['free_ram'] for i in dUseHyper.keys() if dUseHyper[i]['az'] == a and\
                    not dUseHyper[i]['migr']])
        alist.append([memory,a])
    #print(sorted(alist, reverse=True))
    az = sorted(alist, reverse=True)[:1][0][1]
    #print(az)
    return az

# %%
def count_all(dh,dv,dg):
    l = [dh[h]['free_ram']/dh[h]['total_ram']  for h in dh.keys() if h not in reserve_list]
    m = [dh[h]['free_cpu']/dh[h]['total_cpu']  for h in dh.keys() if h not in reserve_list]
    #m = [hpd_res[h]['perc_cpu'] for h in hpd_res.keys()]
    vml = sum([dh[h]['vm_count'] for h in dh.keys()])
    hpl = [i for i in dh.keys()]
    #print(hpl)
    print("Всего машин:", vml)
    #print("Необходимо машинам vCPU :" , vm_res_total_list[0], ", RAM :", vm_res_total_list[1], "MB" )
    #print("На одном ВУ CPU :", cpu_per_cn, ", RAM :", ram_per_cn, "MB")
    print("Всего ВУ:", len(hpl))
    #print("Суммарно на ВУ :" , hyper_res_total_list[0], ", RAM :", hyper_res_total_list[1], "MB" )
    #print("Суммарная подписка по CPU :", over_total_list[0], ", RAM :", over_total_list[1])

    print("Забитость ВУ по RAM")
    print("Самый забитый :", 1-min(l))
    print("Наименее забитый :", 1-max(l))
    print("Средняя загруженность :",  1 - sum(l)/len(l))
    print("Среднедратичное отклонение по ВУ :",  np.std(l))
    print('')
    print("Перерасход vCPU относительно CPU ВУ ")
    print("Самый забитый :", 1-min(m))
    print("Наименее забитый :", 1-max(m))
    print("Средняя загруженность :", 1 - sum(m)/len(m))

# %%
#dUseHyper

# %%
#dRealHyper['cn-d720.egron.tnx']['memory_size']

# %%
###
### создаем виртуальную среду на основе базовых словарей
###
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

dVirtualHyper = create_dict_computes_clean(z1=lAZ1,z2=lAZ2,z3=lAZ3,migr=lMigr,cn=lCN)
dVirtualVm = create_dict_vm_with_groups(vdict=dRealVm,gdict=dGroups)
dVirtualGroups = create_dict_groups_via_az(gdict=dGroups)
ml = [i for i in dVirtualHyper.keys() if dVirtualHyper[i]['migr'] == True]
vms_on_migr = [i for j in ml for i in dVirtualVm.keys() if dVirtualVm[i]['cn'] == j]

# %%
#len([i for i in dVirtualVm.keys() if dVirtualVm[i]['group'] == 'master_slave'])

# %%
distributuion_init(gdict=dVirtualGroups,vdict=dVirtualVm,hdict=dVirtualHyper,vms_on_migr=vms_on_migr)
# Out:
# migr-gkn-oracle migr-gkn-oracle-24-err
# migr-filestore migr-filestore-02
# migr-log migr-log-01
# migr-grp-oracle migr-grp-oracle-24
# migr-gkn-oracle migr-gkn-oracle-24
# migr-arc migr-arc-67
# migr-arc migr-arc-64
# migr-arc migr-arc-60
# migr-arc migr-arc-57
# migr-arc migr-arc-46
# migr-arc migr-arc-40
# migr-arc migr-arc-36
# migr-arc migr-arc-34
# migr-arc migr-arc-31
# migr-node migr-node-140
# migr-node migr-node-131
# migr-node migr-node-112
# migr-node migr-node-110
# migr-node migr-node-106
# migr-node migr-node-105
# migr-node migr-node-104
# migr-node migr-node-076
# migr-gkn-oracle migr-gkn-oracle-61
# migr-arc migr-arc-85
# migr-arc migr-arc-80
# migr-arc migr-arc-81
# migr-arc migr-arc-77
# migr-arc migr-arc-82
# migr-gkn-oracle migr-gkn-oracle-85
# migr-gkn-oracle migr-gkn-oracle-82
# migr-gkn-oracle migr-gkn-oracle-81
# migr-gkn-oracle migr-gkn-oracle-50
# migr-arc migr-arc-74
# migr-arc migr-arc-43
# migr-gkn-oracle migr-gkn-oracle-80
# migr-gkn-oracle migr-gkn-oracle-74
# migr-gkn-oracle migr-gkn-oracle-43
# migr-arc migr-arc-86
# migr-arc migr-arc-49
# migr-arc migr-arc-12
# migr-node migr-node-060
# migr-node migr-node-059
# migr-node migr-node-058
# migr-node migr-node-057
# migr-node migr-node-056
# migr-node migr-node-055
# migr-node migr-node-054
# migr-node migr-node-053
# migr-node migr-node-052
# migr-node migr-node-051
# migr-node migr-node-050
# migr-node migr-node-049
# migr-node migr-node-048
# migr-node migr-node-047
# migr-node migr-node-046
# migr-node migr-node-045
# migr-node migr-node-044
# migr-node migr-node-043
# migr-node migr-node-042
# migr-node migr-node-041
# migr-node migr-node-040
# migr-node migr-node-039
# migr-node migr-node-038
# migr-node migr-node-037
# migr-node migr-node-036
# migr-node migr-node-035
# migr-node migr-node-034
# migr-node migr-node-033
# migr-node migr-node-032
# migr-node migr-node-031
# migr-node migr-node-030
# migr-node migr-node-029
# migr-node migr-node-028
# migr-node migr-node-027
# migr-node migr-node-026
# migr-node migr-node-025
# migr-node migr-node-024
# migr-node migr-node-023
# migr-node migr-node-022
# migr-node migr-node-021
# migr-node migr-node-020
# migr-node migr-node-018
# migr-node migr-node-015
# migr-node migr-node-014
# migr-node migr-node-013
# migr-node migr-node-012
# migr-node migr-node-011
# migr-node migr-node-010
# migr-node migr-node-009
# migr-node migr-node-008
# migr-node migr-node-007
# migr-node migr-node-006
# migr-node migr-node-005
# migr-node migr-node-004
# migr-node migr-node-003
# migr-node migr-node-002
# migr-node migr-node-001
# migr-arc migr-arc-91
# migr-arc migr-arc-90
# migr-arc migr-arc-89
# migr-arc migr-arc-88
# migr-arc migr-arc-87
# migr-arc migr-arc-84
# migr-arc migr-arc-83
# migr-arc migr-arc-79
# migr-arc migr-arc-78
# migr-arc migr-arc-75
# migr-arc migr-arc-73
# migr-arc migr-arc-72
# migr-arc migr-arc-70
# migr-arc migr-arc-68
# migr-arc migr-arc-66
# migr-arc migr-arc-65
# migr-arc migr-arc-63
# migr-arc migr-arc-62
# migr-arc migr-arc-59
# migr-arc migr-arc-58
# migr-arc migr-arc-56
# migr-arc migr-arc-55
# migr-arc migr-arc-54
# migr-arc migr-arc-53
# migr-arc migr-arc-52
# migr-arc migr-arc-51
# migr-arc migr-arc-47
# migr-arc migr-arc-45
# migr-arc migr-arc-44
# migr-arc migr-arc-42
# migr-arc migr-arc-41
# migr-arc migr-arc-39
# migr-arc migr-arc-38
# migr-arc migr-arc-35
# migr-arc migr-arc-29
# migr-arc migr-arc-28
# migr-arc migr-arc-27
# migr-arc migr-arc-26
# migr-arc migr-arc-25
# migr-arc migr-arc-24
# migr-arc migr-arc-23
# migr-arc migr-arc-22
# migr-arc migr-arc-21
# migr-arc migr-arc-20
# migr-arc migr-arc-19
# migr-arc migr-arc-18
# migr-arc migr-arc-17
# migr-arc migr-arc-16
# migr-arc migr-arc-15
# migr-arc migr-arc-14
# migr-arc migr-arc-13
# migr-arc migr-arc-11
# migr-arc migr-arc-10
# migr-gkn-oracle migr-gkn-oracle-77
# migr-gkn-oracle migr-gkn-oracle-91
# migr-gkn-oracle migr-gkn-oracle-90
# migr-gkn-oracle migr-gkn-oracle-89
# migr-gkn-oracle migr-gkn-oracle-88
# migr-gkn-oracle migr-gkn-oracle-87
# migr-gkn-oracle migr-gkn-oracle-86
# migr-gkn-oracle migr-gkn-oracle-84
# migr-gkn-oracle migr-gkn-oracle-79
# migr-gkn-oracle migr-gkn-oracle-72
# migr-gkn-oracle migr-gkn-oracle-70
# migr-gkn-oracle migr-gkn-oracle-78
# migr-gkn-oracle migr-gkn-oracle-75
# migr-gkn-oracle migr-gkn-oracle-73
# migr-gkn-oracle migr-gkn-oracle-68
# migr-gkn-oracle migr-gkn-oracle-66
# migr-gkn-oracle migr-gkn-oracle-65
# migr-gkn-oracle migr-gkn-oracle-63
# migr-gkn-oracle migr-gkn-oracle-62
# migr-gkn-oracle migr-gkn-oracle-59
# migr-gkn-oracle migr-gkn-oracle-58
# migr-gkn-oracle migr-gkn-oracle-56
# migr-gkn-oracle migr-gkn-oracle-55
# migr-gkn-oracle migr-gkn-oracle-54
# migr-gkn-oracle migr-gkn-oracle-53
# migr-gkn-oracle migr-gkn-oracle-51
# migr-gkn-oracle migr-gkn-oracle-49
# migr-gkn-oracle migr-gkn-oracle-47
# migr-gkn-oracle migr-gkn-oracle-45
# migr-gkn-oracle migr-gkn-oracle-44
# migr-gkn-oracle migr-gkn-oracle-42
# migr-gkn-oracle migr-gkn-oracle-41
# migr-gkn-oracle migr-gkn-oracle-39
# migr-gkn-oracle migr-gkn-oracle-38
# migr-gkn-oracle migr-gkn-oracle-35
# migr-gkn-oracle migr-gkn-oracle-29
# migr-gkn-oracle migr-gkn-oracle-28
# migr-gkn-oracle migr-gkn-oracle-27
# migr-gkn-oracle migr-gkn-oracle-26
# migr-gkn-oracle migr-gkn-oracle-25
# migr-gkn-oracle migr-gkn-oracle-23
# migr-gkn-oracle migr-gkn-oracle-22
# migr-gkn-oracle migr-gkn-oracle-21
# migr-gkn-oracle migr-gkn-oracle-20
# migr-gkn-oracle migr-gkn-oracle-18
# migr-gkn-oracle migr-gkn-oracle-17
# migr-gkn-oracle migr-gkn-oracle-16
# migr-gkn-oracle migr-gkn-oracle-15
# migr-gkn-oracle migr-gkn-oracle-14
# migr-gkn-oracle migr-gkn-oracle-13
# migr-gkn-oracle migr-gkn-oracle-12
# migr-gkn-oracle migr-gkn-oracle-11
# migr-gkn-oracle migr-gkn-oracle-10
# migr-grp-oracle migr-grp-oracle-26
# migr-grp-oracle migr-grp-oracle-23
# migr-grp-oracle migr-grp-oracle-57
# migr-grp-oracle migr-grp-oracle-76
# migr-jst-oracle migr-jst-oracle-61
# migr-jst-oracle migr-jst-oracle-46
# migr-grp-oracle migr-grp-oracle-36
# migr-jst-oracle migr-jst-oracle-34
# migr-jst-oracle migr-jst-oracle-74
# migr-grp-oracle migr-grp-oracle-71
# migr-gkn-oracle migr-gkn-oracle-71
# migr-grp-oracle migr-grp-oracle-69
# migr-grp-oracle migr-grp-oracle-64
# migr-gkn-oracle migr-gkn-oracle-57
# migr-jst-oracle migr-jst-oracle-48
# migr-gkn-oracle migr-gkn-oracle-48
# migr-gkn-oracle migr-gkn-oracle-46
# migr-grp-oracle migr-grp-oracle-40
# migr-gkn-oracle migr-gkn-oracle-40
# migr-gkn-oracle migr-gkn-oracle-37
# migr-grp-oracle migr-grp-oracle-37
# migr-gkn-oracle migr-gkn-oracle-36
# migr-gkn-oracle migr-gkn-oracle-34
# migr-grp-oracle migr-grp-oracle-33
# migr-gkn-oracle migr-gkn-oracle-33
# migr-grp-oracle migr-grp-oracle-32
# migr-gkn-oracle migr-gkn-oracle-32
# migr-jst-oracle migr-jst-oracle-31
# migr-gkn-oracle migr-gkn-oracle-31
# migr-jst-oracle migr-jst-oracle-30
# migr-gkn-oracle migr-gkn-oracle-30
# migr-jst-oracle migr-jst-oracle-08
# migr-gkn-oracle migr-gkn-oracle-01
# migr-jst-oracle migr-jst-oracle-01
# migr-conf-bkp migr-conf-bkp-01
# migr-grp-oracle migr-grp-oracle-82
# migr-grp-oracle migr-grp-oracle-80
# migr-grp-oracle migr-grp-oracle-50
# migr-grp-oracle migr-grp-oracle-85
# migr-grp-oracle migr-grp-oracle-81
# migr-grp-oracle migr-grp-oracle-74
# migr-grp-oracle migr-grp-oracle-43
# migr-filestore migr-filestore-01
# migr-jst-oracle migr-jst-oracle-20
# migr-jst-oracle migr-jst-oracle-19
# migr-jst-oracle migr-jst-oracle-18
# migr-jst-oracle migr-jst-oracle-17
# migr-jst-oracle migr-jst-oracle-16
# migr-jst-oracle migr-jst-oracle-15
# migr-jst-oracle migr-jst-oracle-14
# migr-jst-oracle migr-jst-oracle-13
# migr-jst-oracle migr-jst-oracle-12
# migr-jst-oracle migr-jst-oracle-11
# migr-jst-oracle migr-jst-oracle-10
# migr-grp-oracle migr-grp-oracle-77
# migr-grp-oracle migr-grp-oracle-91
# migr-grp-oracle migr-grp-oracle-90
# migr-grp-oracle migr-grp-oracle-89
# migr-grp-oracle migr-grp-oracle-87
# migr-grp-oracle migr-grp-oracle-86
# migr-grp-oracle migr-grp-oracle-83
# migr-grp-oracle migr-grp-oracle-79
# migr-grp-oracle migr-grp-oracle-78
# migr-grp-oracle migr-grp-oracle-75
# migr-grp-oracle migr-grp-oracle-73
# migr-grp-oracle migr-grp-oracle-70
# migr-grp-oracle migr-grp-oracle-68
# migr-grp-oracle migr-grp-oracle-66
# migr-grp-oracle migr-grp-oracle-65
# migr-grp-oracle migr-grp-oracle-63
# migr-grp-oracle migr-grp-oracle-62
# migr-grp-oracle migr-grp-oracle-59
# migr-grp-oracle migr-grp-oracle-58
# migr-grp-oracle migr-grp-oracle-55
# migr-grp-oracle migr-grp-oracle-54
# migr-grp-oracle migr-grp-oracle-53
# migr-grp-oracle migr-grp-oracle-52
# migr-grp-oracle migr-grp-oracle-51
# migr-grp-oracle migr-grp-oracle-49
# migr-grp-oracle migr-grp-oracle-47
# migr-grp-oracle migr-grp-oracle-45
# migr-grp-oracle migr-grp-oracle-44
# migr-grp-oracle migr-grp-oracle-42
# migr-grp-oracle migr-grp-oracle-41
# migr-grp-oracle migr-grp-oracle-35
# migr-grp-oracle migr-grp-oracle-29
# migr-grp-oracle migr-grp-oracle-28
# migr-grp-oracle migr-grp-oracle-27
# migr-grp-oracle migr-grp-oracle-25
# migr-grp-oracle migr-grp-oracle-22
# migr-grp-oracle migr-grp-oracle-21
# migr-init-bkp migr-init-bkp-01
# migr-oracle-replicastore migr-oracle-replicastore-01
# migr-init-snap migr-init-snap-01
# master_slave pg-attribute-right-registry-entities
# master_slave pg-master-replica-standby-01
# master_slave pg-attribute-standby-right-registry-entities
# master_slave pg-reservation-01-standby
# master_slave pg-attribute-standby-borders
# master_slave pg-attribute-standby-books
# master_slave pg-attribute-borders
# master_slave pg-attribute-books
# master_slave pg-master
# master_slave pg-master-replica-01
# master_slave pg-reservation-01
# master_slave pg-master-standby
# migr-init migr-init-04
# migr-init migr-init-01
# ppoz-db-fs-bkp ppoz-db-fs-bkp-10
# ppoz-db-fs-bkp ppoz-db-fs-bkp-09
# ppoz-db-fs-bkp ppoz-db-fs-bkp-08
# ppoz-db-fs-bkp ppoz-db-fs-bkp-07
# ppoz-db-fs-bkp ppoz-db-fs-bkp-06
# ppoz-db-fs-bkp ppoz-db-fs-bkp-05
# ppoz-db-fs-bkp ppoz-db-fs-bkp-04
# ppoz-db-fs-bkp ppoz-db-fs-bkp-03
# ppoz-db-fs-bkp ppoz-db-fs-bkp-02
# ppoz-db-fs-bkp ppoz-db-fs-bkp-01
# ppoz-db-fs ppoz-db-fs-30
# ppoz-db-fs ppoz-db-fs-29
# ppoz-db-fs ppoz-db-fs-28
# ppoz-db-fs ppoz-db-fs-27
# ppoz-db-fs ppoz-db-fs-26
# ppoz-db-fs ppoz-db-fs-25
# ppoz-db-fs ppoz-db-fs-24
# ppoz-db-fs ppoz-db-fs-23
# ppoz-db-fs ppoz-db-fs-22
# ppoz-db-fs ppoz-db-fs-21
# ppoz-db-fs ppoz-db-fs-20
# ppoz-db-fs ppoz-db-fs-19
# ppoz-db-fs ppoz-db-fs-18
# ppoz-db-fs ppoz-db-fs-17
# ppoz-db-fs ppoz-db-fs-16
# ppoz-db-fs ppoz-db-fs-15
# ppoz-db-fs ppoz-db-fs-14
# ppoz-db-fs ppoz-db-fs-13
# ppoz-db-fs ppoz-db-fs-12
# ppoz-db-fs ppoz-db-fs-11
# ppoz-db-fs ppoz-db-fs-10
# ppoz-db-fs ppoz-db-fs-09
# ppoz-db-fs ppoz-db-fs-08
# ppoz-db-fs ppoz-db-fs-07
# ppoz-db-fs ppoz-db-fs-06
# ppoz-db-fs ppoz-db-fs-05
# ppoz-db-fs ppoz-db-fs-04
# ppoz-db-fs ppoz-db-fs-03
# ppoz-db-fs ppoz-db-fs-02
# ppoz-db-fs ppoz-db-fs-01
# ppoz-db-request ppoz-db-request-30
# ppoz-db-request ppoz-db-request-29
# ppoz-db-request ppoz-db-request-28
# ppoz-db-request ppoz-db-request-27
# ppoz-db-request ppoz-db-request-26
# ppoz-db-request ppoz-db-request-25
# ppoz-db-request ppoz-db-request-24
# ppoz-db-request ppoz-db-request-23
# ppoz-db-request ppoz-db-request-22
# ppoz-db-request ppoz-db-request-21
# ppoz-db-request ppoz-db-request-20
# ppoz-db-request ppoz-db-request-19
# ppoz-db-request ppoz-db-request-18
# ppoz-db-request ppoz-db-request-17
# ppoz-db-request ppoz-db-request-16
# ppoz-db-request ppoz-db-request-15
# ppoz-db-request ppoz-db-request-14
# ppoz-db-request ppoz-db-request-13
# ppoz-db-request ppoz-db-request-12
# ppoz-db-request ppoz-db-request-11
# ppoz-db-request ppoz-db-request-10
# ppoz-db-request ppoz-db-request-09
# ppoz-db-request ppoz-db-request-08
# ppoz-db-request ppoz-db-request-07
# ppoz-kuvd-db ppoz-kuvd-db-21
# ppoz-kuvd-db ppoz-kuvd-db-20
# ppoz-kuvd-db ppoz-kuvd-db-19
# ppoz-kuvd-db ppoz-kuvd-db-18
# ppoz-kuvd-db ppoz-kuvd-db-17
# ppoz-kuvd-db ppoz-kuvd-db-16
# ppoz-kuvd-db ppoz-kuvd-db-15
# ppoz-kuvd-db ppoz-kuvd-db-14
# ppoz-kuvd-db ppoz-kuvd-db-13
# ppoz-kuvd-db ppoz-kuvd-db-12
# ppoz-kuvd-db ppoz-kuvd-db-11
# ppoz-kuvd-db ppoz-kuvd-db-10
# ppoz-kuvd-db ppoz-kuvd-db-09
# ppoz-kuvd-db ppoz-kuvd-db-08
# ppoz-kuvd-db ppoz-kuvd-db-07
# ppoz-db-request ppoz-db-request-06
# ppoz-db-request ppoz-db-request-05
# ppoz-db-request ppoz-db-request-04
# migr-init migr-init-02
# ppoz-kuvd-db ppoz-kuvd-db-06
# ppoz-kuvd-db ppoz-kuvd-db-05
# ppoz-kuvd-db ppoz-kuvd-db-04
# ppoz-kuvd-db ppoz-kuvd-db-03
# ppoz-kuvd-db ppoz-kuvd-db-02
# ppoz-kuvd-db ppoz-kuvd-db-01
# ppoz-db-request ppoz-db-request-03
# ppoz-db-request ppoz-db-request-02
# ppoz-db-request ppoz-db-request-01
# ppoz-kuvd-db-bkp ppoz-kuvd-db-bkp-01
# ppoz-db-request-bkp ppoz-db-request-bkp-09
# ppoz-db-request-bkp ppoz-db-request-bkp-02
# ppoz-db-request-bkp ppoz-db-request-bkp-10
# ppoz-db-request-bkp ppoz-db-request-bkp-11
# ppoz-db-request-bkp ppoz-db-request-bkp-08
# ppoz-db-request-bkp ppoz-db-request-bkp-07
# ppoz-db-request-bkp ppoz-db-request-bkp-06
# ppoz-db-request-bkp ppoz-db-request-bkp-05
# ppoz-db-request-bkp ppoz-db-request-bkp-04
# ppoz-db-request-bkp ppoz-db-request-bkp-03
# ppoz-db-request-bkp ppoz-db-request-bkp-01
# ppoz-kuvd-db-bkp ppoz-kuvd-db-bkp-08
# ppoz-kuvd-db-bkp ppoz-kuvd-db-bkp-07
# ppoz-kuvd-db-bkp ppoz-kuvd-db-bkp-06
# ppoz-kuvd-db-bkp ppoz-kuvd-db-bkp-05
# ppoz-kuvd-db-bkp ppoz-kuvd-db-bkp-04
# ppoz-kuvd-db-bkp ppoz-kuvd-db-bkp-03
# ppoz-kuvd-db-bkp ppoz-kuvd-db-bkp-02
# cia-db cia-db-03
# site-db site-db-04
# site-db site-db-03
# site-db site-db-02
# site-db site-db-01
# cia-db cia-db-02
# cia-db cia-db-01
# pkurp-app pkurp-app-039
# pkurp-app pkurp-app-038
# pkurp-app pkurp-app-037
# pkurp-app pkurp-app-036
# pkurp-app pkurp-app-035
# pkurp-app pkurp-app-034
# pkurp-app pkurp-app-033
# pkurp-app pkurp-app-032
# pkurp-app pkurp-app-031
# pkurp-app pkurp-app-030
# pkurp-app pkurp-app-029
# pkurp-app pkurp-app-028
# pkurp-app pkurp-app-027
# pkurp-app pkurp-app-026
# pkurp-app pkurp-app-025
# pkurp-app pkurp-app-024
# pkurp-app pkurp-app-023
# pkurp-app pkurp-app-022
# pkurp-app pkurp-app-021
# pkurp-app pkurp-app-016
# pkurp-app pkurp-app-015
# pkurp-app pkurp-app-014
# pkurp-app pkurp-app-013
# pkurp-app pkurp-app-012
# pkurp-app pkurp-app-011
# pmuf-stat-db pmuf-stat-db-02
# pkurp-app pkurp-app-010
# pkurp-app pkurp-app-009
# pkurp-app pkurp-app-008
# pkurp-app pkurp-app-007
# pkurp-app pkurp-app-006
# pkurp-app pkurp-app-005
# pkurp-app pkurp-app-020
# pkurp-app pkurp-app-019
# pkurp-app pkurp-app-018
# pkurp-app pkurp-app-017
# pmuf-stat-db pmuf-stat-db-01
# pkurp-app pkurp-app-004
# pkurp-app pkurp-app-003
# pkurp-app pkurp-app-002
# pkurp-app pkurp-app-001
# 1
# ir-bd ir-bd-01
# 1
# popd-bpd popd-bpd-01
# 1
# ir-bd ir-bd-01-01
# 2
# ir-bd ir-bd-01-02
# 4
# ir-bd ir-bd-04
# 3
# ir-bd ir-bd-03
# 2
# ir-bd ir-bd-02
# 4
# popd-bpd popd-bpd-04
# 3
# popd-bpd popd-bpd-03
# 2
# popd-bpd popd-bpd-02
# 8
# ir-bd ir-bd-08
# 7
# ir-bd ir-bd-07
# 6
# ir-bd ir-bd-06
# 5
# ir-bd ir-bd-05
# 7
# ppoz-db-proc-popd ppoz-db-proc-popd-07
# 7
# ppoz-db-proc-gmp ppoz-db-proc-gmp-07
# 7
# ppoz-db-proc-pkurp ppoz-db-proc-pkurp-07
# 7
# ppoz-db-proc-ppoz ppoz-db-proc-ppoz-07
# 2
# pmuf-db pmuf-db-02
# 6
# ppoz-db-proc-ppoz ppoz-db-proc-ppoz-06
# 5
# ppoz-db-proc-ppoz ppoz-db-proc-ppoz-05
# 4
# ppoz-db-proc-ppoz ppoz-db-proc-ppoz-04
# 3
# ppoz-db-proc-ppoz ppoz-db-proc-ppoz-03
# 6
# ppoz-db-proc-popd ppoz-db-proc-popd-06
# 5
# ppoz-db-proc-popd ppoz-db-proc-popd-05
# 4
# ppoz-db-proc-popd ppoz-db-proc-popd-04
# 3
# ppoz-db-proc-popd ppoz-db-proc-popd-03
# 6
# ppoz-db-proc-pkurp ppoz-db-proc-pkurp-06
# 5
# ppoz-db-proc-pkurp ppoz-db-proc-pkurp-05
# 4
# ppoz-db-proc-pkurp ppoz-db-proc-pkurp-04
# 3
# ppoz-db-proc-pkurp ppoz-db-proc-pkurp-03
# 6
# ppoz-db-proc-gmp ppoz-db-proc-gmp-06
# 5
# ppoz-db-proc-gmp ppoz-db-proc-gmp-05
# 4
# ppoz-db-proc-gmp ppoz-db-proc-gmp-04
# 3
# ppoz-db-proc-gmp ppoz-db-proc-gmp-03
# 2
# ppoz-db-proc-ppoz ppoz-db-proc-ppoz-02
# 1
# ppoz-db-proc-ppoz ppoz-db-proc-ppoz-01
# 2
# ppoz-db-proc-popd ppoz-db-proc-popd-02
# 1
# ppoz-db-proc-popd ppoz-db-proc-popd-01
# 2
# ppoz-db-proc-pkurp ppoz-db-proc-pkurp-02
# 1
# ppoz-db-proc-pkurp ppoz-db-proc-pkurp-01
# 2
# ppoz-db-proc-gmp ppoz-db-proc-gmp-02
# 1
# ppoz-db-proc-gmp ppoz-db-proc-gmp-01
# 1
# pmuf-db pmuf-db-01
# 2
# pmuf-zabbix-db pmuf-zabbix-db-02
# 1
# pmuf-zabbix-db pmuf-zabbix-db-01
# 5
# ppoz-popd-process ppoz-popd-process-05
# 6
# isurz-mq isurz-mq-06
# 5
# isurz-mq isurz-mq-05
# 4
# isurz-mq isurz-mq-04
# 3
# isurz-mq isurz-mq-03
# 2
# isurz-mq isurz-mq-02
# 1
# isurz-mq isurz-mq-01
# 6
# popd-bpd popd-bpd-06
# 5
# popd-bpd popd-bpd-05
# 4
# ppoz-bus-ext ppoz-bus-ext-04
# 3
# ppoz-bus-ext ppoz-bus-ext-03
# 4
# ppoz-bus-data ppoz-bus-data-04
# 3
# ppoz-bus-data ppoz-bus-data-03
# 4
# ppoz-bus-command ppoz-bus-command-04
# 3
# ppoz-bus-command ppoz-bus-command-03
# 6
# ppoz-gmp-process ppoz-gmp-process-06
# 5
# ppoz-gmp-process ppoz-gmp-process-05
# 4
# ppoz-gmp-process ppoz-gmp-process-04
# 3
# ppoz-gmp-process ppoz-gmp-process-03
# 6
# ppoz-process-core ppoz-process-core-06
# 5
# ppoz-process-core ppoz-process-core-05
# 4
# ppoz-process-core ppoz-process-core-04
# 3
# ppoz-process-core ppoz-process-core-03
# 6
# ppoz-popd-process ppoz-popd-process-06
# 4
# ppoz-popd-process ppoz-popd-process-04
# 3
# ppoz-popd-process ppoz-popd-process-03
# 6
# ppoz-pkurp-process ppoz-pkurp-process-06
# 5
# ppoz-pkurp-process ppoz-pkurp-process-05
# 4
# ppoz-pkurp-process ppoz-pkurp-process-04
# 3
# ppoz-pkurp-process ppoz-pkurp-process-03
# 2
# ppoz-process-core ppoz-process-core-02
# 1
# ppoz-process-core ppoz-process-core-01
# 2
# ppoz-popd-process ppoz-popd-process-02
# 1
# ppoz-popd-process ppoz-popd-process-01
# 2
# ppoz-pkurp-process ppoz-pkurp-process-02
# 1
# ppoz-pkurp-process ppoz-pkurp-process-01
# 2
# ppoz-gmp-process ppoz-gmp-process-02
# 1
# ppoz-gmp-process ppoz-gmp-process-01
# 2
# ppoz-bus-ext ppoz-bus-ext-02
# 1
# ppoz-bus-ext ppoz-bus-ext-01
# 2
# ppoz-bus-data ppoz-bus-data-02
# 1
# ppoz-bus-data ppoz-bus-data-01
# 2
# ppoz-bus-command ppoz-bus-command-02
# 1
# ppoz-bus-command ppoz-bus-command-01
# 8
# popd-bpd popd-bpd-08
# 7
# popd-bpd popd-bpd-07
# pg-attribute pg-attribute-07
# pg-attribute pg-attribute-07_orphan
# isurz-xml-storage isurz-xml-storage-82
# isurz-xml-storage isurz-xml-storage-80
# pg-attribute pg-attribute-82
# pg-attribute pg-attribute-80
# pg-attribute pg-attribute-19
# pg-attribute pg-attribute-27
# pg-attribute pg-attribute-85
# pg-attribute pg-attribute-83
# pg-attribute pg-attribute-77
# pg-attribute pg-attribute-75
# pg-attribute pg-attribute-74
# pg-attribute pg-attribute-70
# pg-attribute pg-attribute-66
# pg-attribute pg-attribute-65
# pg-attribute pg-attribute-63
# pg-attribute pg-attribute-62
# pg-attribute pg-attribute-59
# pg-attribute pg-attribute-53
# pg-attribute pg-attribute-50
# pg-attribute pg-attribute-49
# pg-attribute pg-attribute-47
# pg-attribute pg-attribute-45
# pg-attribute pg-attribute-44
# pg-attribute pg-attribute-35
# pg-attribute pg-attribute-29
# pg-attribute pg-attribute-28
# pg-attribute pg-attribute-26
# pg-attribute pg-attribute-25
# pg-attribute pg-attribute-24
# pg-attribute pg-attribute-17
# pg-attribute pg-attribute-16
# pg-attribute pg-attribute-12
# pg-attribute pg-attribute-11
# pg-attribute pg-attribute-10
# pg-attribute pg-attribute-06
# pg-attribute pg-attribute-05
# pg-attribute pg-attribute-02
# pg-attribute pg-attribute-91
# pg-attribute pg-attribute-90
# pg-attribute pg-attribute-89
# pg-attribute pg-attribute-88
# pg-attribute pg-attribute-87
# pg-attribute pg-attribute-86
# pg-attribute pg-attribute-84
# pg-attribute pg-attribute-81
# pg-attribute pg-attribute-79
# pg-attribute pg-attribute-78
# pg-attribute pg-attribute-73
# pg-attribute pg-attribute-72
# pg-attribute pg-attribute-68
# pg-attribute pg-attribute-58
# pg-attribute pg-attribute-56
# pg-attribute pg-attribute-55
# pg-attribute pg-attribute-54
# pg-attribute pg-attribute-52
# pg-attribute pg-attribute-51
# pg-attribute pg-attribute-43
# pg-attribute pg-attribute-42
# pg-attribute pg-attribute-41
# pg-attribute pg-attribute-39
# pg-attribute pg-attribute-38
# pg-attribute pg-attribute-23
# pg-attribute pg-attribute-22
# pg-attribute pg-attribute-21
# pg-attribute pg-attribute-20
# pg-attribute pg-attribute-18
# pg-attribute pg-attribute-15
# pg-attribute pg-attribute-14
# pg-attribute pg-attribute-13
# pg-attribute pg-attribute-09
# pg-attribute pg-attribute-04
# pg-attribute pg-attribute-03
# pg-attribute pg-attribute-76
# pg-attribute pg-attribute-71
# pg-attribute pg-attribute-69
# pg-attribute pg-attribute-67
# pg-attribute pg-attribute-64
# pg-attribute pg-attribute-61
# pg-attribute pg-attribute-60
# pg-attribute pg-attribute-57
# pg-attribute pg-attribute-48
# pg-attribute pg-attribute-46
# pg-attribute pg-attribute-40
# pg-attribute pg-attribute-37
# pg-attribute pg-attribute-36
# pg-attribute pg-attribute-34
# pg-attribute pg-attribute-33
# pg-attribute pg-attribute-32
# pg-attribute pg-attribute-31
# pg-attribute pg-attribute-30
# pg-attribute pg-attribute-00
# isurz-xml-storage isurz-xml-storage-85
# isurz-xml-storage isurz-xml-storage-42
# pg-attribute pg-attribute-24-bkp-test
# isurz-xml-storage isurz-xml-storage-91
# isurz-xml-storage isurz-xml-storage-90
# isurz-xml-storage isurz-xml-storage-89
# isurz-xml-storage isurz-xml-storage-88
# isurz-xml-storage isurz-xml-storage-87
# isurz-xml-storage isurz-xml-storage-86
# isurz-xml-storage isurz-xml-storage-84
# isurz-xml-storage isurz-xml-storage-83
# isurz-xml-storage isurz-xml-storage-81
# isurz-xml-storage isurz-xml-storage-79
# isurz-xml-storage isurz-xml-storage-78
# isurz-xml-storage isurz-xml-storage-77
# isurz-xml-storage isurz-xml-storage-76
# isurz-xml-storage isurz-xml-storage-75
# isurz-xml-storage isurz-xml-storage-73
# isurz-xml-storage isurz-xml-storage-72
# isurz-xml-storage isurz-xml-storage-70
# isurz-xml-storage isurz-xml-storage-68
# isurz-xml-storage isurz-xml-storage-66
# isurz-xml-storage isurz-xml-storage-65
# isurz-xml-storage isurz-xml-storage-63
# isurz-xml-storage isurz-xml-storage-62
# isurz-xml-storage isurz-xml-storage-59
# isurz-xml-storage isurz-xml-storage-58
# isurz-xml-storage isurz-xml-storage-56
# isurz-xml-storage isurz-xml-storage-55
# isurz-xml-storage isurz-xml-storage-54
# isurz-xml-storage isurz-xml-storage-53
# isurz-xml-storage isurz-xml-storage-52
# isurz-xml-storage isurz-xml-storage-51
# isurz-xml-storage isurz-xml-storage-49
# isurz-xml-storage isurz-xml-storage-47
# isurz-xml-storage isurz-xml-storage-45
# isurz-xml-storage isurz-xml-storage-44
# isurz-xml-storage isurz-xml-storage-41
# isurz-xml-storage isurz-xml-storage-39
# isurz-xml-storage isurz-xml-storage-38
# isurz-xml-storage isurz-xml-storage-35
# isurz-xml-storage isurz-xml-storage-29
# isurz-xml-storage isurz-xml-storage-28
# isurz-xml-storage isurz-xml-storage-27
# isurz-xml-storage isurz-xml-storage-26
# isurz-xml-storage isurz-xml-storage-25
# isurz-xml-storage isurz-xml-storage-24
# isurz-xml-storage isurz-xml-storage-23
# isurz-xml-storage isurz-xml-storage-22
# isurz-xml-storage isurz-xml-storage-21
# isurz-xml-storage isurz-xml-storage-20
# isurz-xml-storage isurz-xml-storage-19
# isurz-xml-storage isurz-xml-storage-18
# isurz-xml-storage isurz-xml-storage-17
# isurz-xml-storage isurz-xml-storage-16
# isurz-xml-storage isurz-xml-storage-15
# isurz-xml-storage isurz-xml-storage-14
# isurz-xml-storage isurz-xml-storage-13
# isurz-xml-storage isurz-xml-storage-12
# isurz-xml-storage isurz-xml-storage-11
# isurz-xml-storage isurz-xml-storage-10
# isurz-xml-storage isurz-xml-storage-09
# isurz-xml-storage isurz-xml-storage-08
# isurz-xml-storage isurz-xml-storage-06
# isurz-xml-storage isurz-xml-storage-05
# isurz-xml-storage isurz-xml-storage-04
# isurz-xml-storage isurz-xml-storage-03
# isurz-xml-storage isurz-xml-storage-02
# isurz-xml-storage isurz-xml-storage-74
# isurz-xml-storage isurz-xml-storage-71
# isurz-xml-storage isurz-xml-storage-69
# isurz-xml-storage isurz-xml-storage-67
# isurz-xml-storage isurz-xml-storage-64
# isurz-xml-storage isurz-xml-storage-61
# isurz-xml-storage isurz-xml-storage-60
# isurz-xml-storage isurz-xml-storage-57
# isurz-xml-storage isurz-xml-storage-50
# isurz-xml-storage isurz-xml-storage-48
# isurz-xml-storage isurz-xml-storage-46
# isurz-xml-storage isurz-xml-storage-43
# isurz-xml-storage isurz-xml-storage-40
# isurz-xml-storage isurz-xml-storage-37
# isurz-xml-storage isurz-xml-storage-36
# isurz-xml-storage isurz-xml-storage-34
# isurz-xml-storage isurz-xml-storage-33
# isurz-xml-storage isurz-xml-storage-32
# isurz-xml-storage isurz-xml-storage-31
# isurz-xml-storage isurz-xml-storage-30
# isurz-xml-storage isurz-xml-storage-07
# isurz-xml-storage isurz-xml-storage-01
# isurz-xml-storage isurz-xml-storage-00
# pkurp-consumer pkurp-consumer-002
# pkurp-consumer pkurp-consumer-001
# egron-elasticsearch egron-elasticsearch-01
# egron-elasticsearch egron-elasticsearch-02
# isurz-elasticsearch isurz-elasticsearch-03
# isurz-elasticsearch isurz-elasticsearch-04
# pkurp-worker pkurp-worker-021
# isurz-elasticsearch isurz-elasticsearch-06
# isurz-elasticsearch isurz-elasticsearch-05
# isurz-kibana isurz-kibana-01
# isurz-elasticsearch isurz-elasticsearch-02
# isurz-elasticsearch isurz-elasticsearch-01
# egron-kibana egron-kibana-02
# egron-elasticsearch egron-elasticsearch-04
# egron-kibana egron-kibana-01
# ir-app-gi ir-app-gi-04
# ir-app-gi ir-app-gi-03
# ir-app-gi ir-app-gi-02
# ir-app-gi ir-app-gi-01
# ir-app-lk ir-app-lk-04
# ir-app-lk ir-app-lk-02
# ir-app-lk ir-app-lk-01
# ir-app-out ir-app-out-04
# ir-app-lk ir-app-lk-03
# ir-app-out ir-app-out-03
# ir-app-out ir-app-out-02
# ir-app-out ir-app-out-01
# ir-app-in ir-app-in-04
# ir-app-in ir-app-in-03
# ir-app-in ir-app-in-02
# ir-app-in ir-app-in-01
# popd-workstation popd-workstation-03
# popd-workstation popd-workstation-04
# isurz-elasticsearch isurz-elasticsearch-07
# isurz-kibana isurz-kibana-02
# popd-workstation popd-workstation-02
# pkurp-redis pkurp-redis-002
# pkurp-worker pkurp-worker-005
# popd-workstation popd-workstation-01
# pkurp-worker pkurp-worker-004
# pkurp-worker pkurp-worker-003
# pkurp-worker pkurp-worker-002
# pkurp-worker pkurp-worker-001
# isurz-api isurz-api-06
# isurz-api isurz-api-05
# isurz-api isurz-api-04
# isurz-api isurz-api-03
# isurz-api isurz-api-02
# isurz-api Isurz-api-01
# pkurp-redis pkurp-redis-001
# isurz-api isurz-api-16
# isurz-api isurz-api-15
# isurz-api isurz-api-14
# isurz-api isurz-api-13
# ppoz-service-validation ppoz-service-validation-06
# ppoz-service-validation ppoz-service-validation-05
# ppoz-service-validation ppoz-service-validation-04
# ppoz-service-validation ppoz-service-validation-03
# ppoz-service-validation ppoz-service-validation-02
# ppoz-service-validation ppoz-service-validation-01
# nsi-tasks nsi-tasks-02
# nsi-tasks nsi-tasks-01
# nsi-db nsi-db-02
# nsi-db nsi-db-01
# nsi-app nsi-app-02
# nsi-app nsi-app-01
# nsi-bal nsi-bal-02
# nsi-bal nsi-bal-01
# mdr-db mdr-db-002
# mdr-db mdr-db-001
# pmuf-zabbix-proxy pmuf-zabbix-proxy-01
# pmuf-zabbix-proxy pmuf-zabbix-proxy-02
# lk-db lk-db-04
# popd-geoserver popd-geoserver-05
# lk-db lk-db-03
# popd-geoserver popd-geoserver-06
# popd-geoserver popd-geoserver-07
# popd-geoserver popd-geoserver-08
# sf-solr sf-solr-04
# sf-solr sf-solr-03
# popd-geoimager popd-geoimager-03
# popd-geoimager popd-geoimager-04
# popd-geoapi popd-geoapi-04
# popd-geoapi popd-geoapi-05
# popd-geoapi popd-geoapi-06
# popd-geoapi popd-geoapi-07
# popd-geoapi popd-geoapi-08
# pmuf-zabbix-proxy pmuf-zabbix-proxy-03
# popd-geoapi popd-geoapi-03
# popd-geoapi popd-geoapi-02
# popd-geoimager popd-geoimager-02
# popd-geoserver popd-geoserver-04
# popd-geoserver popd-geoserver-03
# popd-bpd-adapter popd-bpd-adapter-04
# popd-bpd-adapter popd-bpd-adapter-03
# site-solr site-solr-04
# site-solr site-solr-03
# ppoz-filestorage ppoz-filestorage-10
# ppoz-filestorage ppoz-filestorage-09
# ppoz-service-external ppoz-service-external-06
# ppoz-service-external ppoz-service-external-05
# ppoz-service-external ppoz-service-external-04
# ppoz-service-external ppoz-service-external-03
# site-solr site-solr-02
# site-solr site-solr-01
# sf-solr sf-solr-02
# sf-solr sf-solr-01
# ppoz-service-external ppoz-service-external-02
# ppoz-service-external ppoz-service-external-01
# ppoz-filestorage ppoz-filestorage-08
# ppoz-filestorage ppoz-filestorage-07
# ppoz-filestorage ppoz-filestorage-06
# ppoz-filestorage ppoz-filestorage-05
# popd-geoimager popd-geoimager-01
# popd-geoapi popd-geoapi-01
# popd-geoserver popd-geoserver-02
# popd-geoserver popd-geoserver-01
# isurz-writer isurz-writer-039
# isurz-writer isurz-writer-009
# lk-db lk-db-02
# lk-db lk-db-01
# isurz-writer isurz-writer-050
# isurz-writer isurz-writer-049
# isurz-writer isurz-writer-047
# isurz-writer isurz-writer-045
# isurz-writer isurz-writer-044
# isurz-writer isurz-writer-043
# isurz-writer isurz-writer-042
# isurz-writer isurz-writer-041
# isurz-writer isurz-writer-038
# isurz-writer isurz-writer-035
# isurz-writer isurz-writer-029
# isurz-writer isurz-writer-028
# isurz-writer isurz-writer-027
# isurz-writer isurz-writer-026
# isurz-writer isurz-writer-025
# isurz-writer isurz-writer-024
# isurz-writer isurz-writer-023
# isurz-writer isurz-writer-022
# isurz-writer isurz-writer-021
# isurz-writer isurz-writer-020
# isurz-writer isurz-writer-019
# isurz-writer isurz-writer-018
# isurz-writer isurz-writer-017
# isurz-writer isurz-writer-016
# isurz-writer isurz-writer-015
# isurz-writer isurz-writer-014
# isurz-writer isurz-writer-013
# isurz-writer isurz-writer-012
# isurz-writer isurz-writer-011
# isurz-writer isurz-writer-010
# isurz-writer isurz-writer-007
# isurz-writer isurz-writer-006
# isurz-writer isurz-writer-005
# isurz-writer isurz-writer-004
# isurz-writer isurz-writer-003
# isurz-writer isurz-writer-002
# isurz-uploader isurz-uploader-020
# isurz-uploader isurz-uploader-019
# isurz-uploader isurz-uploader-018
# isurz-uploader isurz-uploader-017
# isurz-uploader isurz-uploader-016
# isurz-uploader isurz-uploader-015
# isurz-uploader isurz-uploader-014
# isurz-uploader isurz-uploader-013
# isurz-uploader isurz-uploader-012
# isurz-uploader isurz-uploader-011
# isurz-uploader isurz-uploader-010
# isurz-uploader isurz-uploader-009
# isurz-uploader isurz-uploader-007
# isurz-uploader isurz-uploader-006
# isurz-uploader isurz-uploader-005
# isurz-uploader isurz-uploader-004
# isurz-uploader isurz-uploader-003
# isurz-uploader isurz-uploader-002
# isurz-api isurz-api-12
# isurz-api isurz-api-11
# isurz-api isurz-api-10
# isurz-api isurz-api-09
# isurz-api isurz-api-08
# isurz-api isurz-api-07
# pg-map-reduce pg-map-reduce-05
# pg-map-reduce pg-map-reduce-04
# pg-map-reduce pg-map-reduce-03
# pg-map-reduce pg-map-reduce-02
# pg-map-reduce pg-map-reduce-01
# isurz-writer isurz-writer-076
# isurz-writer isurz-writer-071
# isurz-writer isurz-writer-069
# isurz-writer isurz-writer-067
# isurz-writer isurz-writer-064
# isurz-writer isurz-writer-061
# isurz-writer isurz-writer-060
# isurz-writer isurz-writer-057
# isurz-writer isurz-writer-048
# isurz-writer isurz-writer-046
# isurz-writer isurz-writer-040
# isurz-writer isurz-writer-037
# isurz-writer isurz-writer-036
# isurz-writer isurz-writer-034
# isurz-writer isurz-writer-033
# isurz-writer isurz-writer-032
# isurz-writer isurz-writer-031
# isurz-writer isurz-writer-030
# isurz-writer isurz-writer-008
# isurz-writer isurz-writer-001
# isurz-writer isurz-writer-000
# ppoz-filestorage ppoz-filestorage-04
# ppoz-filestorage ppoz-filestorage-03
# ppoz-filestorage ppoz-filestorage-02
# ppoz-filestorage ppoz-filestorage-01
# isurz-uploader isurz-uploader-076
# isurz-uploader isurz-uploader-071
# isurz-uploader isurz-uploader-069
# isurz-uploader isurz-uploader-067
# isurz-uploader isurz-uploader-064
# isurz-uploader isurz-uploader-061
# isurz-uploader isurz-uploader-060
# isurz-uploader isurz-uploader-057
# isurz-uploader isurz-uploader-048
# isurz-uploader isurz-uploader-046
# isurz-uploader isurz-uploader-040
# isurz-uploader isurz-uploader-037
# isurz-uploader isurz-uploader-036
# isurz-uploader isurz-uploader-034
# isurz-uploader isurz-uploader-033
# isurz-uploader isurz-uploader-032
# isurz-uploader isurz-uploader-031
# isurz-uploader isurz-uploader-030
# isurz-uploader isurz-uploader-008
# isurz-uploader isurz-uploader-001
# isurz-uploader isurz-uploader-000
# popd-bpd-adapter popd-bpd-adapter-02
# popd-bpd-adapter popd-bpd-adapter-01
# ir-app-bal ir-app-bal-02
# ir-app-bal ir-app-bal-01
# ps-bd-bal ps-bd-bal-02
# ps-bd-bal ps-bd-bal-01
# pkurp-worker pkurp-worker-022
# ir-app-gi-bal ir-app-gi-bal-01
# ir-app-lk-bal ir-app-lk-bal-01
# ir-app-out-bal ir-app-out-bal-01
# ir-app-in-bal ir-app-in-bal-01
# ir-bd-bal ir-bd-bal-01
# popd-geoapi-balancer popd-geoapi-balancer-01
# popd-bpd-balancer popd-bpd-balancer-01
# pkurp-worker pkurp-worker-017
# pkurp-worker pkurp-worker-016
# pkurp-worker pkurp-worker-015
# pkurp-worker pkurp-worker-014
# pkurp-worker pkurp-worker-013
# pkurp-worker pkurp-worker-012
# pkurp-worker pkurp-worker-011
# lk-srv lk-srv-04
# lk-srv lk-srv-03
# lk-backend lk-backend-04
# lk-backend lk-backend-03
# site-dstool site-dstool-04
# site-dstool site-dstool-03
# popd-geoworkers popd-geoworkers-03
# popd-geoworkers popd-geoworkers-04
# sf-back sf-back-04
# sf-back sf-back-03
# sf-front sf-front-04
# sf-front sf-front-03
# site-liferay-srv site-liferay-srv-10
# site-liferay-srv site-liferay-srv-09
# site-liferay-srv site-liferay-srv-08
# site-liferay-srv site-liferay-srv-07
# site-liferay site-liferay-10
# site-liferay site-liferay-09
# site-liferay site-liferay-08
# site-liferay site-liferay-07
# cia-idp-core cia-idp-core-10
# cia-idp-core cia-idp-core-09
# cia-idp-core cia-idp-core-08
# cia-idp-core cia-idp-core-07
# cia-sign cia-sign-20
# cia-sign cia-sign-19
# cia-sign cia-sign-18
# cia-sign cia-sign-17
# cia-sign cia-sign-16
# cia-sign cia-sign-15
# cia-sign cia-sign-14
# cia-sign cia-sign-13
# cia-sign cia-sign-12
# cia-sign cia-sign-11
# cia-sign cia-sign-10
# cia-core cia-core-10
# cia-core cia-core-09
# cia-core cia-core-08
# cia-core cia-core-07
# popd-geoworkers popd-geoworkers-02
# pkurp-worker pkurp-worker-010
# pkurp-worker pkurp-worker-009
# pkurp-worker pkurp-worker-008
# pkurp-worker pkurp-worker-007
# pkurp-worker pkurp-worker-006
# site-int site-int-04
# site-int site-int-03
# site-liferay-srv site-liferay-srv-06
# site-liferay-srv site-liferay-srv-05
# ppoz-gmp-services ppoz-gmp-services-07
# site-liferay-srv site-liferay-srv-04
# site-liferay-srv site-liferay-srv-03
# site-liferay site-liferay-06
# site-liferay site-liferay-05
# site-liferay site-liferay-04
# site-liferay site-liferay-03
# cia-sign cia-sign-09
# cia-sign cia-sign-08
# cia-sign cia-sign-07
# ppoz-smev-service ppoz-smev-service-10
# ppoz-smev-service ppoz-smev-service-09
# ppoz-smev-service ppoz-smev-service-08
# ppoz-smev-service ppoz-smev-service-07
# ppoz-smev-service ppoz-smev-service-06
# ppoz-smev-service ppoz-smev-service-05
# ppoz-kuvd-service ppoz-kuvd-service-06
# ppoz-kuvd-service ppoz-kuvd-service-05
# ppoz-kuvd-service ppoz-kuvd-service-04
# ppoz-kuvd-service ppoz-kuvd-service-03
# ppoz-gmp-services ppoz-gmp-services-06
# ppoz-gmp-services ppoz-gmp-services-05
# ppoz-gmp-services ppoz-gmp-services-04
# ppoz-gmp-services ppoz-gmp-services-03
# cia-sign cia-sign-06
# cia-sign cia-sign-05
# cia-idp-core cia-idp-core-06
# cia-idp-core cia-idp-core-05
# cia-idp-core cia-idp-core-04
# cia-idp-core cia-idp-core-03
# cia-core cia-core-06
# cia-core cia-core-05
# cia-core cia-core-04
# cia-core cia-core-03
# pkurp-worker pkurp-worker-020
# pkurp-worker pkurp-worker-019
# pkurp-worker pkurp-worker-018
# site-liferay-srv site-liferay-srv-02
# site-liferay-srv site-liferay-srv-01
# site-liferay site-liferay-02
# site-liferay site-liferay-01
# site-int site-int-02
# site-int site-int-01
# site-dstool site-dstool-02
# site-dstool site-dstool-01
# sf-front sf-front-02
# sf-front sf-front-01
# sf-back sf-back-02
# sf-back sf-back-01
# ppoz-smev-service ppoz-smev-service-04
# ppoz-smev-service ppoz-smev-service-03
# ppoz-smev-service ppoz-smev-service-02
# ppoz-smev-service ppoz-smev-service-01
# ppoz-kuvd-service ppoz-kuvd-service-02
# ppoz-kuvd-service ppoz-kuvd-service-01
# ppoz-gmp-services ppoz-gmp-services-02
# ppoz-gmp-services ppoz-gmp-services-01
# popd-geoserver-balancer popd-geoserver-balancer-01
# popd-workstation-balancer popd-workstation-balancer-01
# popd-geoworkers popd-geoworkers-01
# popd-bpd-adapter-balancer popd-bpd-adapter-balancer-01
# migr-conf migr-conf-01
# lk-srv lk-srv-02
# lk-srv lk-srv-01
# lk-backend lk-backend-02
# lk-backend lk-backend-01
# cia-sign cia-sign-04
# cia-sign cia-sign-03
# cia-sign cia-sign-02
# cia-sign cia-sign-01
# cia-idp-core cia-idp-core-02
# cia-idp-core cia-idp-core-01
# cia-core cia-core-02
# cia-core cia-core-01
# pkurp-app-balancer pkurp-app-balancer-02
# mgmt-ansible mgmt-ansible-02
# mgmt-ansible mgmt-ansible-01
# pkurp-app-balancer pkurp-app-balancer-01
# isurz-uploader-balancer isurz-uploader-balancer-01
# isurz-api-balancer isurz-api-balancer-01
# pmuf-zabbix-server pmuf-zabbix-server-02
# pmuf-zabbix-server pmuf-zabbix-server-01
# ppoz-smev-bal ppoz-smev-bal-01
# lk-rd lk-rd-04
# lk-rd lk-rd-03
# site-dstool-bal site-dstool-bal-02
# site-dstool-bal site-dstool-bal-01
# site-bal site-bal-02
# site-bal site-bal-01
# sf-bal sf-bal-02
# sf-bal sf-bal-01
# ppoz-smev-bal ppoz-smev-bal-02
# ppoz-service-bal ppoz-service-bal-02
# ppoz-service-bal ppoz-service-bal-01
# ppoz-process-bal-ppoz ppoz-process-bal-ppoz-02
# ppoz-process-bal-ppoz ppoz-process-bal-ppoz-01
# ppoz-process-bal-popd ppoz-process-bal-popd-02
# ppoz-process-bal-popd ppoz-process-bal-popd-01
# ppoz-process-bal-pkurp ppoz-process-bal-pkurp-02
# ppoz-process-bal-pkurp ppoz-process-bal-pkurp-01
# ppoz-process-bal-gmp ppoz-process-bal-gmp-02
# ppoz-process-bal-gmp ppoz-process-bal-gmp-01
# ppoz-nsi-adapter ppoz-nsi-adapter-02
# ppoz-nsi-adapter ppoz-nsi-adapter-01
# ppoz-kuvd-bal ppoz-kuvd-bal-02
# ppoz-kuvd-bal ppoz-kuvd-bal-01
# ppoz-gmp-bal ppoz-gmp-bal-02
# ppoz-gmp-bal ppoz-gmp-bal-01
# pmuf-arm-sc-balancer pmuf-arm-sc-balancer-01
# lk-ui lk-ui-02
# lk-ui lk-ui-01
# lk-rd lk-rd-02
# lk-rd lk-rd-01
# lk-bal lk-bal-02
# lk-bal lk-bal-01
# egron-bal-outer egron-bal-outer-02
# egron-bal-outer egron-bal-outer-01
# cite-bal-outer cite-bal-outer-02
# cite-bal-outer cite-bal-outer-01
# cia-sign-bal cia-sign-bal-02
# cia-sign-bal cia-sign-bal-01
# cia-idp-bal cia-idp-bal-02
# cia-idp-bal cia-idp-bal-01
# cia-core-bal cia-core-bal-02
# cia-core-bal cia-core-bal-01
# ppoz-filestorage-bal ppoz-filestorage-bal-02
# ppoz-filestorage-bal ppoz-filestorage-bal-01
#  pkurp-dev-01
#  pkurp-report-01
#  lk-srzu-ir-02
#  lk-srzu-ir-01
#  pmo-db-fed-03
#  pmo-db-fed-02
#  pmo-db-fed-01
#  pmo-etl-001
#  pmo-isurzdb-replica-01
#  ppoz-kuvd-migration-service-01
#  ir-app-01-02
#  ir-app-01-01
#  ir-srv-01-01
#  is-centr
#  popd-api-migr-02
#  popd-api-migr-01
# pg-attribute-standby pg-attribute-standby-82
# pg-attribute-standby pg-attribute-standby-80
#  migr-gkn-oracle-0
#  pmo-app-006
#  pmo-app-007
#  pmo-app-008
#  pmo-app-009
#  pmo-app-010
#  pmo-armedit-03
#  pkurp-elasticsearch-04
#  pmo-armedit-02
#  pmo-etl-004
#  pmo-etl-003
#  pmo-app-005
#  pmo-app-004
#  pmo-app-003
#  pmo-app-002
#  migr-arc-9
#  migr-arc-7
#  migr-arc-6
#  migr-arc-5
#  migr-arc-4
#  migr-arc-3
#  migr-arc-2
#  pmo-etl-002
#  pmo-db-003
#  pmo-db-002
#  pmo-db-001
#  pmo-armedit-01
#  pmo-app-001
#  migr-arc-xx
#  migr-arc-0
#  migr-gkn-oracle-9
#  migr-gkn-oracle-7
#  migr-gkn-oracle-6
#  migr-gkn-oracle-5
#  migr-gkn-oracle-4
#  migr-gkn-oracle-3
#  migr-gkn-oracle-2
#  migr-gkn-oracle-1
#  ppoz-kuvd-migration-service-85
#  ppoz-kuvd-migration-service-82
#  ppoz-kuvd-migration-service-81
#  ppoz-kuvd-migration-service-80
#  ppoz-kuvd-migration-service-63
#  ppoz-kuvd-migration-service-62
#  ppoz-kuvd-migration-service-61
#  ppoz-kuvd-migration-service-91
#  ppoz-kuvd-migration-service-90
#  ppoz-kuvd-migration-service-89
#  ppoz-kuvd-migration-service-87
#  ppoz-kuvd-migration-service-86
#  ppoz-kuvd-migration-service-83
#  ppoz-kuvd-migration-service-79
#  ppoz-kuvd-migration-service-78
#  ppoz-kuvd-migration-service-77
#  ppoz-kuvd-migration-service-76
#  ppoz-kuvd-migration-service-75
#  ppoz-kuvd-migration-service-74
#  ppoz-kuvd-migration-service-73
#  ppoz-kuvd-migration-service-72
#  ppoz-kuvd-migration-service-71
#  ppoz-kuvd-migration-service-70
#  ppoz-kuvd-migration-service-69
#  ppoz-kuvd-migration-service-68
#  ppoz-kuvd-migration-service-67
#  ppoz-kuvd-migration-service-66
#  ppoz-kuvd-migration-service-65
#  ppoz-kuvd-migration-service-64
#  pg-v1-attribute-33
#  mgmt-bacula-director
#  mgmt-bacula-catalog
#  Hmdr-bus-app-001
#  pmuf-arm-sc-02
#  lk-srzu-db-01
#  lk-srzu-gi-01
# pg-attribute-standby pg-attribute-standby-34
# pg-attribute-standby pg-attribute-standby-35
# pg-attribute-standby pg-attribute-standby-33
# pg-attribute-standby pg-attribute-standby-36
# pg-attribute-standby pg-attribute-standby-32
# pg-attribute-standby pg-attribute-standby-37
# pg-attribute-standby pg-attribute-standby-31
# pg-attribute-standby pg-attribute-standby-38
# pg-attribute-standby pg-attribute-standby-30
# pg-attribute-standby pg-attribute-standby-39
# pg-attribute-standby pg-attribute-standby-29
# pg-attribute-standby pg-attribute-standby-40
# pg-attribute-standby pg-attribute-standby-28
# pg-attribute-standby pg-attribute-standby-41
# pg-attribute-standby pg-attribute-standby-27
# pg-attribute-standby pg-attribute-standby-42
# pg-attribute-standby pg-attribute-standby-26
# pg-attribute-standby pg-attribute-standby-43
# pg-attribute-standby pg-attribute-standby-25
# pg-attribute-standby pg-attribute-standby-44
# pg-attribute-standby pg-attribute-standby-24
# pg-attribute-standby pg-attribute-standby-45
# pg-attribute-standby pg-attribute-standby-23
# pg-attribute-standby pg-attribute-standby-46
# pg-attribute-standby pg-attribute-standby-22
# pg-attribute-standby pg-attribute-standby-47
# pg-attribute-standby pg-attribute-standby-21
# pg-attribute-standby pg-attribute-standby-48
# pg-attribute-standby pg-attribute-standby-20
# pg-attribute-standby pg-attribute-standby-49
# pg-attribute-standby pg-attribute-standby-19
# pg-attribute-standby pg-attribute-standby-50
# pg-attribute-standby pg-attribute-standby-18
# pg-attribute-standby pg-attribute-standby-51
# pg-attribute-standby pg-attribute-standby-17
# pg-attribute-standby pg-attribute-standby-52
# pg-attribute-standby pg-attribute-standby-16
# pg-attribute-standby pg-attribute-standby-53
# pg-attribute-standby pg-attribute-standby-15
# pg-attribute-standby pg-attribute-standby-54
# pg-attribute-standby pg-attribute-standby-14
# pg-attribute-standby pg-attribute-standby-55
# pg-attribute-standby pg-attribute-standby-13
# pg-attribute-standby pg-attribute-standby-56
# pg-attribute-standby pg-attribute-standby-12
# pg-attribute-standby pg-attribute-standby-57
# pg-attribute-standby pg-attribute-standby-11
# pg-attribute-standby pg-attribute-standby-58
# pg-attribute-standby pg-attribute-standby-10
# pg-attribute-standby pg-attribute-standby-59
# pg-attribute-standby pg-attribute-standby-09
# pg-attribute-standby pg-attribute-standby-60
# pg-attribute-standby pg-attribute-standby-08
# pg-attribute-standby pg-attribute-standby-61
# pg-attribute-standby pg-attribute-standby-07
# pg-attribute-standby pg-attribute-standby-62
# pg-attribute-standby pg-attribute-standby-06
# pg-attribute-standby pg-attribute-standby-63
# pg-attribute-standby pg-attribute-standby-05
# pg-attribute-standby pg-attribute-standby-64
# pg-attribute-standby pg-attribute-standby-04
# pg-attribute-standby pg-attribute-standby-65
# pg-attribute-standby pg-attribute-standby-03
# pg-attribute-standby pg-attribute-standby-66
# pg-attribute-standby pg-attribute-standby-02
# pg-attribute-standby pg-attribute-standby-67
# pg-attribute-standby pg-attribute-standby-01
# pg-attribute-standby pg-attribute-standby-68
# pg-attribute-standby pg-attribute-standby-00
# pg-attribute-standby pg-attribute-standby-69
# pg-attribute-standby pg-attribute-standby-70
# pg-attribute-standby pg-attribute-standby-71
# pg-attribute-standby pg-attribute-standby-72
# pg-attribute-standby pg-attribute-standby-73
# pg-attribute-standby pg-attribute-standby-74
# pg-attribute-standby pg-attribute-standby-75
# pg-attribute-standby pg-attribute-standby-76
# pg-attribute-standby pg-attribute-standby-77
# pg-attribute-standby pg-attribute-standby-78
# pg-attribute-standby pg-attribute-standby-79
# pg-attribute-standby pg-attribute-standby-81
# pg-attribute-standby pg-attribute-standby-83
# pg-attribute-standby pg-attribute-standby-84
# pg-attribute-standby pg-attribute-standby-85
# pg-attribute-standby pg-attribute-standby-86
# pg-attribute-standby pg-attribute-standby-87
# pg-attribute-standby pg-attribute-standby-88
# pg-attribute-standby pg-attribute-standby-89
# pg-attribute-standby pg-attribute-standby-90
# pg-attribute-standby pg-attribute-standby-91
#  pkurp-kibana-02
#  pmo-services-01
#  ppoz-kuvd-migration-service-60
#  ppoz-kuvd-migration-service-59
#  ppoz-kuvd-migration-service-58
#  ppoz-kuvd-migration-service-57
#  ppoz-kuvd-migration-service-56
#  ppoz-kuvd-migration-service-55
#  ppoz-kuvd-migration-service-54
#  ppoz-kuvd-migration-service-53
#  ppoz-kuvd-migration-service-52
#  ppoz-kuvd-migration-service-51
#  ppoz-kuvd-migration-service-50
#  ppoz-kuvd-migration-service-49
#  ppoz-kuvd-migration-service-48
#  ppoz-kuvd-migration-service-47
#  ppoz-kuvd-migration-service-46
#  ppoz-kuvd-migration-service-45
#  ppoz-kuvd-migration-service-44
#  ppoz-kuvd-migration-service-43
#  ppoz-kuvd-migration-service-42
#  ppoz-kuvd-migration-service-41
#  ppoz-kuvd-migration-service-40
#  ppoz-kuvd-migration-service-39
#  ppoz-kuvd-migration-service-38
#  ppoz-kuvd-migration-service-37
#  ppoz-kuvd-migration-service-36
#  ppoz-kuvd-migration-service-35
#  ppoz-kuvd-migration-service-34
#  ppoz-kuvd-migration-service-33
#  ppoz-kuvd-migration-service-32
#  ppoz-kuvd-migration-service-31
#  ppoz-kuvd-migration-service-30
#  ppoz-kuvd-migration-service-29
#  ppoz-kuvd-migration-service-28
#  ppoz-kuvd-migration-service-27
#  ppoz-kuvd-migration-service-26
#  ppoz-kuvd-migration-service-25
#  ppoz-kuvd-migration-service-24
#  ppoz-kuvd-migration-service-23
#  ppoz-kuvd-migration-service-22
#  ppoz-kuvd-migration-service-21
#  pmuf-rmq-01
#  pmuf-arm-sc-01
#  pmo-services-02
#  pkurp-kibana-01
#  migr-jst-oracle-9
#  migr-jst-oracle-7
#  migr-jst-oracle-5
#  migr-jst-oracle-4
#  migr-jst-oracle-3
#  migr-jst-oracle-2
#  migr-jst-oracle-0
#  pg-bouncer
#  ppoz-kuvd-migration-service-20
#  ppoz-kuvd-migration-service-19
#  ppoz-kuvd-migration-service-18
#  ppoz-kuvd-migration-service-17
#  ppoz-kuvd-migration-service-16
#  ppoz-kuvd-migration-service-15
#  ppoz-kuvd-migration-service-14
#  ppoz-kuvd-migration-service-13
#  ppoz-kuvd-migration-service-12
#  ppoz-kuvd-migration-service-11
#  ppoz-kuvd-migration-service-10
#  ppoz-kuvd-migration-service-09
#  ppoz-kuvd-migration-service-08
#  ppoz-kuvd-migration-service-07
#  ppoz-kuvd-migration-service-06
#  ppoz-kuvd-migration-service-05
#  ppoz-kuvd-migration-service-04
#  ppoz-kuvd-migration-service-03
#  ppoz-kuvd-migration-service-02
#  mgmt-repo-01
#  isurz-bpd-inserter-01
#  aizhk-order-db-02
#  aizhk-order-db-01
#  aizhk-arm-service-02
#  aizhk-arm-service-01
#  agent-pvd3
#  isurz-xml-storage-right-registry-entities
#  pkurp-app-readonly-02
#  pkurp-app-readonly-01
#  egron-mgmt-01
#  egron-monitoring-01
#  pg-pool-01
#  pg-master-bkp-test
#  cia-db-bkp-01
#  mgmt-repository-01
#  1007
#  mgmt-docker-registry-01
#  pkurp-app-notification-002
#  popd-geocdn-01
#  pmo-db-pgpool-001
#  pmo-db-fed-pgpool-01
#  pkurp-app-notification-001
#  pkurp-sentry-db
#  isurz-sentry-db
#  isurz-xml-storage-books
#  isurz-xml-storage-borders
#  zbx_bcp
#  zabbix
#  fordump2
#  fordump
#  aizhk-order-db-bal-01
#  aizhk-arm-bal-02
#  aizhk-arm-bal-01
#  tnx-mon
#  mgmt-pypi-01
#  pg-mq-02-standby
#  pg-mq-03
#  pg-mq-03-standby
#  pg-mq-02
#  migr-arc-test
#  pg-mq-01-standby
#  pg-mq-01
#  monitor-mdr-egrn
#  s_hdd
#  pmuf-db-pgpool-01
#  pmo-arm-edit-balancer-01
#  pmo-app-balancer-01
#  DNS2_relay
#  DNS_relay
#  pkurp-sentry
#  isurz-sentry
#  pmuf-zabbix-db-pgpool-01

# %%
#[i for i in z1.dict_servers.keys() if 'pg-master-replica' in z1.dict_servers[i]['name']]

# %%
#dUseVms['pg-attribute-91'], dUseGroups['pg-attribute']

# %%
#len(z1.dict_servers.keys()), len(dUseVms)

# %%
#z1.dict_servers['pg-master-replica-standby-01']#, z1.dict_servers['pg-master-replica-standy-01']

# %%
count_all(dg=dUseGroups,dh=dUseHyper,dv=dUseVms)
# Out:
# Всего машин: 1653
# Всего ВУ: 76
# Забитость ВУ по RAM
# Самый забитый : 0.982425191976634
# Наименее забитый : 0.8239695158513705
# Средняя загруженность : 0.8918649734938064
# Среднедратичное отклонение по ВУ : 0.054506574162
#
# Перерасход vCPU относительно CPU ВУ
# Самый забитый : 3.75
# Наименее забитый : 2.0
# Средняя загруженность : 2.901174168297456

# %%
make_xls()
# Out:
# /usr/lib/python3.6/site-packages/openpyxl/workbook/child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
#dUseVms['pg-attribute-standby-02']
#dUseGroups['ppoz-process-core']

# %%
tl = [[i,dUseVms[i]['cn'],dUseVms[i]['cn_new']] for i in dUseVms.keys()]
otl = [[i,dUseVms[i]['cn'],dUseVms[i]['cn_new']] \
       for i in dUseVms.keys() if dUseVms[i]['cn_new'] ==  dUseVms[i]['cn']]
otl_vm = [i \
       for i in dUseVms.keys() if dUseVms[i]['cn_new'] ==  dUseVms[i]['cn']]
migrations = len(tl) - len(otl)

# %%
len(tl), len(otl)
# Out:
# (1681, 864)

# %%
migrations = len(tl) - len(otl)
migrations
# Out:
# 817

# %%
dUseVms['iperf_lacp_test_client_1']
# Out:
# {'cn': 'cn-e0f6.egron.tnx',
#  'cn_new': '',
#  'cpu': 4,
#  'group': '',
#  'name': 'iperf_lacp_test_client_1',
#  'ram': 4096}

# %%
#rm = [1,2,3,4,511,128,-1,-1,-1]
#min(rm)

# %%
dUseGroups
# Out:
# {'cia-core': {'az': {1: 3, 2: 3, 3: 4},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 1,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 1,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 1,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 1,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 1,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 1,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 1,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 1,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 2},
#   'type': 1,
#   'vm_count': 10,
#   'vms': ['cia-core-10',
#    'cia-core-09',
#    'cia-core-08',
#    'cia-core-07',
#    'cia-core-06',
#    'cia-core-05',
#    'cia-core-04',
#    'cia-core-03',
#    'cia-core-02',
#    'cia-core-01']},
#  'cia-core-bal': {'az': {1: 1, 2: 0, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 1,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 1,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 2,
#   'vms': ['cia-core-bal-02', 'cia-core-bal-01']},
#  'cia-db': {'az': {1: 1, 2: 1, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 1,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 1,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 1,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 4,
#   'vm_count': 3,
#   'vms': ['cia-db-03', 'cia-db-02', 'cia-db-01']},
#  'cia-idp-bal': {'az': {1: 1, 2: 0, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 1,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 1,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 2,
#   'vms': ['cia-idp-bal-02', 'cia-idp-bal-01']},
#  'cia-idp-core': {'az': {1: 3, 2: 3, 3: 4},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 1,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 2,
#    'cn-db74.egron.tnx': 1,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 1,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 1,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 1,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 1,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 2,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 10,
#   'vms': ['cia-idp-core-10',
#    'cia-idp-core-09',
#    'cia-idp-core-08',
#    'cia-idp-core-07',
#    'cia-idp-core-06',
#    'cia-idp-core-05',
#    'cia-idp-core-04',
#    'cia-idp-core-03',
#    'cia-idp-core-02',
#    'cia-idp-core-01']},
#  'cia-sign': {'az': {1: 6, 2: 7, 3: 7},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 1,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 1,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 1,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 1,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 1,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 1,
#    'cn-dc8e.egron.tnx': 1,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 1,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 1,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 1,
#    'cn-de10.egron.tnx': 1,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 1,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 1,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 1,
#    'cn-e814.egron.tnx': 1,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 1,
#    'cn-ed8c.egron.tnx': 1,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 1,
#    'cn-fdec.egron.tnx': 1,
#    'cn-fe1a.egron.tnx': 1},
#   'type': 1,
#   'vm_count': 20,
#   'vms': ['cia-sign-20',
#    'cia-sign-19',
#    'cia-sign-18',
#    'cia-sign-17',
#    'cia-sign-16',
#    'cia-sign-15',
#    'cia-sign-14',
#    'cia-sign-13',
#    'cia-sign-12',
#    'cia-sign-11',
#    'cia-sign-10',
#    'cia-sign-09',
#    'cia-sign-08',
#    'cia-sign-07',
#    'cia-sign-06',
#    'cia-sign-05',
#    'cia-sign-04',
#    'cia-sign-03',
#    'cia-sign-02',
#    'cia-sign-01']},
#  'cia-sign-bal': {'az': {1: 0, 2: 1, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 1,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 1,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 2,
#   'vms': ['cia-sign-bal-02', 'cia-sign-bal-01']},
#  'cite-bal-outer': {'az': {1: 0, 2: 1, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 1,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 1,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 2,
#   'vms': ['cite-bal-outer-02', 'cite-bal-outer-01']},
#  'egron-bal-outer': {'az': {1: 0, 2: 1, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 1,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 1,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 2,
#   'vms': ['egron-bal-outer-02', 'egron-bal-outer-01']},
#  'egron-elasticsearch': {'az': {1: 2, 2: 1, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 1,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 1,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 1,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 1,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 4,
#   'vms': ['egron-elasticsearch-03',
#    'egron-elasticsearch-01',
#    'egron-elasticsearch-02',
#    'egron-elasticsearch-04']},
#  'egron-kibana': {'az': {1: 0, 2: 1, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 1,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 1,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 2,
#   'vms': ['egron-kibana-02', 'egron-kibana-01']},
#  'ir-app-bal': {'az': {1: 1, 2: 0, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 1,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 1,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 2,
#   'vms': ['ir-app-bal-02', 'ir-app-bal-01']},
#  'ir-app-gi': {'az': {1: 1, 2: 2, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 1,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 1,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 2,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 4,
#   'vms': ['ir-app-gi-04', 'ir-app-gi-03', 'ir-app-gi-02', 'ir-app-gi-01']},
#  'ir-app-gi-bal': {'az': {1: 0, 2: 0, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 1,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 1,
#   'vms': ['ir-app-gi-bal-01']},
#  'ir-app-in': {'az': {1: 1, 2: 2, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 1,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 1,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 1,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 1,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 4,
#   'vms': ['ir-app-in-04', 'ir-app-in-03', 'ir-app-in-02', 'ir-app-in-01']},
#  'ir-app-in-bal': {'az': {1: 0, 2: 0, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 1,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 1,
#   'vms': ['ir-app-in-bal-01']},
#  'ir-app-lk': {'az': {1: 1, 2: 2, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 1,
#    'cn-da22.egron.tnx': 1,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 1,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 1,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 4,
#   'vms': ['ir-app-lk-04', 'ir-app-lk-02', 'ir-app-lk-01', 'ir-app-lk-03']},
#  'ir-app-lk-bal': {'az': {1: 0, 2: 0, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 1,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 1,
#   'vms': ['ir-app-lk-bal-01']},
#  'ir-app-out': {'az': {1: 1, 2: 1, 3: 2},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 1,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 1,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 1,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 1,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 4,
#   'vms': ['ir-app-out-04', 'ir-app-out-03', 'ir-app-out-02', 'ir-app-out-01']},
#  'ir-app-out-bal': {'az': {1: 1, 2: 0, 3: 0},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 1,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 1,
#   'vms': ['ir-app-out-bal-01']},
#  'ir-bd': {'az': {1: 4, 2: 1, 3: 5},
#   'az_even': '',
#   'az_odd': 3,
#   'hypers': {'cn-d720.egron.tnx': 1,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 1,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 1,
#    'cn-db38.egron.tnx': 1,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 1,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 1,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 1,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 2,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 1,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 3,
#   'vm_count': 10,
#   'vms': ['ir-bd-01-01',
#    'ir-bd-01-02',
#    'ir-bd-01',
#    'ir-bd-08',
#    'ir-bd-07',
#    'ir-bd-06',
#    'ir-bd-05',
#    'ir-bd-04',
#    'ir-bd-03',
#    'ir-bd-02']},
#  'ir-bd-bal': {'az': {1: 0, 2: 0, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 1,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
# ...
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 1,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 1,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 1,
#    'cn-fe1a.egron.tnx': 1},
#   'type': 4,
#   'vm_count': 4,
#   'vms': ['site-db-04', 'site-db-03', 'site-db-02', 'site-db-01']},
#  'site-dstool': {'az': {1: 1, 2: 1, 3: 2},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 1,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 1,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 1,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 1},
#   'type': 1,
#   'vm_count': 4,
#   'vms': ['site-dstool-04',
#    'site-dstool-03',
#    'site-dstool-02',
#    'site-dstool-01']},
#  'site-dstool-bal': {'az': {1: 0, 2: 1, 3: 1},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 1,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 1,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 2,
#   'vms': ['site-dstool-bal-02', 'site-dstool-bal-01']},
#  'site-int': {'az': {1: 1, 2: 1, 3: 2},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 1,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 1,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 1,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 1,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 4,
#   'vms': ['site-int-04', 'site-int-03', 'site-int-02', 'site-int-01']},
#  'site-liferay': {'az': {1: 3, 2: 3, 3: 4},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 1,
#    'cn-da44.egron.tnx': 1,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 1,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 1,
#    'cn-db32.egron.tnx': 1,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 1,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 1,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 1,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 1,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 1,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 0},
#   'type': 1,
#   'vm_count': 10,
#   'vms': ['site-liferay-10',
#    'site-liferay-09',
#    'site-liferay-08',
#    'site-liferay-07',
#    'site-liferay-06',
#    'site-liferay-05',
#    'site-liferay-04',
#    'site-liferay-03',
#    'site-liferay-02',
#    'site-liferay-01']},
#  'site-liferay-srv': {'az': {1: 3, 2: 3, 3: 4},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 0,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 0,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 1,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 1,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 1,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 1,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 1,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 0,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 2,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 1,
#    'cn-ed8c.egron.tnx': 1,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 1},
#   'type': 1,
#   'vm_count': 10,
#   'vms': ['site-liferay-srv-10',
#    'site-liferay-srv-09',
#    'site-liferay-srv-08',
#    'site-liferay-srv-07',
#    'site-liferay-srv-06',
#    'site-liferay-srv-05',
#    'site-liferay-srv-04',
#    'site-liferay-srv-03',
#    'site-liferay-srv-02',
#    'site-liferay-srv-01']},
#  'site-solr': {'az': {1: 1, 2: 1, 3: 2},
#   'az_even': '',
#   'az_odd': '',
#   'hypers': {'cn-d720.egron.tnx': 0,
#    'cn-d724.egron.tnx': 0,
#    'cn-da14.egron.tnx': 1,
#    'cn-da16.egron.tnx': 0,
#    'cn-da18.egron.tnx': 0,
#    'cn-da1a.egron.tnx': 0,
#    'cn-da1e.egron.tnx': 0,
#    'cn-da22.egron.tnx': 0,
#    'cn-da32.egron.tnx': 0,
#    'cn-da44.egron.tnx': 0,
#    'cn-da46.egron.tnx': 1,
#    'cn-da48.egron.tnx': 0,
#    'cn-da4a.egron.tnx': 0,
#    'cn-da74.egron.tnx': 0,
#    'cn-daa0.egron.tnx': 0,
#    'cn-daa6.egron.tnx': 0,
#    'cn-db08.egron.tnx': 0,
#    'cn-db0a.egron.tnx': 0,
#    'cn-db26.egron.tnx': 0,
#    'cn-db28.egron.tnx': 0,
#    'cn-db32.egron.tnx': 0,
#    'cn-db38.egron.tnx': 0,
#    'cn-db3e.egron.tnx': 0,
#    'cn-db74.egron.tnx': 0,
#    'cn-db76.egron.tnx': 0,
#    'cn-dc6c.egron.tnx': 0,
#    'cn-dc7c.egron.tnx': 0,
#    'cn-dc84.egron.tnx': 0,
#    'cn-dc8c.egron.tnx': 0,
#    'cn-dc8e.egron.tnx': 0,
#    'cn-dc9a.egron.tnx': 0,
#    'cn-dca2.egron.tnx': 0,
#    'cn-dca4.egron.tnx': 0,
#    'cn-dca6.egron.tnx': 0,
#    'cn-dca8.egron.tnx': 0,
#    'cn-dcaa.egron.tnx': 0,
#    'cn-dce2.egron.tnx': 0,
#    'cn-dce8.egron.tnx': 0,
#    'cn-dcec.egron.tnx': 0,
#    'cn-de10.egron.tnx': 0,
#    'cn-e0ba.egron.tnx': 0,
#    'cn-e0dc.egron.tnx': 0,
#    'cn-e0f6.egron.tnx': 0,
#    'cn-e128.egron.tnx': 0,
#    'cn-e13a.egron.tnx': 0,
#    'cn-e13c.egron.tnx': 0,
#    'cn-e13e.egron.tnx': 0,
#    'cn-e4b8.egron.tnx': 1,
#    'cn-e4ba.egron.tnx': 0,
#    'cn-e4bc.egron.tnx': 0,
#    'cn-e4c2.egron.tnx': 0,
#    'cn-e612.egron.tnx': 0,
#    'cn-e620.egron.tnx': 0,
#    'cn-e624.egron.tnx': 0,
#    'cn-e672.egron.tnx': 0,
#    'cn-e80c.egron.tnx': 0,
#    'cn-e80e.egron.tnx': 0,
#    'cn-e810.egron.tnx': 0,
#    'cn-e812.egron.tnx': 0,
#    'cn-e814.egron.tnx': 0,
#    'cn-e816.egron.tnx': 0,
#    'cn-e818.egron.tnx': 0,
#    'cn-e826.egron.tnx': 0,
#    'cn-e828.egron.tnx': 0,
#    'cn-e82a.egron.tnx': 0,
#    'cn-e89a.egron.tnx': 0,
#    'cn-e8a8.egron.tnx': 0,
#    'cn-e8aa.egron.tnx': 0,
#    'cn-e8ae.egron.tnx': 0,
#    'cn-e8b6.egron.tnx': 0,
#    'cn-ed8c.egron.tnx': 0,
#    'cn-ed8e.egron.tnx': 0,
#    'cn-ee38.egron.tnx': 0,
#    'cn-fdc6.egron.tnx': 0,
#    'cn-fdec.egron.tnx': 0,
#    'cn-fe1a.egron.tnx': 1},
#   'type': 1,
#   'vm_count': 4,
#   'vms': ['site-solr-04', 'site-solr-03', 'site-solr-02', 'site-solr-01']}}

# %%
#dUseVms
len(master_slave_list)
# Out:
# 6

# %%
for c in range(0,len(master_slave_list)):
    print(c)
    pair = [i for i in master_slave_list][c]
    print(pair)
    vm1 = pair[0]
    vm2 = pair[1]
    cn1 = dUseVms[vm1]['cn_new']
    cn2 = dUseVms[vm2]['cn_new']
    az1 = dUseHyper[cn1]['az'] 
    az2 = dUseHyper[cn2]['az']

    print(vm1,vm2)
    print(cn1,cn2)
    print(az1,az2)
# Out:
# 0
# ['pg-master-standby', 'pg-master']
# pg-master-standby pg-master
# cn-db28.egron.tnx cn-ee38.egron.tnx
# 1 2
# 1
# ['pg-attribute-standby-books', 'pg-attribute-books']
# pg-attribute-standby-books pg-attribute-books
# cn-da44.egron.tnx cn-ed8e.egron.tnx
# 3 2
# 2
# ['pg-attribute-standby-borders', 'pg-attribute-borders']
# pg-attribute-standby-borders pg-attribute-borders
# cn-da1e.egron.tnx cn-ed8e.egron.tnx
# 3 2
# 3
# ['pg-attribute-standby-right-registry-entities', 'pg-attribute-right-registry-entities']
# pg-attribute-standby-right-registry-entities pg-attribute-right-registry-entities
# cn-ed8e.egron.tnx cn-e612.egron.tnx
# 2 3
# 4
# ['pg-reservation-01-standby', 'pg-reservation-01']
# pg-reservation-01-standby pg-reservation-01
# cn-de10.egron.tnx cn-db32.egron.tnx
# 3 1
# 5
# ['pg-master-replica-standby-01', 'pg-master-replica-01']
# pg-master-replica-standby-01 pg-master-replica-01
# cn-ed8e.egron.tnx cn-e816.egron.tnx
# 2 3

# %%
tl = [[i,dUseVms[i]['cn'],dUseVms[i]['cn_new']] for i in dUseVms.keys()]

# %%
otl = [[i,dUseVms[i]['cn'],dUseVms[i]['cn_new']] \
       for i in dUseVms.keys() if dUseVms[i]['cn_new'] ==  dUseVms[i]['cn']]

# %%
otl_vm = [i \
       for i in dUseVms.keys() if dUseVms[i]['cn_new'] ==  dUseVms[i]['cn']]

# %%
len(tl), len(otl)
# Out:
# (1681, 864)

# %%
migrations = len(tl) - len(otl)

# %%
migrations
# Out:
# 817

# %%
otl_vm
# Out:
# ['aizhk-order-db-01',
#  'aizhk-order-db-bal-01',
#  'aizhk-arm-service-02',
#  'aizhk-arm-service-01',
#  'aizhk-arm-bal-02',
#  'aizhk-arm-bal-01',
#  'ppoz-kuvd-migration-service-82',
#  'ppoz-kuvd-migration-service-81',
#  'ppoz-kuvd-migration-service-80',
#  'ppoz-popd-process-05',
#  'ir-app-01-01',
#  'ir-bd-01-02',
#  'ir-app-bal-02',
#  'ps-bd-bal-02',
#  'egron-elasticsearch-03',
#  'migr-node-079',
#  'agent-pvd3',
#  'pkurp-worker-022',
#  'pkurp-app-037',
#  'pkurp-app-033',
#  'pkurp-app-029',
#  'pkurp-app-026',
#  'pkurp-app-025',
#  'pkurp-app-022',
#  'ppoz-kuvd-migration-service-63',
#  'ppoz-kuvd-migration-service-91',
#  'ppoz-kuvd-migration-service-90',
#  'ppoz-kuvd-migration-service-87',
#  'ppoz-kuvd-migration-service-79',
#  'ppoz-kuvd-migration-service-78',
#  'ppoz-kuvd-migration-service-76',
#  'ppoz-kuvd-migration-service-75',
#  'ppoz-kuvd-migration-service-74',
#  'ppoz-kuvd-migration-service-71',
#  'ppoz-kuvd-migration-service-69',
#  'ppoz-kuvd-migration-service-68',
#  'ppoz-kuvd-migration-service-65',
#  'migr-arc-50',
#  'isurz-xml-storage-82',
#  'isurz-xml-storage-85',
#  'migr-analitycs-01',
#  'isurz-mq-06',
#  'isurz-bpd-inserter-01',
#  'pg-v1-attribute-33',
#  'pg-mq-03',
#  'ppoz-db-fs-bkp-08',
#  'ppoz-db-fs-bkp-05',
#  'ppoz-db-fs-bkp-04',
#  'ppoz-db-fs-bkp-01',
#  'ppoz-db-fs-29',
#  'ppoz-db-fs-27',
#  'ppoz-db-fs-25',
#  'ppoz-db-fs-21',
#  'ppoz-db-fs-20',
#  'ppoz-db-fs-17',
#  'ppoz-db-fs-14',
#  'ppoz-db-fs-11',
#  'ppoz-db-fs-08',
#  'ppoz-db-fs-05',
#  'ppoz-db-fs-02',
#  'ppoz-db-fs-01',
#  'pkurp-app-readonly-01',
#  'isurz-api-16',
#  'isurz-api-13',
#  'migr-arc-test',
#  'migr-node-200',
#  'migr-node-199',
#  'migr-node-198',
#  'migr-node-197',
#  'migr-node-196',
#  'migr-node-195',
#  'migr-node-194',
#  'migr-node-193',
#  'migr-node-192',
#  'migr-node-191',
#  'migr-node-190',
#  'migr-node-189',
#  'migr-node-188',
#  'migr-node-187',
#  'migr-node-186',
#  'migr-node-185',
#  'migr-node-184',
#  'migr-node-183',
#  'migr-node-182',
#  'migr-node-181',
#  'migr-node-180',
#  'migr-node-179',
#  'migr-node-178',
#  'migr-node-177',
#  'migr-node-176',
#  'migr-node-175',
#  'migr-node-174',
#  'migr-node-173',
#  'ppoz-service-validation-06',
#  'ppoz-service-validation-04',
#  'ppoz-service-validation-03',
#  'migr-arc-76',
#  'migr-arc-71',
#  'migr-arc-69',
#  'migr-arc-61',
#  'migr-arc-57',
#  'migr-arc-48',
#  'migr-arc-46',
#  'migr-arc-37',
#  'migr-arc-33',
#  'migr-arc-32',
#  'migr-node-172',
#  'migr-node-171',
#  'migr-node-170',
#  'migr-node-169',
#  'migr-node-168',
#  'migr-node-167',
#  'migr-node-166',
#  'migr-node-165',
#  'migr-arc-31',
#  'migr-arc-30',
#  'migr-arc-8',
#  'migr-node-164',
#  'migr-node-163',
#  'migr-node-162',
#  'migr-node-161',
#  'migr-node-160',
#  'migr-node-159',
#  'migr-node-158',
#  'migr-node-157',
#  'migr-node-156',
#  'migr-node-155',
#  'migr-node-154',
#  'migr-node-153',
#  'migr-node-152',
#  'migr-node-151',
#  'migr-node-150',
#  'migr-node-149',
#  'migr-node-148',
#  'migr-node-147',
#  'migr-node-146',
#  'migr-node-145',
#  'migr-node-144',
#  'migr-node-143',
#  'migr-node-142',
#  'migr-node-141',
#  'migr-node-140',
#  'migr-node-139',
#  'migr-node-138',
#  'migr-node-137',
#  'migr-node-136',
#  'migr-node-135',
#  'migr-node-134',
#  'migr-node-133',
#  'migr-node-132',
#  'migr-node-130',
#  'migr-node-129',
#  'migr-node-128',
#  'migr-node-127',
#  'migr-node-126',
#  'migr-node-125',
#  'migr-node-124',
#  'migr-node-123',
#  'migr-node-122',
#  'migr-node-121',
#  'migr-node-120',
#  'migr-node-119',
#  'migr-node-118',
#  'migr-node-117',
#  'migr-node-116',
#  'migr-node-115',
#  'migr-node-114',
#  'migr-node-113',
#  'migr-node-111',
#  'migr-node-109',
#  'migr-node-108',
#  'migr-node-107',
#  'migr-node-104',
#  'migr-node-103',
#  'migr-node-102',
#  'migr-node-101',
#  'migr-node-100',
#  'migr-node-099',
#  'migr-node-098',
#  'migr-node-097',
#  'migr-node-096',
#  'migr-node-095',
#  'migr-node-094',
#  'migr-node-093',
#  'migr-node-092',
#  'migr-node-091',
#  'migr-node-090',
#  'migr-node-089',
#  'migr-node-088',
#  'migr-node-087',
#  'migr-node-086',
#  'migr-node-085',
#  'migr-node-084',
#  'migr-node-083',
#  'migr-node-082',
#  'migr-node-081',
#  'migr-node-080',
#  'migr-node-078',
#  'migr-node-077',
#  'migr-node-075',
#  'migr-node-074',
#  'migr-node-073',
#  'migr-node-072',
#  'migr-node-071',
#  'migr-node-070',
#  'migr-node-069',
#  'migr-node-065',
#  'migr-node-064',
#  'migr-node-062',
#  'migr-node-068',
#  'migr-node-067',
#  'migr-node-066',
#  'migr-node-063',
#  'migr-node-061',
#  'migr-arc-1',
#  'isurz-xml-storage-42',
#  'mdr-app-001-2',
#  'pg-mq-01-standby',
#  'pg-mq-01',
#  'pg-attribute-07',
#  'egron-mgmt-01',
#  'pkurp-consumer-002',
#  'pkurp-consumer-001',
#  'isurz-mq-04',
#  's_hdd',
#  'pg-master-replica-standby-01',
#  'migr-gkn-oracle-64',
#  'migr-grp-oracle-60',
#  'migr-gkn-oracle-60',
#  'migr-grp-oracle-67',
#  'migr-gkn-oracle-76',
#  'migr-gkn-oracle-69',
#  'migr-gkn-oracle-67',
#  'migr-gkn-oracle-57',
#  'migr-gkn-oracle-46',
#  'migr-gkn-oracle-40',
#  'migr-grp-oracle-37',
#  'migr-grp-oracle-33',
#  'migr-gkn-oracle-32',
#  'migr-jst-oracle-31',
#  'migr-jst-oracle-30',
#  'migr-jst-oracle-08',
#  'migr-gkn-oracle-08',
#  'migr-jst-oracle-01',
#  'mgmt-bacula-catalog',
#  'pg-pool-01',
#  'nsi-tasks-02',
#  'nsi-db-02',
#  'nsi-app-02',
#  'nsi-app-01',
#  'nsi-bal-02',
#  'nsi-bal-01',
#  'migr-reporter-01',
#  'ppoz-kuvd-db-bkp-01',
#  'migr-init-bkp-01',
#  'migr-conf-bkp-01',
#  'ppoz-db-request-bkp-11',
#  'ppoz-db-request-bkp-08',
#  'ppoz-db-request-bkp-06',
#  'ppoz-db-request-bkp-05',
#  'ppoz-kuvd-db-bkp-06',
#  'ppoz-kuvd-db-bkp-05',
#  'pkurp-dev-01',
#  'pkurp-report-01',
#  'isurz-mq-01',
#  'egron-elasticsearch-01',
#  'egron-kibana-02',
#  'egron-elasticsearch-04',
#  'mdr-db-002',
#  'mgmt-repository-01',
#  'Hmdr-bus-app-001',
#  'ir-bd-01',
#  'ir-app-gi-04',
#  'ir-app-gi-01',
#  'ir-app-lk-04',
#  'ir-app-out-04',
#  'ir-app-lk-03',
#  'ir-app-out-03',
#  'ir-app-out-02',
#  'ir-app-out-01',
#  'ir-app-in-04',
#  'ir-app-in-01',
#  'ir-bd-07',
#  'ir-bd-05',
#  'ir-bd-04',
#  'ir-bd-03',
#  'ir-bd-02',
#  'ir-app-gi-bal-01',
#  'ir-app-lk-bal-01',
#  'ir-app-out-bal-01',
#  'ir-app-in-bal-01',
#  'ir-bd-bal-01',
#  'zbx_bcp',
#  'migr-oracle-replicastore-01',
#  'pg-attribute-right-registry-entities',
#  'pg-attribute-standby-82',
#  'pg-attribute-standby-80',
#  'pg-attribute-82',
#  'pg-attribute-standby-right-registry-entities',
#  'pmuf-arm-sc-02',
#  'lk-srzu-db-01',
#  'lk-srzu-gi-01',
#  'lk-srzu-ir-02',
#  'lk-srzu-ir-01',
#  'migr-arc-85',
#  'migr-arc-81',
#  'migr-arc-82',
#  'migr-gkn-oracle-50',
#  'migr-gkn-oracle-0',
#  'migr-grp-oracle-82',
#  'migr-grp-oracle-50',
#  'popd-geoapi-balancer-01',
#  'migr-arc-43',
#  'migr-grp-oracle-74',
#  'pg-attribute-19',
#  'pg-attribute-27',
#  'pmo-db-fed-03',
#  'popd-bpd-05',
#  'popd-bpd-balancer-01',
#  'cia-db-03',
#  'pmuf-zabbix-proxy-01',
#  'pg-attribute-85',
#  'pg-attribute-83',
#  'pg-attribute-75',
#  'pg-attribute-70',
#  'pg-attribute-65',
#  'pg-attribute-63',
#  'pg-attribute-62',
#  'pg-attribute-59',
#  'pg-attribute-53',
#  'pg-attribute-49',
#  'pg-attribute-47',
#  'pg-attribute-28',
#  'pg-attribute-25',
#  'pg-attribute-17',
#  'pg-attribute-11',
#  'pg-attribute-10',
#  'pg-attribute-05',
#  'pg-attribute-02',
#  'pg-attribute-86',
#  'pg-attribute-22',
#  'pg-attribute-21',
#  'pg-attribute-18',
#  'pg-attribute-15',
#  'pg-attribute-07_orphan',
#  'pg-attribute-04',
#  'pg-attribute-03',
#  'pg-attribute-standby-35',
#  'pg-attribute-standby-33',
#  'pg-attribute-standby-36',
#  'pg-attribute-standby-32',
#  'pg-attribute-standby-37',
#  'pg-attribute-standby-38',
#  'pg-attribute-standby-30',
#  'pg-attribute-standby-39',
#  'pg-attribute-standby-40',
#  'pg-attribute-standby-27',
#  'pg-attribute-standby-42',
#  'pg-attribute-standby-43',
#  'pg-attribute-standby-22',
#  'pg-attribute-standby-47',
#  'pg-attribute-standby-49',
#  'pg-attribute-standby-19',
#  'pg-attribute-standby-51',
#  'pg-attribute-standby-17',
#  'pg-attribute-standby-52',
#  'pg-attribute-standby-15',
#  'pg-attribute-standby-54',
#  'pg-attribute-standby-55',
#  'pg-attribute-standby-56',
#  'pg-attribute-standby-12',
#  'pg-attribute-standby-57',
#  'pg-attribute-standby-58',
#  'pg-attribute-standby-59',
#  'pg-attribute-standby-08',
#  'pg-attribute-standby-07',
#  'pg-attribute-standby-62',
#  'pg-attribute-standby-63',
#  'pg-attribute-standby-05',
#  'pg-attribute-standby-03',
#  'pg-attribute-standby-66',
#  'pg-attribute-standby-02',
#  'pg-attribute-standby-67',
#  'pg-attribute-standby-01',
#  'pg-attribute-standby-68',
#  'pg-reservation-01-standby',
#  'pg-attribute-standby-72',
#  'pg-attribute-standby-74',
#  'pkurp-worker-015',
#  'pg-attribute-standby-75',
#  'pg-attribute-standby-76',
#  'pkurp-worker-012',
#  'pg-attribute-standby-78',
#  'pg-attribute-standby-79',
#  'pkurp-app-014',
#  'pg-attribute-standby-85',
#  'pg-attribute-standby-86',
#  'pkurp-app-011',
#  'lk-srv-04',
#  'lk-srv-03',
#  'lk-backend-04',
#  'pg-attribute-standby-90',
#  'lk-rd-04',
#  'pg-attribute-standby-borders',
#  'lk-rd-03',
#  'pg-attribute-standby-books',
#  'lk-db-04',
#  'popd-geoserver-05',
#  'popd-geoserver-06',
#  'site-dstool-04',
#  'popd-geoserver-08',
#  'sf-solr-04',
#  'popd-geoworkers-03',
#  'sf-back-04',
#  'popd-geoimager-03',
#  'sf-front-04',
#  'popd-geoapi-04',
#  'popd-geoapi-05',
#  'site-liferay-srv-10',
#  'popd-geoapi-07',
#  'site-liferay-srv-07',
#  'popd-workstation-03',
#  'site-liferay-10',
#  'site-liferay-07',
#  'cia-idp-core-10',
#  'cia-idp-core-08',
#  'cia-idp-core-07',
#  'cia-sign-20',
#  'pmo-app-006',
#  'pmo-app-007',
#  'cia-sign-17',
#  'pmo-app-008',
#  'pmo-app-009',
#  'pmo-app-010',
#  'cia-sign-14',
#  'pmo-armedit-03',
#  'isurz-elasticsearch-07',
#  'cia-sign-11',
#  'pkurp-elasticsearch-04',
#  'cia-core-10',
#  'isurz-elasticsearch-03',
#  'isurz-elasticsearch-04',
#  'cia-core-07',
#  'ppoz-db-proc-popd-07',
#  'ppoz-db-proc-gmp-07',
#  'ppoz-db-proc-pkurp-07',
#  'ppoz-db-proc-ppoz-07',
#  'ppoz-db-request-29',
#  'ppoz-db-request-26',
#  'ppoz-db-request-23',
#  'ppoz-db-request-20',
#  'ppoz-db-request-18',
#  'ppoz-db-request-17',
#  'pmuf-stat-db-02',
#  'pmuf-db-pgpool-01',
#  'pmo-services-01',
#  'pmo-etl-003',
#  'pmo-app-005',
#  'pmo-app-004',
#  'pmo-app-003',
#  'pmo-app-002',
#  'popd-geoapi-02',
#  'popd-geoimager-02',
#  'popd-bpd-adapter-04',
#  'popd-bpd-adapter-03',
#  'pkurp-redis-002',
#  'pkurp-worker-009',
#  'pkurp-worker-008',
#  'pkurp-worker-006',
#  'pkurp-worker-005',
#  'pkurp-app-008',
#  'pkurp-app-005',
#  'site-int-04',
#  'site-int-03',
#  'site-solr-04',
#  'site-solr-03',
#  'ppoz-gmp-services-07',
#  'site-liferay-srv-04',
#  'site-liferay-04',
#  'cia-sign-08',
#  'ppoz-filestorage-10',
#  'ppoz-smev-service-10',
#  'ppoz-smev-service-07',
#  'ppoz-kuvd-service-06',
#  'ppoz-kuvd-service-03',
#  'ppoz-service-external-06',
#  'ppoz-service-external-05',
#  'ppoz-service-external-03',
#  'ppoz-bus-ext-04',
#  'ppoz-bus-ext-03',
#  'ppoz-bus-command-04',
#  'ppoz-gmp-services-04',
#  'ppoz-gmp-process-06',
#  'cia-sign-05',
#  'cia-idp-core-06',
#  'cia-idp-core-04',
#  'cia-idp-core-03',
#  'cia-core-06',
#  'cia-core-04',
#  'ppoz-db-proc-ppoz-06',
#  'ppoz-db-proc-ppoz-05',
#  'ppoz-db-proc-ppoz-04',
#  'ppoz-db-proc-popd-06',
#  'ppoz-db-proc-popd-05',
#  'ppoz-db-proc-popd-04',
#  'ppoz-db-proc-pkurp-06',
#  'ppoz-db-proc-pkurp-05',
#  'pkurp-worker-021',
#  'ppoz-db-proc-pkurp-04',
#  'ppoz-db-proc-gmp-06',
#  'pkurp-worker-018',
#  'ppoz-db-proc-gmp-05',
#  'ppoz-db-proc-gmp-04',
#  'ppoz-db-proc-gmp-03',
#  'ppoz-db-request-10',
#  'pkurp-app-019',
#  'ppoz-popd-process-06',
#  'ppoz-pkurp-process-05',
#  'ppoz-pkurp-process-03',
#  'migr-arc-5',
#  'site-solr-01',
#  'site-liferay-srv-01',
#  'site-liferay-01',
#  'site-int-01',
#  'site-dstool-bal-02',
#  'site-dstool-01',
#  'site-db-02',
#  'site-bal-02',
#  'sf-solr-01',
#  'sf-front-01',
#  'sf-bal-02',
#  'sf-back-01',
#  'ppoz-smev-service-04',
#  'ppoz-smev-service-01',
#  'ppoz-smev-bal-02',
#  'ppoz-smev-bal-01',
#  'ppoz-service-bal-02',
#  'ppoz-process-core-02',
#  'ppoz-process-bal-ppoz-02',
#  'ppoz-process-bal-popd-02',
#  'ppoz-process-bal-pkurp-02',
#  'ppoz-process-bal-pkurp-01',
#  'ppoz-process-bal-gmp-02',
#  'ppoz-process-bal-gmp-01',
#  'ppoz-popd-process-01',
#  'ppoz-pkurp-process-02',
#  'ppoz-nsi-adapter-02',
#  'ppoz-kuvd-service-02',
#  'ppoz-kuvd-migration-service-59',
#  'ppoz-kuvd-migration-service-58',
#  'ppoz-kuvd-migration-service-57',
#  'ppoz-kuvd-migration-service-56',
#  'ppoz-kuvd-migration-service-55',
#  'ppoz-kuvd-migration-service-54',
#  'ppoz-kuvd-migration-service-53',
#  'ppoz-kuvd-migration-service-52',
#  'ppoz-kuvd-migration-service-51',
#  'ppoz-kuvd-migration-service-49',
#  'ppoz-kuvd-migration-service-48',
#  'ppoz-kuvd-migration-service-47',
#  'ppoz-kuvd-migration-service-46',
#  'ppoz-kuvd-migration-service-45',
#  'ppoz-kuvd-migration-service-44',
#  'ppoz-kuvd-migration-service-43',
#  'ppoz-kuvd-migration-service-42',
#  'ppoz-kuvd-migration-service-41',
#  'ppoz-kuvd-migration-service-40',
#  'ppoz-kuvd-migration-service-39',
#  'ppoz-kuvd-migration-service-37',
#  'ppoz-kuvd-migration-service-36',
#  'ppoz-kuvd-migration-service-35',
#  'ppoz-kuvd-migration-service-34',
#  'ppoz-kuvd-migration-service-33',
#  'ppoz-kuvd-migration-service-32',
#  'ppoz-kuvd-migration-service-31',
#  'ppoz-kuvd-migration-service-30',
#  'ppoz-kuvd-migration-service-29',
#  'ppoz-kuvd-migration-service-27',
#  'ppoz-kuvd-migration-service-26',
#  'ppoz-kuvd-migration-service-25',
#  'ppoz-kuvd-migration-service-23',
#  'ppoz-kuvd-migration-service-22',
#  'ppoz-kuvd-migration-service-21',
#  'ppoz-kuvd-db-20',
#  'ppoz-kuvd-db-17',
#  'ppoz-kuvd-db-11',
#  'ppoz-kuvd-db-08',
#  'ppoz-kuvd-bal-02',
#  'ppoz-gmp-services-01',
#  'ppoz-gmp-process-02',
#  'ppoz-gmp-bal-02',
#  'ppoz-filestorage-07',
#  'ppoz-db-request-05',
#  'ppoz-db-proc-ppoz-01',
#  'ppoz-db-proc-popd-02',
#  'ppoz-db-proc-popd-01',
#  'ppoz-db-proc-pkurp-01',
#  'ppoz-db-proc-gmp-01',
#  'ppoz-bus-ext-02',
#  'ppoz-bus-data-02',
#  'ppoz-bus-command-02',
#  'popd-geocdn-01',
#  'popd-geoserver-balancer-01',
#  'popd-geoimager-01',
#  'popd-workstation-balancer-01',
#  'popd-workstation-01',
#  'popd-geoworkers-01',
#  'popd-geoserver-02',
#  'popd-bpd-adapter-balancer-01',
#  'popd-bpd-08',
#  'popd-bpd-03',
#  'pmuf-rmq-01',
#  'pmuf-arm-sc-balancer-01',
#  'pmuf-arm-sc-01',
#  'pmo-services-02',
#  'pmo-etl-002',
#  'pmo-etl-001',
#  'pmo-db-pgpool-001',
#  'pmo-db-fed-pgpool-01',
#  'pmo-db-003',
#  'pmo-db-002',
#  'pmo-armedit-01',
#  'pmo-arm-edit-balancer-01',
#  'pmo-app-balancer-01',
#  'pmo-app-001',
#  'migr-node-017',
#  'migr-arc-49',
#  'isurz-writer-039',
#  'migr-node-060',
#  'migr-node-059',
#  'migr-node-058',
#  'migr-node-057',
#  'migr-node-056',
#  'migr-node-054',
#  'migr-node-053',
#  'migr-node-051',
#  'migr-node-049',
#  'migr-node-048',
#  'migr-node-045',
#  'migr-node-043',
#  'migr-node-037',
#  'migr-node-034',
#  'migr-node-033',
#  'migr-node-030',
#  'migr-node-027',
#  'migr-node-022',
#  'migr-node-021',
#  'migr-node-019',
#  'migr-node-016',
#  'migr-node-015',
#  'migr-node-014',
#  'migr-node-012',
#  'migr-node-010',
#  'migr-node-008',
#  'migr-node-007',
#  'migr-node-005',
#  'migr-node-003',
#  'migr-node-001',
#  'migr-init-03',
#  'migr-init-02',
#  'migr-init-01',
#  'migr-conf-01',
#  'migr-arc-xx',
#  'migr-arc-90',
#  'migr-arc-89',
#  'migr-arc-88',
#  'migr-arc-87',
#  'migr-arc-84',
#  'migr-arc-83',
#  'migr-arc-78',
#  'migr-arc-73',
#  'migr-arc-72',
#  'migr-arc-65',
#  'migr-arc-62',
#  'migr-arc-58',
#  'migr-arc-56',
#  'migr-arc-53',
#  'migr-arc-52',
#  'migr-arc-51',
#  'migr-arc-44',
#  'migr-arc-42',
#  'migr-arc-38',
#  'migr-arc-35',
#  'migr-arc-28',
#  'migr-arc-25',
#  'migr-arc-22',
#  'migr-arc-21',
#  'migr-arc-19',
#  'migr-arc-17',
#  'migr-arc-16',
#  'migr-arc-13',
#  'migr-arc-11',
#  'lk-ui-02',
#  'lk-ui-01',
#  'lk-srv-01',
#  'lk-rd-01',
#  'lk-db-01',
#  'lk-bal-02',
#  'lk-backend-01',
#  'isurz-writer-049',
#  'isurz-writer-044',
#  'isurz-writer-041',
#  'isurz-writer-029',
#  'isurz-writer-026',
#  'isurz-writer-023',
#  'isurz-writer-020',
#  'isurz-writer-017',
#  'isurz-writer-014',
#  'isurz-writer-011',
#  'isurz-writer-006',
#  'isurz-writer-003',
#  'isurz-uploader-020',
#  'isurz-uploader-017',
#  'isurz-uploader-014',
#  'isurz-uploader-011',
#  'isurz-uploader-007',
#  'isurz-uploader-004',
#  'isurz-uploader-003',
#  'isurz-api-12',
#  'isurz-api-10',
#  'egron-bal-outer-02',
#  'cite-bal-outer-02',
#  'cia-sign-bal-02',
#  'cia-sign-04',
#  'cia-sign-02',
#  'cia-idp-core-01',
#  'cia-idp-bal-02',
#  'cia-db-02',
#  'cia-core-bal-02',
#  'cia-core-01',
#  'isurz-api-07',
#  'isurz-xml-storage-91',
#  'isurz-xml-storage-90',
#  'isurz-xml-storage-86',
#  'isurz-xml-storage-84',
#  'isurz-xml-storage-81',
#  'isurz-xml-storage-73',
#  'isurz-xml-storage-68',
#  'isurz-xml-storage-66',
#  'isurz-xml-storage-59',
#  'isurz-xml-storage-56',
#  'isurz-xml-storage-51',
#  'isurz-xml-storage-09',
#  'isurz-xml-storage-08',
#  'isurz-xml-storage-04',
#  'isurz-xml-storage-03',
#  'isurz-xml-storage-02',
#  'pkurp-app-balancer-02',
#  'migr-gkn-oracle-89',
#  'migr-gkn-oracle-86',
#  'migr-gkn-oracle-83',
#  'migr-gkn-oracle-72',
#  'migr-gkn-oracle-70',
#  'pg-attribute-borders',
#  'pg-attribute-books',
#  'migr-gkn-oracle-78',
#  'migr-gkn-oracle-9',
#  'pg-master',
#  'pg-attribute-76',
#  'pg-attribute-71',
#  'pg-attribute-69',
#  'pg-attribute-67',
#  'pg-attribute-61',
#  'isurz-elasticsearch-05',
#  'pg-attribute-57',
#  'pg-attribute-40',
#  'pg-attribute-37',
#  'pg-attribute-33',
#  'pg-attribute-30',
#  'pg-attribute-08',
#  'pg-attribute-01',
#  'pg-map-reduce-05',
#  'pg-map-reduce-04',
#  'pg-map-reduce-02',
#  'pg-master-replica-01',
#  'DNS2_relay',
#  'mgmt-ansible-02',
#  'isurz-kibana-01',
#  'isurz-elasticsearch-01',
#  'migr-gkn-oracle-66',
#  'migr-gkn-oracle-63',
#  'migr-gkn-oracle-59',
#  'migr-gkn-oracle-54',
#  'migr-gkn-oracle-52',
#  'migr-gkn-oracle-41',
#  'migr-gkn-oracle-35',
#  'migr-gkn-oracle-26',
#  'migr-gkn-oracle-24-err',
#  'migr-gkn-oracle-20',
#  'migr-gkn-oracle-19',
#  'migr-gkn-oracle-17',
#  'migr-gkn-oracle-16',
#  'migr-gkn-oracle-13',
#  'migr-gkn-oracle-10',
#  'migr-jst-oracle-6',
#  'migr-jst-oracle-20',
#  'migr-jst-oracle-19',
#  'migr-jst-oracle-17',
#  'migr-jst-oracle-15',
#  'migr-grp-oracle-78',
#  'migr-grp-oracle-72',
#  'migr-grp-oracle-68',
#  'migr-grp-oracle-65',
#  'migr-grp-oracle-56',
#  'migr-grp-oracle-53',
#  'migr-grp-oracle-51',
#  'migr-grp-oracle-42',
#  'migr-grp-oracle-39',
#  'migr-grp-oracle-38',
#  'migr-grp-oracle-26',
#  'migr-grp-oracle-23',
#  'isurz-xml-storage-71',
#  'isurz-xml-storage-67',
#  'isurz-xml-storage-64',
#  'isurz-xml-storage-60',
#  'isurz-xml-storage-33',
#  'isurz-xml-storage-31',
#  'isurz-xml-storage-00',
#  'pmuf-zabbix-db-01',
#  'pkurp-worker-003',
#  'isurz-writer-071',
#  'isurz-writer-069',
#  'isurz-writer-064',
#  'isurz-writer-060',
#  'isurz-writer-057',
#  'isurz-writer-048',
#  'isurz-writer-046',
#  'isurz-writer-040',
#  'isurz-writer-037',
#  'isurz-writer-034',
#  'isurz-writer-031',
#  'isurz-writer-001',
#  'isurz-writer-000',
#  'isurz-uploader-balancer-01',
#  'isurz-api-balancer-01',
#  'isurz-api-06',
#  'isurz-api-05',
#  'isurz-api-03',
#  'Isurz-api-01',
#  'pkurp-redis-001',
#  'popd-bpd-01',
#  'ppoz-kuvd-migration-service-09',
#  'ppoz-kuvd-migration-service-03',
#  'ppoz-kuvd-migration-service-01',
#  'ppoz-filestorage-bal-02',
#  'ppoz-filestorage-04',
#  'ppoz-filestorage-03',
#  'ppoz-filestorage-01',
#  'isurz-uploader-076',
#  'isurz-uploader-071',
#  'isurz-uploader-067',
#  'isurz-uploader-061',
#  'isurz-uploader-060',
#  'isurz-uploader-057',
#  'isurz-uploader-048',
#  'isurz-uploader-046',
#  'isurz-uploader-040',
#  'isurz-uploader-036',
#  'isurz-uploader-032',
#  'isurz-uploader-008',
#  'isurz-uploader-000',
#  'popd-bpd-adapter-01',
#  'pmuf-zabbix-server-02',
#  'pmuf-zabbix-server-01']

# %%
otl
# Out:
# [['aizhk-order-db-01', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['aizhk-order-db-bal-01', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['aizhk-arm-service-02', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['aizhk-arm-service-01', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['aizhk-arm-bal-02', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['aizhk-arm-bal-01', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['ppoz-kuvd-migration-service-82', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['ppoz-kuvd-migration-service-81', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['ppoz-kuvd-migration-service-80', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['ppoz-popd-process-05', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['ir-app-01-01', 'cn-e8ae.egron.tnx', 'cn-e8ae.egron.tnx'],
#  ['ir-bd-01-02', 'cn-e4c2.egron.tnx', 'cn-e4c2.egron.tnx'],
#  ['ir-app-bal-02', 'cn-e4c2.egron.tnx', 'cn-e4c2.egron.tnx'],
#  ['ps-bd-bal-02', 'cn-e4c2.egron.tnx', 'cn-e4c2.egron.tnx'],
#  ['egron-elasticsearch-03', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-079', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['agent-pvd3', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['pkurp-worker-022', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['pkurp-app-037', 'cn-e810.egron.tnx', 'cn-e810.egron.tnx'],
#  ['pkurp-app-033', 'cn-e4c2.egron.tnx', 'cn-e4c2.egron.tnx'],
#  ['pkurp-app-029', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['pkurp-app-026', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['pkurp-app-025', 'cn-ed8c.egron.tnx', 'cn-ed8c.egron.tnx'],
#  ['pkurp-app-022', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['ppoz-kuvd-migration-service-63', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['ppoz-kuvd-migration-service-91', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['ppoz-kuvd-migration-service-90', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['ppoz-kuvd-migration-service-87', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['ppoz-kuvd-migration-service-79', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['ppoz-kuvd-migration-service-78', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['ppoz-kuvd-migration-service-76', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['ppoz-kuvd-migration-service-75', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['ppoz-kuvd-migration-service-74', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-71', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-69', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-68', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-65', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['migr-arc-50', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['isurz-xml-storage-82', 'cn-e4b8.egron.tnx', 'cn-e4b8.egron.tnx'],
#  ['isurz-xml-storage-85', 'cn-dc8e.egron.tnx', 'cn-dc8e.egron.tnx'],
#  ['migr-analitycs-01', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['isurz-mq-06', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['isurz-bpd-inserter-01', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['pg-v1-attribute-33', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['pg-mq-03', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['ppoz-db-fs-bkp-08', 'cn-e128.egron.tnx', 'cn-e128.egron.tnx'],
#  ['ppoz-db-fs-bkp-05', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['ppoz-db-fs-bkp-04', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['ppoz-db-fs-bkp-01', 'cn-e810.egron.tnx', 'cn-e810.egron.tnx'],
#  ['ppoz-db-fs-29', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['ppoz-db-fs-27', 'cn-dca8.egron.tnx', 'cn-dca8.egron.tnx'],
#  ['ppoz-db-fs-25', 'cn-dc8c.egron.tnx', 'cn-dc8c.egron.tnx'],
#  ['ppoz-db-fs-21', 'cn-db3e.egron.tnx', 'cn-db3e.egron.tnx'],
#  ['ppoz-db-fs-20', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['ppoz-db-fs-17', 'cn-e612.egron.tnx', 'cn-e612.egron.tnx'],
#  ['ppoz-db-fs-14', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['ppoz-db-fs-11', 'cn-d724.egron.tnx', 'cn-d724.egron.tnx'],
#  ['ppoz-db-fs-08', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['ppoz-db-fs-05', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['ppoz-db-fs-02', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['ppoz-db-fs-01', 'cn-ed8c.egron.tnx', 'cn-ed8c.egron.tnx'],
#  ['pkurp-app-readonly-01', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['isurz-api-16', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['isurz-api-13', 'cn-dca6.egron.tnx', 'cn-dca6.egron.tnx'],
#  ['migr-arc-test', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['migr-node-200', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-199', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-198', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-197', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-196', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-195', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-194', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-193', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-192', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-191', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-190', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-189', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-188', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-187', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-186', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-185', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-184', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-183', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-182', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-181', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-180', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-179', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-178', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-177', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-176', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-175', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-174', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['migr-node-173', 'cn-e4ba.egron.tnx', 'cn-e4ba.egron.tnx'],
#  ['ppoz-service-validation-06', 'cn-e4b8.egron.tnx', 'cn-e4b8.egron.tnx'],
#  ['ppoz-service-validation-04', 'cn-dcaa.egron.tnx', 'cn-dcaa.egron.tnx'],
#  ['ppoz-service-validation-03', 'cn-dcaa.egron.tnx', 'cn-dcaa.egron.tnx'],
#  ['migr-arc-76', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-arc-71', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-arc-69', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-arc-61', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-arc-57', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['migr-arc-48', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-arc-46', 'cn-e13e.egron.tnx', 'cn-e13e.egron.tnx'],
#  ['migr-arc-37', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-arc-33', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-arc-32', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-172', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-171', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-170', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-169', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-168', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-167', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-166', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-165', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-arc-31', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['migr-arc-30', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-arc-8', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-164', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-163', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-162', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-161', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-160', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-159', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-node-158', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-157', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-156', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-155', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-154', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-153', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-152', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-151', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-150', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-149', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-148', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-147', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-146', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-145', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-144', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-143', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-142', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-141', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-140', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['migr-node-139', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-138', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-137', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-136', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-135', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-134', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-133', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-132', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-130', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-129', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-128', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-127', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-126', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-125', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-124', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-123', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-122', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-121', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-120', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-119', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-118', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-117', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-116', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-115', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-114', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-113', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-111', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-109', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-108', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-107', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-104', 'cn-da1e.egron.tnx', 'cn-da1e.egron.tnx'],
#  ['migr-node-103', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-102', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-101', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-100', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-099', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-098', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-097', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-096', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-095', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-094', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-093', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-092', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-091', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-090', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-089', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-088', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-087', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-086', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-085', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-084', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-083', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-082', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-081', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-080', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-078', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-077', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-075', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-074', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-073', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-072', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-071', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-070', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-node-069', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-065', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['migr-node-064', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-node-062', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-node-068', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-node-067', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-node-066', 'cn-e826.egron.tnx', 'cn-e826.egron.tnx'],
#  ['migr-node-063', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-061', 'cn-da18.egron.tnx', 'cn-da18.egron.tnx'],
#  ['migr-arc-1', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['isurz-xml-storage-42', 'cn-ed8c.egron.tnx', 'cn-ed8c.egron.tnx'],
#  ['mdr-app-001-2', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['pg-mq-01-standby', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['pg-mq-01', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['pg-attribute-07', 'cn-da22.egron.tnx', 'cn-da22.egron.tnx'],
#  ['egron-mgmt-01', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['pkurp-consumer-002', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['pkurp-consumer-001', 'cn-e13a.egron.tnx', 'cn-e13a.egron.tnx'],
#  ['isurz-mq-04', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['s_hdd', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['pg-master-replica-standby-01', 'cn-ed8e.egron.tnx', 'cn-ed8e.egron.tnx'],
#  ['migr-gkn-oracle-64', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-grp-oracle-60', 'cn-e4bc.egron.tnx', 'cn-e4bc.egron.tnx'],
#  ['migr-gkn-oracle-60', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-grp-oracle-67', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-gkn-oracle-76', 'cn-e620.egron.tnx', 'cn-e620.egron.tnx'],
#  ['migr-gkn-oracle-69', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-gkn-oracle-67', 'cn-da4a.egron.tnx', 'cn-da4a.egron.tnx'],
#  ['migr-gkn-oracle-57', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['migr-gkn-oracle-46', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['migr-gkn-oracle-40', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['migr-grp-oracle-37', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['migr-grp-oracle-33', 'cn-dcaa.egron.tnx', 'cn-dcaa.egron.tnx'],
#  ['migr-gkn-oracle-32', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['migr-jst-oracle-31', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['migr-jst-oracle-30', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['migr-jst-oracle-08', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['migr-gkn-oracle-08', 'cn-daa6.egron.tnx', 'cn-daa6.egron.tnx'],
#  ['migr-jst-oracle-01', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['mgmt-bacula-catalog', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['pg-pool-01', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['nsi-tasks-02', 'cn-dca8.egron.tnx', 'cn-dca8.egron.tnx'],
#  ['nsi-db-02', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['nsi-app-02', 'cn-dca6.egron.tnx', 'cn-dca6.egron.tnx'],
#  ['nsi-app-01', 'cn-db28.egron.tnx', 'cn-db28.egron.tnx'],
#  ['nsi-bal-02', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['nsi-bal-01', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['migr-reporter-01', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['ppoz-kuvd-db-bkp-01', 'cn-dca6.egron.tnx', 'cn-dca6.egron.tnx'],
#  ['migr-init-bkp-01', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['migr-conf-bkp-01', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['ppoz-db-request-bkp-11', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['ppoz-db-request-bkp-08', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['ppoz-db-request-bkp-06', 'cn-db28.egron.tnx', 'cn-db28.egron.tnx'],
#  ['ppoz-db-request-bkp-05', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['ppoz-kuvd-db-bkp-06', 'cn-db28.egron.tnx', 'cn-db28.egron.tnx'],
#  ['ppoz-kuvd-db-bkp-05', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['pkurp-dev-01', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['pkurp-report-01', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['isurz-mq-01', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['egron-elasticsearch-01', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['egron-kibana-02', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['egron-elasticsearch-04', 'cn-dc84.egron.tnx', 'cn-dc84.egron.tnx'],
#  ['mdr-db-002', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['mgmt-repository-01', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['Hmdr-bus-app-001', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['ir-bd-01', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['ir-app-gi-04', 'cn-e810.egron.tnx', 'cn-e810.egron.tnx'],
#  ['ir-app-gi-01', 'cn-e810.egron.tnx', 'cn-e810.egron.tnx'],
#  ['ir-app-lk-04', 'cn-e810.egron.tnx', 'cn-e810.egron.tnx'],
#  ['ir-app-out-04', 'cn-e810.egron.tnx', 'cn-e810.egron.tnx'],
#  ['ir-app-lk-03', 'cn-da22.egron.tnx', 'cn-da22.egron.tnx'],
#  ['ir-app-out-03', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['ir-app-out-02', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['ir-app-out-01', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['ir-app-in-04', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['ir-app-in-01', 'cn-da22.egron.tnx', 'cn-da22.egron.tnx'],
#  ['ir-bd-07', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['ir-bd-05', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['ir-bd-04', 'cn-da22.egron.tnx', 'cn-da22.egron.tnx'],
#  ['ir-bd-03', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['ir-bd-02', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['ir-app-gi-bal-01', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['ir-app-lk-bal-01', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['ir-app-out-bal-01', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['ir-app-in-bal-01', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['ir-bd-bal-01', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['zbx_bcp', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['migr-oracle-replicastore-01', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['pg-attribute-right-registry-entities',
#   'cn-e612.egron.tnx',
#   'cn-e612.egron.tnx'],
#  ['pg-attribute-standby-82', 'cn-e13e.egron.tnx', 'cn-e13e.egron.tnx'],
#  ['pg-attribute-standby-80', 'cn-dc8c.egron.tnx', 'cn-dc8c.egron.tnx'],
#  ['pg-attribute-82', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['pg-attribute-standby-right-registry-entities',
#   'cn-ed8e.egron.tnx',
#   'cn-ed8e.egron.tnx'],
#  ['pmuf-arm-sc-02', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['lk-srzu-db-01', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['lk-srzu-gi-01', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['lk-srzu-ir-02', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['lk-srzu-ir-01', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['migr-arc-85', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['migr-arc-81', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['migr-arc-82', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['migr-gkn-oracle-50', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['migr-gkn-oracle-0', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['migr-grp-oracle-82', 'cn-dce2.egron.tnx', 'cn-dce2.egron.tnx'],
#  ['migr-grp-oracle-50', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['popd-geoapi-balancer-01', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['migr-arc-43', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['migr-grp-oracle-74', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['pg-attribute-19', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['pg-attribute-27', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['pmo-db-fed-03', 'cn-e13c.egron.tnx', 'cn-e13c.egron.tnx'],
#  ['popd-bpd-05', 'cn-e128.egron.tnx', 'cn-e128.egron.tnx'],
#  ['popd-bpd-balancer-01', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['cia-db-03', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['pmuf-zabbix-proxy-01', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['pg-attribute-85', 'cn-ed8e.egron.tnx', 'cn-ed8e.egron.tnx'],
#  ['pg-attribute-83', 'cn-da1e.egron.tnx', 'cn-da1e.egron.tnx'],
#  ['pg-attribute-75', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['pg-attribute-70', 'cn-e128.egron.tnx', 'cn-e128.egron.tnx'],
#  ['pg-attribute-65', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['pg-attribute-63', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['pg-attribute-62', 'cn-daa0.egron.tnx', 'cn-daa0.egron.tnx'],
#  ['pg-attribute-59', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['pg-attribute-53', 'cn-e13a.egron.tnx', 'cn-e13a.egron.tnx'],
#  ['pg-attribute-49', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx'],
#  ['pg-attribute-47', 'cn-dc8e.egron.tnx', 'cn-dc8e.egron.tnx'],
#  ['pg-attribute-28', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['pg-attribute-25', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['pg-attribute-17', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['pg-attribute-11', 'cn-db3e.egron.tnx', 'cn-db3e.egron.tnx'],
#  ['pg-attribute-10', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['pg-attribute-05', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['pg-attribute-02', 'cn-dc8c.egron.tnx', 'cn-dc8c.egron.tnx'],
#  ['pg-attribute-86', 'cn-db28.egron.tnx', 'cn-db28.egron.tnx'],
#  ['pg-attribute-22', 'cn-dca8.egron.tnx', 'cn-dca8.egron.tnx'],
#  ['pg-attribute-21', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['pg-attribute-18', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['pg-attribute-15', 'cn-dc8e.egron.tnx', 'cn-dc8e.egron.tnx'],
#  ['pg-attribute-07_orphan', 'cn-d724.egron.tnx', 'cn-d724.egron.tnx'],
#  ['pg-attribute-04', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['pg-attribute-03', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx'],
#  ['pg-attribute-standby-35', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['pg-attribute-standby-33', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['pg-attribute-standby-36', 'cn-dcaa.egron.tnx', 'cn-dcaa.egron.tnx'],
#  ['pg-attribute-standby-32', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['pg-attribute-standby-37', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['pg-attribute-standby-38', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['pg-attribute-standby-30', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['pg-attribute-standby-39', 'cn-e13e.egron.tnx', 'cn-e13e.egron.tnx'],
#  ['pg-attribute-standby-40', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['pg-attribute-standby-27', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['pg-attribute-standby-42', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['pg-attribute-standby-43', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['pg-attribute-standby-22', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['pg-attribute-standby-47', 'cn-e612.egron.tnx', 'cn-e612.egron.tnx'],
#  ['pg-attribute-standby-49', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['pg-attribute-standby-19', 'cn-d724.egron.tnx', 'cn-d724.egron.tnx'],
#  ['pg-attribute-standby-51', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['pg-attribute-standby-17', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['pg-attribute-standby-52', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['pg-attribute-standby-15', 'cn-e13c.egron.tnx', 'cn-e13c.egron.tnx'],
#  ['pg-attribute-standby-54', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['pg-attribute-standby-55', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['pg-attribute-standby-56', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['pg-attribute-standby-12', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['pg-attribute-standby-57', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['pg-attribute-standby-58', 'cn-ed8c.egron.tnx', 'cn-ed8c.egron.tnx'],
#  ['pg-attribute-standby-59', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['pg-attribute-standby-08', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['pg-attribute-standby-07', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['pg-attribute-standby-62', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['pg-attribute-standby-63', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['pg-attribute-standby-05', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['pg-attribute-standby-03', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['pg-attribute-standby-66', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['pg-attribute-standby-02', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['pg-attribute-standby-67', 'cn-d724.egron.tnx', 'cn-d724.egron.tnx'],
#  ['pg-attribute-standby-01', 'cn-e612.egron.tnx', 'cn-e612.egron.tnx'],
#  ['pg-attribute-standby-68', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['pg-reservation-01-standby', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['pg-attribute-standby-72', 'cn-e13c.egron.tnx', 'cn-e13c.egron.tnx'],
#  ['pg-attribute-standby-74', 'cn-ed8e.egron.tnx', 'cn-ed8e.egron.tnx'],
#  ['pkurp-worker-015', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['pg-attribute-standby-75', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['pg-attribute-standby-76', 'cn-dce2.egron.tnx', 'cn-dce2.egron.tnx'],
#  ['pkurp-worker-012', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['pg-attribute-standby-78', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['pg-attribute-standby-79', 'cn-dc8e.egron.tnx', 'cn-dc8e.egron.tnx'],
#  ['pkurp-app-014', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['pg-attribute-standby-85', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['pg-attribute-standby-86', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['pkurp-app-011', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['lk-srv-04', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['lk-srv-03', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['lk-backend-04', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['pg-attribute-standby-90', 'cn-dc8c.egron.tnx', 'cn-dc8c.egron.tnx'],
#  ['lk-rd-04', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['pg-attribute-standby-borders', 'cn-da1e.egron.tnx', 'cn-da1e.egron.tnx'],
#  ['lk-rd-03', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['pg-attribute-standby-books', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['lk-db-04', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['popd-geoserver-05', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['popd-geoserver-06', 'cn-ed8c.egron.tnx', 'cn-ed8c.egron.tnx'],
#  ['site-dstool-04', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['popd-geoserver-08', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['sf-solr-04', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['popd-geoworkers-03', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['sf-back-04', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['popd-geoimager-03', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['sf-front-04', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['popd-geoapi-04', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['popd-geoapi-05', 'cn-e8ae.egron.tnx', 'cn-e8ae.egron.tnx'],
#  ['site-liferay-srv-10', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['popd-geoapi-07', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['site-liferay-srv-07', 'cn-e13c.egron.tnx', 'cn-e13c.egron.tnx'],
#  ['popd-workstation-03', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['site-liferay-10', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['site-liferay-07', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['cia-idp-core-10', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['cia-idp-core-08', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx'],
#  ['cia-idp-core-07', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['cia-sign-20', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['pmo-app-006', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['pmo-app-007', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['cia-sign-17', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['pmo-app-008', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['pmo-app-009', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['pmo-app-010', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['cia-sign-14', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['pmo-armedit-03', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['isurz-elasticsearch-07', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['cia-sign-11', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['pkurp-elasticsearch-04', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['cia-core-10', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['isurz-elasticsearch-03', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['isurz-elasticsearch-04', 'cn-dce2.egron.tnx', 'cn-dce2.egron.tnx'],
#  ['cia-core-07', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['ppoz-db-proc-popd-07', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['ppoz-db-proc-gmp-07', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['ppoz-db-proc-pkurp-07', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['ppoz-db-proc-ppoz-07', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['ppoz-db-request-29', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['ppoz-db-request-26', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['ppoz-db-request-23', 'cn-e13e.egron.tnx', 'cn-e13e.egron.tnx'],
#  ['ppoz-db-request-20', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['ppoz-db-request-18', 'cn-dc84.egron.tnx', 'cn-dc84.egron.tnx'],
#  ['ppoz-db-request-17', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['pmuf-stat-db-02', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['pmuf-db-pgpool-01', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['pmo-services-01', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['pmo-etl-003', 'cn-d724.egron.tnx', 'cn-d724.egron.tnx'],
#  ['pmo-app-005', 'cn-e128.egron.tnx', 'cn-e128.egron.tnx'],
#  ['pmo-app-004', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['pmo-app-003', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['pmo-app-002', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['popd-geoapi-02', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['popd-geoimager-02', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['popd-bpd-adapter-04', 'cn-e13a.egron.tnx', 'cn-e13a.egron.tnx'],
#  ['popd-bpd-adapter-03', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['pkurp-redis-002', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['pkurp-worker-009', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['pkurp-worker-008', 'cn-db3e.egron.tnx', 'cn-db3e.egron.tnx'],
#  ['pkurp-worker-006', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['pkurp-worker-005', 'cn-dca6.egron.tnx', 'cn-dca6.egron.tnx'],
#  ['pkurp-app-008', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['pkurp-app-005', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['site-int-04', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['site-int-03', 'cn-da1e.egron.tnx', 'cn-da1e.egron.tnx'],
#  ['site-solr-04', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['site-solr-03', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['ppoz-gmp-services-07', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['site-liferay-srv-04', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['site-liferay-04', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['cia-sign-08', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['ppoz-filestorage-10', 'cn-e612.egron.tnx', 'cn-e612.egron.tnx'],
#  ['ppoz-smev-service-10', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['ppoz-smev-service-07', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['ppoz-kuvd-service-06', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['ppoz-kuvd-service-03', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['ppoz-service-external-06', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['ppoz-service-external-05', 'cn-da1e.egron.tnx', 'cn-da1e.egron.tnx'],
#  ['ppoz-service-external-03', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['ppoz-bus-ext-04', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['ppoz-bus-ext-03', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['ppoz-bus-command-04', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['ppoz-gmp-services-04', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['ppoz-gmp-process-06', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['cia-sign-05', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['cia-idp-core-06', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['cia-idp-core-04', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['cia-idp-core-03', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['cia-core-06', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['cia-core-04', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['ppoz-db-proc-ppoz-06', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['ppoz-db-proc-ppoz-05', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['ppoz-db-proc-ppoz-04', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['ppoz-db-proc-popd-06', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['ppoz-db-proc-popd-05', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['ppoz-db-proc-popd-04', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['ppoz-db-proc-pkurp-06', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['ppoz-db-proc-pkurp-05', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['pkurp-worker-021', 'cn-db28.egron.tnx', 'cn-db28.egron.tnx'],
#  ['ppoz-db-proc-pkurp-04', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['ppoz-db-proc-gmp-06', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['pkurp-worker-018', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['ppoz-db-proc-gmp-05', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['ppoz-db-proc-gmp-04', 'cn-dca8.egron.tnx', 'cn-dca8.egron.tnx'],
#  ['ppoz-db-proc-gmp-03', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['ppoz-db-request-10', 'cn-fe1a.egron.tnx', 'cn-fe1a.egron.tnx'],
#  ['pkurp-app-019', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['ppoz-popd-process-06', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['ppoz-pkurp-process-05', 'cn-fdec.egron.tnx', 'cn-fdec.egron.tnx'],
#  ['ppoz-pkurp-process-03', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['migr-arc-5', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['site-solr-01', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['site-liferay-srv-01', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['site-liferay-01', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['site-int-01', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['site-dstool-bal-02', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['site-dstool-01', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['site-db-02', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['site-bal-02', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['sf-solr-01', 'cn-ed8e.egron.tnx', 'cn-ed8e.egron.tnx'],
#  ['sf-front-01', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['sf-bal-02', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['sf-back-01', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['ppoz-smev-service-04', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['ppoz-smev-service-01', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['ppoz-smev-bal-02', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['ppoz-smev-bal-01', 'cn-da22.egron.tnx', 'cn-da22.egron.tnx'],
#  ['ppoz-service-bal-02', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['ppoz-process-core-02', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['ppoz-process-bal-ppoz-02', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['ppoz-process-bal-popd-02', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['ppoz-process-bal-pkurp-02', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['ppoz-process-bal-pkurp-01', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['ppoz-process-bal-gmp-02', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['ppoz-process-bal-gmp-01', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['ppoz-popd-process-01', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['ppoz-pkurp-process-02', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['ppoz-nsi-adapter-02', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['ppoz-kuvd-service-02', 'cn-e612.egron.tnx', 'cn-e612.egron.tnx'],
#  ['ppoz-kuvd-migration-service-59', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-58', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['ppoz-kuvd-migration-service-57', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['ppoz-kuvd-migration-service-56', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['ppoz-kuvd-migration-service-55', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-54', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['ppoz-kuvd-migration-service-53', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['ppoz-kuvd-migration-service-52', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-51', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['ppoz-kuvd-migration-service-49', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['ppoz-kuvd-migration-service-48', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['ppoz-kuvd-migration-service-47', 'cn-e8ae.egron.tnx', 'cn-e8ae.egron.tnx'],
#  ['ppoz-kuvd-migration-service-46', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['ppoz-kuvd-migration-service-45', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-44', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['ppoz-kuvd-migration-service-43', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['ppoz-kuvd-migration-service-42', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['ppoz-kuvd-migration-service-41', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['ppoz-kuvd-migration-service-40', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['ppoz-kuvd-migration-service-39', 'cn-e128.egron.tnx', 'cn-e128.egron.tnx'],
#  ['ppoz-kuvd-migration-service-37', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['ppoz-kuvd-migration-service-36', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['ppoz-kuvd-migration-service-35', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['ppoz-kuvd-migration-service-34', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-33', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['ppoz-kuvd-migration-service-32', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['ppoz-kuvd-migration-service-31', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['ppoz-kuvd-migration-service-30', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-29', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['ppoz-kuvd-migration-service-27', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['ppoz-kuvd-migration-service-26', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['ppoz-kuvd-migration-service-25', 'cn-e8ae.egron.tnx', 'cn-e8ae.egron.tnx'],
#  ['ppoz-kuvd-migration-service-23', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['ppoz-kuvd-migration-service-22', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['ppoz-kuvd-migration-service-21', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['ppoz-kuvd-db-20', 'cn-d724.egron.tnx', 'cn-d724.egron.tnx'],
#  ['ppoz-kuvd-db-17', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['ppoz-kuvd-db-11', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['ppoz-kuvd-db-08', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['ppoz-kuvd-bal-02', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['ppoz-gmp-services-01', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['ppoz-gmp-process-02', 'cn-e13c.egron.tnx', 'cn-e13c.egron.tnx'],
#  ['ppoz-gmp-bal-02', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['ppoz-filestorage-07', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['ppoz-db-request-05', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['ppoz-db-proc-ppoz-01', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['ppoz-db-proc-popd-02', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['ppoz-db-proc-popd-01', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['ppoz-db-proc-pkurp-01', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['ppoz-db-proc-gmp-01', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['ppoz-bus-ext-02', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['ppoz-bus-data-02', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['ppoz-bus-command-02', 'cn-d724.egron.tnx', 'cn-d724.egron.tnx'],
#  ['popd-geocdn-01', 'cn-da1e.egron.tnx', 'cn-da1e.egron.tnx'],
#  ['popd-geoserver-balancer-01', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['popd-geoimager-01', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['popd-workstation-balancer-01', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['popd-workstation-01', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['popd-geoworkers-01', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['popd-geoserver-02', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['popd-bpd-adapter-balancer-01', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['popd-bpd-08', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['popd-bpd-03', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['pmuf-rmq-01', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['pmuf-arm-sc-balancer-01', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['pmuf-arm-sc-01', 'cn-e13e.egron.tnx', 'cn-e13e.egron.tnx'],
#  ['pmo-services-02', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['pmo-etl-002', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['pmo-etl-001', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['pmo-db-pgpool-001', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['pmo-db-fed-pgpool-01', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['pmo-db-003', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['pmo-db-002', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['pmo-armedit-01', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['pmo-arm-edit-balancer-01', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['pmo-app-balancer-01', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['pmo-app-001', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['migr-node-017', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-arc-49', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['isurz-writer-039', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['migr-node-060', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['migr-node-059', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['migr-node-058', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['migr-node-057', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['migr-node-056', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['migr-node-054', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['migr-node-053', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['migr-node-051', 'cn-e89a.egron.tnx', 'cn-e89a.egron.tnx'],
#  ['migr-node-049', 'cn-de10.egron.tnx', 'cn-de10.egron.tnx'],
#  ['migr-node-048', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['migr-node-045', 'cn-e13e.egron.tnx', 'cn-e13e.egron.tnx'],
#  ['migr-node-043', 'cn-db0a.egron.tnx', 'cn-db0a.egron.tnx'],
#  ['migr-node-037', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['migr-node-034', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['migr-node-033', 'cn-e13e.egron.tnx', 'cn-e13e.egron.tnx'],
#  ['migr-node-030', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['migr-node-027', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['migr-node-022', 'cn-da1e.egron.tnx', 'cn-da1e.egron.tnx'],
#  ['migr-node-021', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['migr-node-019', 'cn-db08.egron.tnx', 'cn-db08.egron.tnx'],
#  ['migr-node-016', 'cn-da48.egron.tnx', 'cn-da48.egron.tnx'],
#  ['migr-node-015', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['migr-node-014', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['migr-node-012', 'cn-e128.egron.tnx', 'cn-e128.egron.tnx'],
#  ['migr-node-010', 'cn-e612.egron.tnx', 'cn-e612.egron.tnx'],
#  ['migr-node-008', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['migr-node-007', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['migr-node-005', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['migr-node-003', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['migr-node-001', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['migr-init-03', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-init-02', 'cn-e828.egron.tnx', 'cn-e828.egron.tnx'],
#  ['migr-init-01', 'cn-e810.egron.tnx', 'cn-e810.egron.tnx'],
#  ['migr-conf-01', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['migr-arc-xx', 'cn-e13c.egron.tnx', 'cn-e13c.egron.tnx'],
#  ['migr-arc-90', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['migr-arc-89', 'cn-d724.egron.tnx', 'cn-d724.egron.tnx'],
#  ['migr-arc-88', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['migr-arc-87', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['migr-arc-84', 'cn-ed8e.egron.tnx', 'cn-ed8e.egron.tnx'],
#  ['migr-arc-83', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['migr-arc-78', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['migr-arc-73', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['migr-arc-72', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['migr-arc-65', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['migr-arc-62', 'cn-e8ae.egron.tnx', 'cn-e8ae.egron.tnx'],
#  ['migr-arc-58', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['migr-arc-56', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['migr-arc-53', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['migr-arc-52', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['migr-arc-51', 'cn-e13c.egron.tnx', 'cn-e13c.egron.tnx'],
#  ['migr-arc-44', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['migr-arc-42', 'cn-e128.egron.tnx', 'cn-e128.egron.tnx'],
#  ['migr-arc-38', 'cn-e612.egron.tnx', 'cn-e612.egron.tnx'],
#  ['migr-arc-35', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['migr-arc-28', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['migr-arc-25', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['migr-arc-22', 'cn-da1e.egron.tnx', 'cn-da1e.egron.tnx'],
#  ['migr-arc-21', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['migr-arc-19', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['migr-arc-17', 'cn-d724.egron.tnx', 'cn-d724.egron.tnx'],
#  ['migr-arc-16', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['migr-arc-13', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['migr-arc-11', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['lk-ui-02', 'cn-fdc6.egron.tnx', 'cn-fdc6.egron.tnx'],
#  ['lk-ui-01', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['lk-srv-01', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['lk-rd-01', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['lk-db-01', 'cn-e612.egron.tnx', 'cn-e612.egron.tnx'],
#  ['lk-bal-02', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['lk-backend-01', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['isurz-writer-049', 'cn-e8ae.egron.tnx', 'cn-e8ae.egron.tnx'],
#  ['isurz-writer-044', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['isurz-writer-041', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['isurz-writer-029', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['isurz-writer-026', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['isurz-writer-023', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['isurz-writer-020', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['isurz-writer-017', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['isurz-writer-014', 'cn-e8ae.egron.tnx', 'cn-e8ae.egron.tnx'],
#  ['isurz-writer-011', 'cn-dcec.egron.tnx', 'cn-dcec.egron.tnx'],
#  ['isurz-writer-006', 'cn-e814.egron.tnx', 'cn-e814.egron.tnx'],
#  ['isurz-writer-003', 'cn-db76.egron.tnx', 'cn-db76.egron.tnx'],
#  ['isurz-uploader-020', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['isurz-uploader-017', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['isurz-uploader-014', 'cn-e612.egron.tnx', 'cn-e612.egron.tnx'],
#  ['isurz-uploader-011', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['isurz-uploader-007', 'cn-e128.egron.tnx', 'cn-e128.egron.tnx'],
#  ['isurz-uploader-004', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['isurz-uploader-003', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['isurz-api-12', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['isurz-api-10', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['egron-bal-outer-02', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['cite-bal-outer-02', 'cn-e8a8.egron.tnx', 'cn-e8a8.egron.tnx'],
#  ['cia-sign-bal-02', 'cn-e13c.egron.tnx', 'cn-e13c.egron.tnx'],
#  ['cia-sign-04', 'cn-e4b8.egron.tnx', 'cn-e4b8.egron.tnx'],
#  ['cia-sign-02', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['cia-idp-core-01', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['cia-idp-bal-02', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['cia-db-02', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['cia-core-bal-02', 'cn-e8b6.egron.tnx', 'cn-e8b6.egron.tnx'],
#  ['cia-core-01', 'cn-e13c.egron.tnx', 'cn-e13c.egron.tnx'],
#  ['isurz-api-07', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['isurz-xml-storage-91', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['isurz-xml-storage-90', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['isurz-xml-storage-86', 'cn-da22.egron.tnx', 'cn-da22.egron.tnx'],
#  ['isurz-xml-storage-84', 'cn-db3e.egron.tnx', 'cn-db3e.egron.tnx'],
#  ['isurz-xml-storage-81', 'cn-daa0.egron.tnx', 'cn-daa0.egron.tnx'],
#  ['isurz-xml-storage-73', 'cn-e13a.egron.tnx', 'cn-e13a.egron.tnx'],
#  ['isurz-xml-storage-68', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['isurz-xml-storage-66', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['isurz-xml-storage-59', 'cn-db28.egron.tnx', 'cn-db28.egron.tnx'],
#  ['isurz-xml-storage-56', 'cn-e4c2.egron.tnx', 'cn-e4c2.egron.tnx'],
#  ['isurz-xml-storage-51', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx'],
#  ['isurz-xml-storage-09', 'cn-ed8c.egron.tnx', 'cn-ed8c.egron.tnx'],
#  ['isurz-xml-storage-08', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['isurz-xml-storage-04', 'cn-db32.egron.tnx', 'cn-db32.egron.tnx'],
#  ['isurz-xml-storage-03', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['isurz-xml-storage-02', 'cn-db3e.egron.tnx', 'cn-db3e.egron.tnx'],
#  ['pkurp-app-balancer-02', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['migr-gkn-oracle-89', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx'],
#  ['migr-gkn-oracle-86', 'cn-dce2.egron.tnx', 'cn-dce2.egron.tnx'],
#  ['migr-gkn-oracle-83', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-gkn-oracle-72', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['migr-gkn-oracle-70', 'cn-dce2.egron.tnx', 'cn-dce2.egron.tnx'],
#  ['pg-attribute-borders', 'cn-ed8e.egron.tnx', 'cn-ed8e.egron.tnx'],
#  ['pg-attribute-books', 'cn-ed8e.egron.tnx', 'cn-ed8e.egron.tnx'],
#  ['migr-gkn-oracle-78', 'cn-da32.egron.tnx', 'cn-da32.egron.tnx'],
#  ['migr-gkn-oracle-9', 'cn-e0dc.egron.tnx', 'cn-e0dc.egron.tnx'],
#  ['pg-master', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['pg-attribute-76', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['pg-attribute-71', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['pg-attribute-69', 'cn-e672.egron.tnx', 'cn-e672.egron.tnx'],
#  ['pg-attribute-67', 'cn-daa0.egron.tnx', 'cn-daa0.egron.tnx'],
#  ['pg-attribute-61', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['isurz-elasticsearch-05', 'cn-dc8c.egron.tnx', 'cn-dc8c.egron.tnx'],
#  ['pg-attribute-57', 'cn-da46.egron.tnx', 'cn-da46.egron.tnx'],
#  ['pg-attribute-40', 'cn-ed8c.egron.tnx', 'cn-ed8c.egron.tnx'],
#  ['pg-attribute-37', 'cn-dc6c.egron.tnx', 'cn-dc6c.egron.tnx'],
#  ['pg-attribute-33', 'cn-e13a.egron.tnx', 'cn-e13a.egron.tnx'],
#  ['pg-attribute-30', 'cn-e4b8.egron.tnx', 'cn-e4b8.egron.tnx'],
#  ['pg-attribute-08', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['pg-attribute-01', 'cn-db26.egron.tnx', 'cn-db26.egron.tnx'],
#  ['pg-map-reduce-05', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['pg-map-reduce-04', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['pg-map-reduce-02', 'cn-ed8e.egron.tnx', 'cn-ed8e.egron.tnx'],
#  ['pg-master-replica-01', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['DNS2_relay', 'cn-e8aa.egron.tnx', 'cn-e8aa.egron.tnx'],
#  ['mgmt-ansible-02', 'cn-db3e.egron.tnx', 'cn-db3e.egron.tnx'],
#  ['isurz-kibana-01', 'cn-da14.egron.tnx', 'cn-da14.egron.tnx'],
#  ['isurz-elasticsearch-01', 'cn-e13a.egron.tnx', 'cn-e13a.egron.tnx'],
#  ['migr-gkn-oracle-66', 'cn-dc84.egron.tnx', 'cn-dc84.egron.tnx'],
#  ['migr-gkn-oracle-63', 'cn-dcaa.egron.tnx', 'cn-dcaa.egron.tnx'],
#  ['migr-gkn-oracle-59', 'cn-e4c2.egron.tnx', 'cn-e4c2.egron.tnx'],
#  ['migr-gkn-oracle-54', 'cn-e816.egron.tnx', 'cn-e816.egron.tnx'],
#  ['migr-gkn-oracle-52', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-gkn-oracle-41', 'cn-da74.egron.tnx', 'cn-da74.egron.tnx'],
#  ['migr-gkn-oracle-35', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['migr-gkn-oracle-26', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['migr-gkn-oracle-24-err', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['migr-gkn-oracle-20', 'cn-daa0.egron.tnx', 'cn-daa0.egron.tnx'],
#  ['migr-gkn-oracle-19', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-gkn-oracle-17', 'cn-e82a.egron.tnx', 'cn-e82a.egron.tnx'],
#  ['migr-gkn-oracle-16', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['migr-gkn-oracle-13', 'cn-da44.egron.tnx', 'cn-da44.egron.tnx'],
#  ['migr-gkn-oracle-10', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['migr-jst-oracle-6', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-jst-oracle-20', 'cn-da1a.egron.tnx', 'cn-da1a.egron.tnx'],
#  ['migr-jst-oracle-19', 'cn-dca8.egron.tnx', 'cn-dca8.egron.tnx'],
#  ['migr-jst-oracle-17', 'cn-e80c.egron.tnx', 'cn-e80c.egron.tnx'],
#  ['migr-jst-oracle-15', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['migr-grp-oracle-78', 'cn-da22.egron.tnx', 'cn-da22.egron.tnx'],
#  ['migr-grp-oracle-72', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-grp-oracle-68', 'cn-dca6.egron.tnx', 'cn-dca6.egron.tnx'],
#  ['migr-grp-oracle-65', 'cn-e4c2.egron.tnx', 'cn-e4c2.egron.tnx'],
#  ['migr-grp-oracle-56', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-grp-oracle-53', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx'],
#  ['migr-grp-oracle-51', 'cn-dc8e.egron.tnx', 'cn-dc8e.egron.tnx'],
#  ['migr-grp-oracle-42', 'cn-dce2.egron.tnx', 'cn-dce2.egron.tnx'],
#  ['migr-grp-oracle-39', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-grp-oracle-38', 'cn-e0ba.egron.tnx', 'cn-e0ba.egron.tnx'],
#  ['migr-grp-oracle-26', 'cn-e818.egron.tnx', 'cn-e818.egron.tnx'],
#  ['migr-grp-oracle-23', 'cn-d720.egron.tnx', 'cn-d720.egron.tnx'],
#  ['isurz-xml-storage-71', 'cn-dc8e.egron.tnx', 'cn-dc8e.egron.tnx'],
#  ['isurz-xml-storage-67', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['isurz-xml-storage-64', 'cn-e4c2.egron.tnx', 'cn-e4c2.egron.tnx'],
#  ['isurz-xml-storage-60', 'cn-db28.egron.tnx', 'cn-db28.egron.tnx'],
#  ['isurz-xml-storage-33', 'cn-daa0.egron.tnx', 'cn-daa0.egron.tnx'],
#  ['isurz-xml-storage-31', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx'],
#  ['isurz-xml-storage-00', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['pmuf-zabbix-db-01', 'cn-e810.egron.tnx', 'cn-e810.egron.tnx'],
#  ['pkurp-worker-003', 'cn-e80e.egron.tnx', 'cn-e80e.egron.tnx'],
#  ['isurz-writer-071', 'cn-dca8.egron.tnx', 'cn-dca8.egron.tnx'],
#  ['isurz-writer-069', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['isurz-writer-064', 'cn-dca8.egron.tnx', 'cn-dca8.egron.tnx'],
#  ['isurz-writer-060', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['isurz-writer-057', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['isurz-writer-048', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['isurz-writer-046', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['isurz-writer-040', 'cn-ee38.egron.tnx', 'cn-ee38.egron.tnx'],
#  ['isurz-writer-037', 'cn-dc84.egron.tnx', 'cn-dc84.egron.tnx'],
#  ['isurz-writer-034', 'cn-ed8e.egron.tnx', 'cn-ed8e.egron.tnx'],
#  ['isurz-writer-031', 'cn-daa0.egron.tnx', 'cn-daa0.egron.tnx'],
#  ['isurz-writer-001', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['isurz-writer-000', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['isurz-uploader-balancer-01', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['isurz-api-balancer-01', 'cn-ed8c.egron.tnx', 'cn-ed8c.egron.tnx'],
#  ['isurz-api-06', 'cn-e13a.egron.tnx', 'cn-e13a.egron.tnx'],
#  ['isurz-api-05', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx'],
#  ['isurz-api-03', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['Isurz-api-01', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['pkurp-redis-001', 'cn-dc8e.egron.tnx', 'cn-dc8e.egron.tnx'],
#  ['popd-bpd-01', 'cn-e13e.egron.tnx', 'cn-e13e.egron.tnx'],
#  ['ppoz-kuvd-migration-service-09', 'cn-e812.egron.tnx', 'cn-e812.egron.tnx'],
#  ['ppoz-kuvd-migration-service-03', 'cn-da16.egron.tnx', 'cn-da16.egron.tnx'],
#  ['ppoz-kuvd-migration-service-01', 'cn-db74.egron.tnx', 'cn-db74.egron.tnx'],
#  ['ppoz-filestorage-bal-02', 'cn-e4c2.egron.tnx', 'cn-e4c2.egron.tnx'],
#  ['ppoz-filestorage-04', 'cn-dc8c.egron.tnx', 'cn-dc8c.egron.tnx'],
#  ['ppoz-filestorage-03', 'cn-e13a.egron.tnx', 'cn-e13a.egron.tnx'],
#  ['ppoz-filestorage-01', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['isurz-uploader-076', 'cn-e4b8.egron.tnx', 'cn-e4b8.egron.tnx'],
#  ['isurz-uploader-071', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx'],
#  ['isurz-uploader-067', 'cn-dcaa.egron.tnx', 'cn-dcaa.egron.tnx'],
#  ['isurz-uploader-061', 'cn-dc84.egron.tnx', 'cn-dc84.egron.tnx'],
#  ['isurz-uploader-060', 'cn-dca8.egron.tnx', 'cn-dca8.egron.tnx'],
#  ['isurz-uploader-057', 'cn-e13e.egron.tnx', 'cn-e13e.egron.tnx'],
#  ['isurz-uploader-048', 'cn-ed8c.egron.tnx', 'cn-ed8c.egron.tnx'],
#  ['isurz-uploader-046', 'cn-dc8c.egron.tnx', 'cn-dc8c.egron.tnx'],
#  ['isurz-uploader-040', 'cn-db38.egron.tnx', 'cn-db38.egron.tnx'],
#  ['isurz-uploader-036', 'cn-dca4.egron.tnx', 'cn-dca4.egron.tnx'],
#  ['isurz-uploader-032', 'cn-daa0.egron.tnx', 'cn-daa0.egron.tnx'],
#  ['isurz-uploader-008', 'cn-dc7c.egron.tnx', 'cn-dc7c.egron.tnx'],
#  ['isurz-uploader-000', 'cn-da22.egron.tnx', 'cn-da22.egron.tnx'],
#  ['popd-bpd-adapter-01', 'cn-dc9a.egron.tnx', 'cn-dc9a.egron.tnx'],
#  ['pmuf-zabbix-server-02', 'cn-e4b8.egron.tnx', 'cn-e4b8.egron.tnx'],
#  ['pmuf-zabbix-server-01', 'cn-dca2.egron.tnx', 'cn-dca2.egron.tnx']]

# %%
sa = [i for i in dVirtualHyper.keys() if dVirtualHyper[i]['label'] in lMigr]

# %%
sv = [i for i in dVirtualVm.keys() if dVirtualVm[i]['cn'] in sa]

# %%
len(sv)
# Out:
# 170

# %%
sa
# Out:
# ['cn-da18.egron.tnx',
#  'cn-da48.egron.tnx',
#  'cn-da4a.egron.tnx',
#  'cn-daa6.egron.tnx',
#  'cn-db08.egron.tnx',
#  'cn-db26.egron.tnx',
#  'cn-e0ba.egron.tnx',
#  'cn-e4ba.egron.tnx',
#  'cn-e4bc.egron.tnx',
#  'cn-e620.egron.tnx',
#  'cn-e826.egron.tnx']

# %%
sa_fail = ['cn-e0ba.egron.tnx', \
'cn-daa6.egron.tnx',\
'cn-db08.egron.tnx',\
'cn-e4bc.egron.tnx',\
'cn-e4ba.egron.tnx',\
'cn-e620.egron.tnx',\
'cn-da18.egron.tnx',\
'cn-da48.egron.tnx',\
'cn-da4a.egron.tnx',\
'cn-e826.egron.tnx',\
]

# %%
len(sa), len(sa_fail)
# Out:
# (11, 10)

# %%
set(sa) - set(sa_fail)
# Out:
# {'cn-db26.egron.tnx'}

# %%
dVirtualHyper['cn-db26.egron.tnx']
# Out:
# {'az': 1,
#  'free_cpu': 56,
#  'free_ram': 516990,
#  'label': 'S_CMP16',
#  'migr': True,
#  'total_cpu': 56,
#  'total_ram': 516990,
#  'vm_count': 0,
#  'vms': []}

# %%
[i for i in dVirtualVm.keys() if dVirtualVm[i]['cn'] == 'cn-db26.egron.tnx']
# Out:
# ['egron-elasticsearch-03',
#  'migr-node-172',
#  'migr-node-165',
#  'migr-node-160',
#  'migr-node-152',
#  'migr-node-142',
#  'migr-node-136',
#  'migr-node-128',
#  'migr-node-121',
#  'migr-node-096',
#  'migr-node-088',
#  'migr-node-065',
#  'mdr-app-001-2',
#  'pg-attribute-08',
#  'pg-attribute-01']
